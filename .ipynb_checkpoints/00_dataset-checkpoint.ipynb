# %% [markdown]
# This notebook search GitHub to create our Dataset
#
#  - 100 projects, 10 for each of the most popular 10 programming languages

# %%
import requests
import json
import datetime

import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Language Selection
#
# The language selection comes from the top 10 technologies from Stackoverflow survey on 2019

# %%
languages = [
    "javascript",
    "typescript",
    "java",
    "python",
    "php",
    "c++",
    "c#",
    "c",
    "ruby",
    "go"
]
projects_per_lang = 35

# %% [markdown]
# # GitHub Search
#
# To search GitHub, we need an API key, which is founded on the [Developer settings](https://github.com/settings/tokens).
# The following file is private, therefore not versioned.

# %%
token=!cat token
headers = {'Authorization': f'Bearer {token[0]}'}

# %% [markdown]
# Github GraphQL query to search repositories:

# %%
query = '''
    query($qnt: Int!, $query: String!) {
        search(
            query: $query,
            type: REPOSITORY,
            first: $qnt
        ) {
            repositoryCount
            nodes {
                ... on Repository {
                    name: nameWithOwner
                    description
                    url
                    stars: stargazers { totalCount }
                    issues{ totalCount }
                    releases { totalCount }
                    commits: object(expression: "HEAD") {
                        ... on Commit { 
                            last_commit: committedDate
                            history{ totalCount }
                        }
                    }
                    tags: refs(refPrefix: "refs/tags/") { totalCount }
                }
            }
        }
    }
'''

# %%
def process_language(lang, data):
    """ Create pandas dataframe from GitHub query response """
    project_lang_data = data['data']['search']['nodes']
    for project_data in project_lang_data:
        project_data['lang'] = lang
        
        # flatten results
        project_data['last_commit'] = project_data['commits']['last_commit']
        project_data['commits'] = project_data['commits']['history']
        for key in project_data.keys():
            if isinstance(project_data[key], dict) and 'totalCount' in project_data[key]:
                project_data[key] = project_data[key]['totalCount']
                
    df = pd.DataFrame.from_dict(data['data']['search']['nodes'])
    return df

# %%
print(f'Searching GitHub on {datetime.date.today()}')
github_projects = pd.DataFrame(columns=['name', 'lang', 'stars', 'commits', 'issues', 'tags', 'releases', 'last_commit', 'description', 'url'])

for lang in languages:
    print(f'Searching lang {lang}')
    response = requests.post('https://api.github.com/graphql', headers=headers, json={
        'query': query,
        'variables': { 'query': f'language:{lang} stars:>5000 sort:stars-desc', 'qnt': projects_per_lang }
    })
    if response.ok:
        data = json.loads(response.content)
        project_lang_df = process_language(lang, data)
        github_projects = pd.concat([github_projects, project_lang_df])
# Out:
# Searching GitHub on 2020-10-10
# Searching lang javascript
# Searching lang typescript
# Searching lang java
# Searching lang python
# Searching lang php
# Searching lang c++
# Searching lang c#
# Searching lang c
# Searching lang ruby
# Searching lang go

# %%
github_projects.last_commit = pd.to_datetime(github_projects.last_commit)
github_projects.stars = pd.to_numeric(github_projects.stars)
github_projects.commits = pd.to_numeric(github_projects.commits)
github_projects.issues = pd.to_numeric(github_projects.issues)
github_projects.releases = pd.to_numeric(github_projects.releases)
github_projects.tags = pd.to_numeric(github_projects.tags)

# %%
github_projects.head(5)
# Out:
#                         name        lang   stars  commits  issues  tags  \
# 0  freeCodeCamp/freeCodeCamp  javascript  315467    26316   14827     0
# 1                  vuejs/vue  javascript  173633     3127    9211   250
# 2             facebook/react  javascript  157151    13618    9635   131
# 3             twbs/bootstrap  javascript  144624    20098   19637    62
# 4          airbnb/javascript  javascript  100327     1835    1030    94
#
#    releases               last_commit  \
# 0         0 2020-10-10 18:25:34+00:00
# 1       208 2020-10-05 14:57:24+00:00
# 2        90 2020-10-09 13:29:30+00:00
# 3        62 2020-10-07 14:03:53+00:00
# 4         0 2020-10-06 14:36:29+00:00
#
#                                          description  \
# 0  freeCodeCamp.org's open source codebase and cu...
# 1  🖖 Vue.js is a progressive, incrementally-adopt...
# 2  A declarative, efficient, and flexible JavaScr...
# 3  The most popular HTML, CSS, and JavaScript fra...
# 4                             JavaScript Style Guide
#
#                                             url
# 0  https://github.com/freeCodeCamp/freeCodeCamp
# 1                  https://github.com/vuejs/vue
# 2             https://github.com/facebook/react
# 3             https://github.com/twbs/bootstrap
# 4          https://github.com/airbnb/javascript

# %%
github_projects.shape
# Out:
# (350, 10)

# %% [markdown]
# # Project filtering

# %%
def select_projects(projects):
    for lang, data in projects.groupby(["lang"]):
        data = data[data.discarded == False].nlargest(n=10, columns="stars")
        projects.loc[projects.name.isin(data.name), 'selected'] = True
    return projects[(projects.selected == True) & (projects.discarded == False)].copy()

# %%
def discard_projects(projects, discard, reason):
    projects.loc[projects.name.isin(discard.name), 'discarded'] = reason

# %%
def remove_inactive_projects(projects, age):
    """ Remove inactive projects """
    selected_projects = projects[projects.last_commit > age]
    discarded_projects = projects[~projects.name.isin(selected_projects.name)]
    return [selected_projects, discarded_projects, discarded_projects.shape[0]]

# %%
def remove_small_projects(projects, min_commits):
    """ Remove projects with less commits than min_commits"""
    selected_projects = projects[projects.commits >= min_commits]
    discarded_projects = projects[~projects.name.isin(selected_projects.name)]
    return [selected_projects, discarded_projects, discarded_projects.shape[0]]

# %%
def remove_big_projects(projects, max_percent_commits):
    """ Remove projects with more commits than a percentage of total """
    sum_commits = projects.commits.sum()
    projects['perc_commits'] = projects.commits / sum_commits

    selected_projects = projects[projects.perc_commits <= max_percent_commits]
    discarded_projects = projects[~projects.name.isin(selected_projects.name)]
    return [selected_projects, discarded_projects, discarded_projects.shape[0]]

# %%
def remove_non_software_projects(projects):
    # c#
    projects.loc[projects.name == 'dotnet/AspNetCore.Docs', 'software'] = False
    # go:
    projects.loc[projects.name == 'avelino/awesome-go', 'software'] = False
    projects.loc[projects.name == 'astaxie/build-web-application-with-golang', 'software'] = False

    # java:
    projects.loc[projects.name == 'CyC2018/CS-Notes', 'software'] = False
    projects.loc[projects.name == 'Snailclimb/JavaGuide', 'software'] = False
    projects.loc[projects.name == 'iluwatar/java-design-patterns', 'software'] = False
    projects.loc[projects.name == 'eugenp/tutorials', 'software'] = False
  
    
    # javascript:
    projects.loc[projects.name == 'freeCodeCamp/freeCodeCamp', 'software'] = False
    projects.loc[projects.name == '30-seconds/30-seconds-of-code', 'software'] = False

    # python:
    projects.loc[projects.name == 'public-apis/public-apis', 'software'] = False
    projects.loc[projects.name == 'tensorflow/models', 'software'] = False

    # ruby:
    projects.loc[projects.name == 'freeCodeCamp/devdocs', 'software'] = False
    
    # typescript
    projects.loc[projects.name == 'DefinitelyTyped/DefinitelyTyped', 'software'] = False
    
    
    """ Remove non software projects """
    selected_projects = projects[projects.software == True]
    discarded_projects = projects[~projects.name.isin(selected_projects.name)]
    return [selected_projects, discarded_projects, discarded_projects.shape[0]]

# %%
def remove_shared_repo_projects(projects):
    # c
    projects.loc[projects.name == 'curl/curl', 'shared'] = True
    projects.loc[projects.name == 'git/git', 'shared'] = True
    projects.loc[projects.name == 'libuv/libuv', 'shared'] = True
    projects.loc[projects.name == 'openssl/openssl', 'shared'] = True
    projects.loc[projects.name == 'redis/redis', 'shared'] = True
    projects.loc[projects.name == 'bilibili/ijkplayer', 'shared'] = True
    projects.loc[projects.name == 'facebook/zstd', 'shared'] = True

    # c#
    projects.loc[projects.name == 'dotnet-architecture/eShopOnContainers', 'shared'] = True
    projects.loc[projects.name == 'dotnet/aspnetcore', 'shared'] = True
    projects.loc[projects.name == 'dotnet/roslyn', 'shared'] = True
    projects.loc[projects.name == 'PowerShell/PowerShell', 'shared'] = True
    projects.loc[projects.name == 'AvaloniaUI/Avalonia', 'shared'] = True
    projects.loc[projects.name == 'OpenRA/OpenRA', 'shared'] = True
    projects.loc[projects.name == 'Unity-Technologies/ml-agents', 'shared'] = True

    # c++
    projects.loc[projects.name == 'BVLC/caffe', 'shared'] = True
    projects.loc[projects.name == 'grpc/grpc', 'shared'] = True
    projects.loc[projects.name == 'rethinkdb/rethinkdb', 'shared'] = True

    # go
    projects.loc[projects.name == 'ethereum/go-ethereum', 'shared'] = True
    projects.loc[projects.name == 'moby/moby', 'shared'] = True
    projects.loc[projects.name == 'golang/go', 'shared'] = True
    projects.loc[projects.name == 'pingcap/tidb', 'shared'] = True
    projects.loc[projects.name == 'syncthing/syncthing', 'shared'] = True

    # java
    projects.loc[projects.name == 'google/guava', 'shared'] = True
    projects.loc[projects.name == 'ReactiveX/RxJava', 'shared'] = True
    projects.loc[projects.name == 'zxing/zxing', 'shared'] = True

    # javascript
    projects.loc[projects.name == 'facebook/create-react-app', 'shared'] = True
    projects.loc[projects.name == 'mui-org/material-ui', 'shared'] = True

    # php
    projects.loc[projects.name == 'symfony/symfony', 'shared'] = True

    # python
    projects.loc[projects.name == 'scikit-learn/scikit-learn', 'shared'] = True

    # ruby
    projects.loc[projects.name == 'fastlane/fastlane', 'shared'] = True
    projects.loc[projects.name == 'rails/rails', 'shared'] = True
    projects.loc[projects.name == 'rapid7/metasploit-framework', 'shared'] = True
    projects.loc[projects.name == 'jekyll/jekyll', 'shared'] = True
    projects.loc[projects.name == 'ruby/ruby', 'shared'] = True
    projects.loc[projects.name == 'elastic/logstash', 'shared'] = True
    
    # typescript
    projects.loc[projects.name == 'angular/angular', 'shared'] = True
    projects.loc[projects.name == 'denoland/deno', 'shared'] = True
    projects.loc[projects.name == 'microsoft/vscode', 'shared'] = True
    projects.loc[projects.name == 'pixijs/pixi.js', 'shared'] = True
    
    """ Remove shared repo projects """
    selected_projects = projects[projects.shared == False]
    discarded_projects = projects[~projects.name.isin(selected_projects.name)]
    return [selected_projects, discarded_projects, discarded_projects.shape[0]]

# %%
def remove_few_releasesprojects(projects):
    """ Remove projects with fewer releases than 10 """

    # go
    projects.loc[projects.name == 'minio/minio', 'few_releases'] = True
    
    # c++
    projects.loc[projects.name == 'x64dbg/x64dbg', 'few_releases'] = True
    
    # ruby
    projects.loc[projects.name == 'huginn/huginn', 'few_releases'] = True
    projects.loc[projects.name == 'forem/forem', 'few_releases'] = True
    
    # c#
    projects.loc[projects.name == '0xd4d/dnSpy', 'few_releases'] = True
    
    # c
    projects.loc[projects.name == 'coolsnowwolf/lede', 'few_releases'] = True
    
    selected_projects = projects[projects.few_releases == False]
    discarded_projects = projects[~projects.name.isin(selected_projects.name)]
    return [selected_projects, discarded_projects, discarded_projects.shape[0]]

# %%
def remove_date_release_projects(projects):
    """ Remove projects with fewer releases than 10 """

    # python
    projects.loc[projects.name == 'ytdl-org/youtube-dl', 'date_releases'] = True
    
    selected_projects = projects[projects.date_releases == False]
    discarded_projects = projects[~projects.name.isin(selected_projects.name)]
    return [selected_projects, discarded_projects, discarded_projects.shape[0]]

# %% [markdown]
# ## Discard projects
#
#  - Inactive
#  - Too small
#  - Too big
#  - Non software
#  - Shared Repo

# %%
today = pd.to_datetime('now').tz_localize('UTC').normalize()
delta = pd.to_timedelta(30*6, unit='d')

age = today - delta
min_commits = 2000
max_percent_commits = 0.05

# %%
def scan(all_projects, fnc, label, **params):
    converged = False
    cnt_discarded = 0
    while not converged:
        projects = select_projects(all_projects)
        params['projects'] = projects
        [s,d,n] = fnc(**params)
        discard_projects(all_projects, d, label)
        converged = (n == 0)
        cnt_discarded += n
        if n:
            print(f' - discarded {n} - {label}')
    return cnt_discarded

# %%
all_projects = github_projects.copy()
all_projects["discarded"] = False
all_projects["software"] = True
all_projects["shared"] = False
all_projects["few_releases"] = False
all_projects["date_releases"] = False

round = 1
fully_converged = False
while not fully_converged:
    cnt_discarded = 0
    
    print(f'Round {round}')
    cnt_discarded += scan(all_projects, remove_inactive_projects, 'inactivity', **{ 'age': age })
    cnt_discarded += scan(all_projects, remove_small_projects, 'small', **{ 'min_commits': min_commits })
    cnt_discarded += scan(all_projects, remove_non_software_projects, 'non_software')
    cnt_discarded += scan(all_projects, remove_big_projects, 'big', **{ 'max_percent_commits': max_percent_commits })
    cnt_discarded += scan(all_projects, remove_shared_repo_projects, 'shared')
    cnt_discarded += scan(all_projects, remove_few_releasesprojects, 'few_releases')
    cnt_discarded += scan(all_projects, remove_date_release_projects, 'date_releases')
        
    projects = select_projects(all_projects)
    
    fully_converged = (cnt_discarded == 0)
    print(f'Discarded {cnt_discarded} projects\n')
    round += 1
# Out:
# Round 1
#  - discarded 2 - inactivity
#  - discarded 25 - small
#  - discarded 9 - small
#  - discarded 9 - non_software
#  - discarded 1 - big
#  - discarded 2 - big
#  - discarded 2 - big
#  - discarded 2 - big
#  - discarded 25 - shared
#  - discarded 5 - shared
#  - discarded 3 - shared
#  - discarded 4 - few_releases
#  - discarded 1 - date_releases
# Discarded 90 projects
#
# Round 2
#  - discarded 6 - inactivity
#  - discarded 1 - inactivity
#  - discarded 1 - inactivity
#  - discarded 13 - small
#  - discarded 5 - small
#  - discarded 3 - small
#  - discarded 1 - small
#  - discarded 1 - small
#  - discarded 1 - small
#  - discarded 3 - non_software
#  - discarded 3 - big
#  - discarded 6 - shared
#  - discarded 2 - few_releases
# Discarded 46 projects
#
# Round 3
#  - discarded 2 - inactivity
#  - discarded 3 - small
#  - discarded 1 - small
# Discarded 6 projects
#
# Round 4
# Discarded 0 projects

# %%
all_projects.loc[all_projects.discarded != False, ['name', 'discarded', 'commits', 'tags', 'last_commit']].sort_values(['discarded','commits'], ascending=[True,False])
# Out:
#                                                  name      discarded  commits  \
# 0                                      torvalds/linux            big   951249
# 19                                          mono/mono            big   122183
# 5                                         php/php-src            big   121215
# 13                             Homebrew/homebrew-cask            big   117397
# 3                                         apple/swift            big   112435
# 23                                     python/cpython            big   108207
# 8                                   gitlabhq/gitlabhq            big   104618
# 9                                       FFmpeg/FFmpeg            big    99522
# 0                               tensorflow/tensorflow            big    97309
# 1                               kubernetes/kubernetes            big    94709
# 5                                 ytdl-org/youtube-dl  date_releases    17768
# 21                                        minio/minio   few_releases     7335
# 16                                        forem/forem   few_releases     6986
# 10                                      x64dbg/x64dbg   few_releases     4502
# 5                                         0xd4d/dnSpy   few_releases     3915
# 4                                       huginn/huginn   few_releases     3324
# 29                                  coolsnowwolf/lede   few_releases     2914
# 11          julycoding/The-Art-Of-Programming-By-July     inactivity     3633
# 6                                freeCodeCamp/devdocs     inactivity     3362
# 24                                     vurtun/nuklear     inactivity     1712
# 17                                twbs/bootstrap-sass     inactivity     1032
# 23                          robertdavidgraham/masscan     inactivity      576
# 30                                greenrobot/EventBus     inactivity      507
# 13  SamyPesse/How-to-Make-a-Computer-Operating-System     inactivity      243
# 15                             cfenollosa/os-tutorial     inactivity      147
# 17                                 FiloSottile/mkcert     inactivity      137
# 7                                              wg/wrk     inactivity       76
# 19                        Awesome-HarmonyOS/HarmonyOS     inactivity       74
# 24                            shadowsocks/shadowsocks     inactivity        1
# 15                    DefinitelyTyped/DefinitelyTyped   non_software    72008
# 0                           freeCodeCamp/freeCodeCamp   non_software    26316
# 29                                   eugenp/tutorials   non_software    20659
# 27                             dotnet/AspNetCore.Docs   non_software    11148
# 6                                   tensorflow/models   non_software     5955
# 12                      30-seconds/30-seconds-of-code   non_software     5144
# 7           astaxie/build-web-application-with-golang   non_software     5111
# 0                                    CyC2018/CS-Notes   non_software     3645
# 3                                  avelino/awesome-go   non_software     3550
# 2                       iluwatar/java-design-patterns   non_software     2932
# 1                                Snailclimb/JavaGuide   non_software     2604
# 1                             public-apis/public-apis   non_software     2187
# 0                                         rails/rails         shared    77936
# 0                                    microsoft/vscode         shared    71538
# 10                                      dotnet/roslyn         shared    65576
# 14                                          ruby/ruby         shared    63371
# 4                                             git/git         shared    60748
# 10                        rapid7/metasploit-framework         shared    58373
# 4                                     symfony/symfony         shared    51252
# 14                                          grpc/grpc         shared    47051
# 3                                   dotnet/aspnetcore         shared    44997
# 0                                           golang/go         shared    44986
# 2                                           moby/moby         shared    39006
# 15                                rethinkdb/rethinkdb         shared    33433
# 22                                      OpenRA/OpenRA         shared    27547
# 20                                    openssl/openssl         shared    27284
# 16                                          curl/curl         shared    26307
# 15                          scikit-learn/scikit-learn         shared    26186
# 2                                     angular/angular         shared    19018
# 3                                   fastlane/fastlane         shared    15616
# 16                                AvaloniaUI/Avalonia         shared    14138
# 14                                mui-org/material-ui         shared    12808
# 16                               ethereum/go-ethereum         shared    12048
# 18                                       pingcap/tidb         shared    11872
# 1                                       jekyll/jekyll         shared    11131
# 2                                         redis/redis         shared     9705
# 20                                   elastic/logstash         shared     9648
# 2                               PowerShell/PowerShell         shared     8317
# 27                                      facebook/zstd         shared     8087
# 11                                syncthing/syncthing         shared     6041
# 8                                    ReactiveX/RxJava         shared     5788
# 14                                     pixijs/pixi.js         shared     5432
# 11                                       google/guava         shared     5354
# 18                                        libuv/libuv         shared     4724
# 1                                       denoland/deno         shared     4480
# 12                                         BVLC/caffe         shared     4156
# 6               dotnet-architecture/eShopOnContainers         shared     3565
# 20                                        zxing/zxing         shared     3560
# 7                           facebook/create-react-app         shared     2607
# 6                                  bilibili/ijkplayer         shared     2599
# 17                       Unity-Technologies/ml-agents         shared     2584
# 3                                 puppeteer/puppeteer          small     1974
# 13                                    ariya/phantomjs          small     1958
# 22                                       nothings/stb          small     1940
# 13                                    square/retrofit          small     1857
# 13                                       junegunn/fzf          small     1839
# 4                                   airbnb/javascript          small     1835
# 3                                TheAlgorithms/Python          small     1831
# 25                            JamesNK/Newtonsoft.Json          small     1821
# 29                                restsharp/RestSharp          small     1813
# 15                        kilimchoi/engineering-blogs          small     1702
# 21                              capistrano/capistrano          small     1666
# 2                                  microsoft/terminal          small     1655
# 12                                PHPMailer/PHPMailer          small     1643
# 4                                vinta/awesome-python          small     1585
# 7                                        nvbn/thefuck          small     1567
# 12              josephmisiti/awesome-machine-learning          small     1491
# 0                     shadowsocks/shadowsocks-windows          small     1448
# 12                               StackExchange/Dapper          small     1415
# 5                                       gin-gonic/gin          small     1402
# 27                                        skylot/jadx          small     1336
# 28                                     alibaba/arthas          small     1325
# 17                                        stedolan/jq          small     1323
# 19                             Blankj/AndroidUtilCode          small     1297
# 11                                      httpie/httpie          small     1277
# 10                                    cdr/code-server          small     1269
# 1                          blueimp/jQuery-File-Upload          small     1249
# 16                                 TheAlgorithms/Java          small     1247
# 11                     thangchung/awesome-dotnet-core          small     1230
# 18                              airbnb/lottie-android          small     1220
# 18                                     cmderdev/cmder          small     1200
# 25                                 deepfakes/faceswap          small     1181
# 8                           domnikl/DesignPatternsPHP          small     1091
# 22                            JakeWharton/butterknife          small     1016
# 2                             danielmiessler/SecLists          small      987
# 3                                   Genymobile/scrcpy          small      977
# 9                                         axios/axios          small      966
# 26                                    App-vNext/Polly          small      966
# 6                                        fatedier/frp          small      866
# 15                                  caddyserver/caddy          small      866
# 8                      trekhleb/javascript-algorithms          small      825
# 13                           NickeManarin/ScreenToGif          small      751
# 23                              crossoverJie/JCSprout          small      704
# 1                                  CodeHubApp/CodeHub          small      593
# 9                                     macrozheng/mall          small      566
# 5                        bayandin/awesome-awesomeness          small      531
# 7                                 doocs/advanced-java          small      508
# 21             GoogleCloudPlatform/microservices-demo          small      501
# 21                      proxyee-down-org/proxyee-down          small      474
# 6                                   kdn251/interviews          small      445
# 14                                   pjreddie/darknet          small      440
# 17                                     google/leveldb          small      337
# 2                           jackfrued/Python-100-Days          small      319
# 0                    donnemartin/system-design-primer          small      315
# 8                                        2dust/v2rayN          small      287
# 17              minimaxir/big-list-of-naughty-strings          small      271
# 3                        MisterBooo/LeetCodeAnimation          small      241
# 18                          ageitgey/face_recognition          small      211
# 26                     ityouknow/spring-boot-examples          small      165
# 7                          mxgmn/WaveFunctionCollapse          small      117
# 22                           521xueweihan/HelloGitHub          small       92
# 11                           FortAwesome/Font-Awesome          small       74
# 24              kon9chunkit/GitHub-Chinese-Top-Charts          small       60
#
#     tags               last_commit
# 0    669 2020-10-10 01:05:12+00:00
# 19   466 2020-10-10 09:13:19+00:00
# 5   1075 2020-10-10 17:20:13+00:00
# 13   114 2020-10-10 17:04:23+00:00
# 3   1698 2020-10-10 17:54:41+00:00
# 23   448 2020-10-10 19:23:42+00:00
# 8   1253 2020-10-10 12:08:27+00:00
# 9    335 2020-10-10 13:37:54+00:00
# 0    121 2020-10-10 19:18:19+00:00
# 1    707 2020-10-10 05:22:46+00:00
# 5   1077 2020-09-24 00:37:10+00:00
# 21   198 2020-10-10 03:36:00+00:00
# 16     0 2020-10-09 22:07:49+00:00
# 10    29 2020-10-02 21:04:45+00:00
# 5      2 2020-09-21 21:31:07+00:00
# 4      0 2020-09-16 01:52:06+00:00
# 29     3 2020-10-10 06:01:45+00:00
# 11     0 2018-06-20 02:30:28+00:00
# 6      0 2020-03-22 14:21:16+00:00
# 24     0 2019-12-01 23:01:55+00:00
# 17    61 2019-02-13 18:58:58+00:00
# 23     8 2019-09-22 17:53:17+00:00
# 30     7 2020-02-11 09:52:09+00:00
# 13    12 2015-10-29 19:04:29+00:00
# 15     0 2018-11-03 00:25:59+00:00
# 17    11 2020-03-22 02:12:54+00:00
# 7     20 2019-04-18 01:51:32+00:00
# 19     0 2019-08-25 16:38:35+00:00
# 24    18 2015-08-22 02:45:55+00:00
# 15     1 2020-10-10 18:52:07+00:00
# 0      0 2020-10-10 18:25:34+00:00
# 29     0 2020-10-10 10:09:32+00:00
# 27    37 2020-10-10 03:56:44+00:00
# 6     15 2020-10-09 20:22:22+00:00
# 12     6 2020-10-10 18:09:15+00:00
# 7      0 2020-05-29 02:12:00+00:00
# 0      0 2020-09-26 15:12:09+00:00
# 3      0 2020-10-10 17:21:17+00:00
# 2     17 2020-10-10 15:51:00+00:00
# 1      0 2020-10-08 06:58:20+00:00
# 1      0 2020-10-10 07:33:43+00:00
# 0    429 2020-10-10 16:43:43+00:00
# 0    163 2020-10-10 17:32:25+00:00
# 10   146 2020-10-10 15:20:49+00:00
# 14  1127 2020-10-10 17:00:28+00:00
# 4    778 2020-10-09 04:53:26+00:00
# 10   696 2020-10-08 22:36:23+00:00
# 4    516 2020-10-08 16:18:58+00:00
# 14   197 2020-10-09 17:52:24+00:00
# 3    125 2020-10-10 05:13:13+00:00
# 0    293 2020-10-10 16:06:07+00:00
# 2    327 2020-10-09 16:03:26+00:00
# 15   139 2020-10-05 12:27:22+00:00
# 22   374 2020-10-10 15:54:55+00:00
# 20   316 2020-10-10 18:23:39+00:00
# 16   198 2020-10-09 15:29:33+00:00
# 15   112 2020-10-09 17:12:43+00:00
# 2    577 2020-10-09 17:57:37+00:00
# 3   1139 2020-10-09 11:23:56+00:00
# 16    32 2020-10-08 16:38:29+00:00
# 14   284 2020-10-10 18:27:56+00:00
# 16   177 2020-10-09 09:23:46+00:00
# 18   119 2020-10-10 05:34:53+00:00
# 1    144 2020-10-08 19:32:51+00:00
# 2    240 2020-10-08 05:33:17+00:00
# 20   232 2020-10-08 15:54:11+00:00
# 2     93 2020-10-09 17:43:31+00:00
# 27    59 2020-10-09 08:01:36+00:00
# 11   428 2020-10-08 15:37:45+00:00
# 8    242 2020-10-06 21:00:02+00:00
# 14   124 2020-10-08 14:36:43+00:00
# 11    90 2020-10-09 15:43:17+00:00
# 18   232 2020-10-02 16:02:39+00:00
# 1    144 2020-10-10 13:05:19+00:00
# 12    14 2020-02-13 07:20:36+00:00
# 6     15 2020-09-23 05:45:53+00:00
# 20    28 2020-10-01 13:34:53+00:00
# 7    362 2020-09-30 17:18:23+00:00
# 6     78 2020-09-15 07:15:25+00:00
# 17    83 2020-10-08 22:15:22+00:00
# 3     53 2020-10-08 15:02:37+00:00
# 13    23 2020-07-13 15:08:08+00:00
# 22     0 2020-07-13 11:46:06+00:00
# 13    54 2020-09-15 15:56:31+00:00
# 13    92 2020-10-10 17:04:07+00:00
# 4     94 2020-10-06 14:36:29+00:00
# 3      0 2020-10-10 17:59:02+00:00
# 25    62 2020-03-25 20:35:34+00:00
# 29    45 2020-09-30 21:04:21+00:00
# 15     0 2020-04-28 14:57:45+00:00
# 21   101 2020-08-26 15:57:51+00:00
# 2     58 2020-10-09 23:06:40+00:00
# 12    62 2020-10-10 13:29:36+00:00
# 4      0 2020-10-06 07:46:44+00:00
# 7     81 2020-07-16 21:56:58+00:00
# 12     0 2020-10-03 21:33:59+00:00
# 0     60 2020-09-30 13:04:10+00:00
# 12    61 2020-08-19 01:54:34+00:00
# 5     22 2020-09-25 01:45:17+00:00
# 27    14 2020-10-02 17:38:08+00:00
# 28    32 2020-10-09 12:01:14+00:00
# 17    11 2020-06-08 16:35:13+00:00
# 19   115 2020-09-08 07:52:50+00:00
# 11    37 2020-10-03 10:01:36+00:00
# 10    48 2020-08-29 21:23:20+00:00
# 1    134 2020-09-18 00:19:54+00:00
# 16     0 2020-10-06 07:04:06+00:00
# 11     0 2020-08-28 07:37:36+00:00
# 18    86 2020-10-03 22:14:40+00:00
# 18    29 2020-08-31 23:11:19+00:00
# 25     3 2020-10-10 10:43:16+00:00
# 8      0 2020-10-03 06:07:09+00:00
# 22    48 2020-09-04 02:00:12+00:00
# 2     11 2020-09-17 13:16:24+00:00
# 3     20 2020-10-05 19:24:59+00:00
# 9     45 2020-10-03 18:25:07+00:00
# 26    29 2020-05-02 11:42:54+00:00
# 6     56 2020-10-08 06:25:03+00:00
# 15    87 2020-10-09 17:32:09+00:00
# 8      0 2020-10-05 19:26:24+00:00
# 13    59 2020-10-07 19:10:28+00:00
# 23     1 2020-05-18 13:54:42+00:00
# 1     39 2020-05-06 02:29:18+00:00
# 9      2 2020-10-08 07:04:13+00:00
# 5      0 2020-10-01 09:05:51+00:00
# 7      0 2020-10-03 13:58:25+00:00
# 21     7 2020-10-08 19:46:38+00:00
# 21    50 2020-08-11 09:34:24+00:00
# 6      0 2020-06-06 02:37:07+00:00
# 14     0 2020-08-16 16:17:19+00:00
# 17    20 2020-10-07 21:15:26+00:00
# 2      0 2020-10-04 00:58:07+00:00
# 0      0 2020-08-02 18:13:17+00:00
# 8     53 2020-10-09 12:35:08+00:00
# 17     0 2020-05-26 02:39:03+00:00
# 3      0 2020-08-24 01:27:49+00:00
# 18     2 2020-09-26 15:32:59+00:00
# 26     0 2020-04-18 05:17:32+00:00
# 7      0 2020-10-08 06:45:25+00:00
# 22     9 2020-09-29 09:41:32+00:00
# 11    64 2020-10-05 18:25:08+00:00
# 24     0 2020-10-05 11:52:40+00:00

# %%
all_projects[all_projects.discarded != False]['discarded'].value_counts()
# Out:
# small            62
# shared           39
# non_software     12
# inactivity       12
# big              10
# few_releases      6
# date_releases     1
# Name: discarded, dtype: int64

# %%
all_projects[all_projects.discarded != False]['discarded'].value_counts().sum()
# Out:
# 142

# %% [markdown]
# ## Project list for manual inspection

# %%
for lang, data in projects.groupby(["lang"]):
    print(f'language: {lang}')
    #for i, project in data.iterrows():
    print(f" - {'stars':6} {'name':25}  {'description'}")
    for project in data.itertuples():
        print(f" - {project.stars:6} {project.name:25}: {project.description}")
    print("\n")
# Out:
# language: c
#  - stars  name                       description
#  -  48821 netdata/netdata          : Real-time performance monitoring, done right! https://www.netdata.cloud
#  -  22526 obsproject/obs-studio    : OBS Studio - Free and open source software for live streaming and screen recording
#  -  20985 ggreer/the_silver_searcher: A code-searching tool similar to ack, but faster.
#  -  19085 tmux/tmux                : tmux source code
#  -  13860 taosdata/TDengine        : An open-source big data platform designed and optimized for the Internet of Things (IoT).
#  -  13242 radareorg/radare2        : UNIX-like reverse engineering framework and command-line toolset
#  -  13130 mpv-player/mpv           : 🎥 Command line video player
#  -  12745 nginx/nginx              : An official read-only mirror of http://hg.nginx.org/nginx/ which is updated hourly. Pull requests on GitHub cannot be accepted and will be automatically closed. The proper way to submit changes to nginx is via the nginx development mailing list, see http://nginx.org/en/docs/contributing_changes.html
#  -  12401 arendst/Tasmota          : Alternative firmware for ESP8266 with easy configuration using webUI, OTA updates, automation using timers or rules, expandability and entirely local control over MQTT, HTTP, Serial or KNX. Full documentation at
#  -  12189 allinurl/goaccess        : GoAccess is a real-time web log analyzer and interactive viewer that runs in a terminal in *nix systems or through your browser.
#
#
# language: c#
#  - stars  name                       description
#  -  18451 Wox-launcher/Wox         : Launcher for Windows, an alternative to Alfred and Launchy.
#  -  13977 ShareX/ShareX            : ShareX is a free and open source program that lets you capture or record any area of your screen and share it with a single press of a key. It also allows uploading images, text or other types of files to many supported destinations you can choose from.
#  -  11179 icsharpcode/ILSpy        : .NET Decompiler with support for PDB generation, ReadyToRun, Metadata (&more) - cross-platform!
#  -   9697 MaterialDesignInXAML/MaterialDesignInXamlToolkit: Google's Material Design in XAML & WPF, for C# & VB.Net.
#  -   9529 dotnet/efcore            : EF Core is a modern object-database mapper for .NET. It supports LINQ queries, change tracking, updates, and schema migrations.
#  -   8896 aspnetboilerplate/aspnetboilerplate: ASP.NET Boilerplate - Web Application Framework
#  -   8185 jellyfin/jellyfin        : The Free Software Media System
#  -   8130 SignalR/SignalR          : Incredibly simple real-time web for .NET
#  -   7544 AutoMapper/AutoMapper    : A convention-based object-object mapper in .NET.
#  -   7388 cefsharp/CefSharp        : .NET (WPF and Windows Forms) bindings for the Chromium Embedded Framework
#
#
# language: c++
#  - stars  name                       description
#  -  86283 electron/electron        : :electron: Build cross-platform desktop apps with JavaScript, HTML, and CSS
#  -  48855 opencv/opencv            : Open Source Computer Vision Library
#  -  45395 bitcoin/bitcoin          : Bitcoin Core integration/staging tree
#  -  44177 protocolbuffers/protobuf : Protocol Buffers - Google's data interchange format
#  -  43011 pytorch/pytorch          : Tensors and Dynamic neural networks in Python with strong GPU acceleration
#  -  39205 microsoft/PowerToys      : Windows system utilities to maximize productivity
#  -  36695 tesseract-ocr/tesseract  : Tesseract Open Source OCR Engine (main repository)
#  -  33725 godotengine/godot        : Godot Engine – Multi-platform 2D and 3D game engine
#  -  23910 ocornut/imgui            : Dear ImGui: Bloat-free Graphical User interface for C++ with minimal dependencies
#  -  21113 aria2/aria2              : aria2 is a lightweight multi-protocol & multi-source, cross platform download utility operated in command-line. It supports HTTP/HTTPS, FTP, SFTP, BitTorrent and Metalink.
#
#
# language: go
#  - stars  name                       description
#  -  47145 gohugoio/hugo            : The world’s fastest framework for building websites.
#  -  35548 gogs/gogs                : Gogs is a painless self-hosted Git service
#  -  35246 v2ray/v2ray-core         : A platform for building proxies to bypass network restrictions.
#  -  33269 prometheus/prometheus    : The Prometheus monitoring system and time series database.
#  -  33056 etcd-io/etcd             : Distributed reliable key-value store for the most critical data of a distributed system
#  -  31046 traefik/traefik          : The Cloud Native Application Proxy
#  -  25010 astaxie/beego            : beego is an open-source, high-performance web framework for the Go programming language.
#  -  24681 istio/istio              : Connect, secure, control, and observe services.
#  -  24008 hashicorp/terraform      : Terraform enables you to safely and predictably create, change, and improve infrastructure. It is an open source tool that codifies APIs into declarative configuration files that can be shared amongst team members, treated as code, edited, reviewed, and versioned.
#  -  23744 rclone/rclone            : "rsync for cloud storage" - Google Drive, Amazon Drive, S3, Dropbox, Backblaze B2, One Drive, Swift, Hubic, Cloudfiles, Google Cloud Storage, Yandex Files
#
#
# language: java
#  - stars  name                       description
#  -  51561 elastic/elasticsearch    : Open Source, Distributed, RESTful Search Engine
#  -  51005 spring-projects/spring-boot: Spring Boot
#  -  39624 spring-projects/spring-framework: Spring Framework
#  -  38392 square/okhttp            : Square’s meticulous HTTP client for the JVM, Android, and GraalVM.
#  -  33730 apache/dubbo             : Apache Dubbo is a high-performance, java based, open source RPC framework.
#  -  31866 PhilJay/MPAndroidChart   : A powerful 🚀 Android chart view / graph view library, supporting line- bar- pie- radar- bubble- and candlestick charts as well as scaling, panning and animations.
#  -  30014 bumptech/glide           : An image loading and caching library for Android focused on smooth scrolling
#  -  24895 netty/netty              : Netty project - an event-driven asynchronous network application framework
#  -  22476 ctripcorp/apollo         : Apollo（阿波罗）是携程框架部门研发的分布式配置中心，能够集中化管理应用不同环境、不同集群的配置，配置修改后能够实时推送到应用端，并且具备规范的权限、流程治理等特性，适用于微服务配置管理场景。
#  -  22463 alibaba/fastjson         : A fast JSON parser/generator for Java.
#
#
# language: javascript
#  - stars  name                       description
#  - 173633 vuejs/vue                : 🖖 Vue.js is a progressive, incrementally-adoptable JavaScript framework for building UI on the web.
#  - 157151 facebook/react           : A declarative, efficient, and flexible JavaScript library for building user interfaces.
#  - 144624 twbs/bootstrap           : The most popular HTML, CSS, and JavaScript framework for developing responsive, mobile first projects on the web.
#  -  93988 d3/d3                    : Bring data to life with SVG, Canvas and HTML. :bar_chart::chart_with_upwards_trend::tada:
#  -  90624 facebook/react-native    : A framework for building native apps with React.
#  -  73625 nodejs/node              : Node.js JavaScript runtime :sparkles::turtle::rocket::sparkles:
#  -  63955 mrdoob/three.js          : JavaScript 3D library.
#  -  59500 angular/angular.js       : AngularJS - HTML enhanced for web apps!
#  -  55847 webpack/webpack          : A bundler for javascript and friends. Packs many modules into a few bundled assets. Code Splitting allows for loading parts of the application on demand. Through "loaders", modules can be CommonJs, AMD, ES6 modules, CSS, Images, JSON, Coffeescript, LESS, ... and your custom stuff.
#  -  54145 vercel/next.js           : The React Framework
#
#
# language: php
#  - stars  name                       description
#  -  61920 laravel/laravel          : A PHP framework for web artisans
#  -  24821 fzaninotto/Faker         : Faker is a PHP library that generates fake data for you
#  -  23952 composer/composer        : Dependency Manager for PHP
#  -  22329 laravel/framework        : None
#  -  20000 guzzle/guzzle            : Guzzle, an extensible PHP HTTP client
#  -  18076 bcit-ci/CodeIgniter      : Open Source PHP Framework (originally from EllisLab)
#  -  17928 Seldaek/monolog          : Sends your logs to files, sockets, inboxes, databases and various web services
#  -  16600 sebastianbergmann/phpunit: The PHP Unit Testing framework.
#  -  14729 briannesbitt/Carbon      : A simple PHP API extension for DateTime.
#  -  14385 WordPress/WordPress      : WordPress, Git-ified. Synced via SVN every 15 minutes, including branches and tags! This repository is just a mirror of the WordPress subversion repository. Please do not send pull requests. Submit patches to https://core.trac.wordpress.org/ instead.
#
#
# language: python
#  - stars  name                       description
#  -  52756 django/django            : The Web framework for perfectionists with deadlines.
#  -  52332 pallets/flask            : The Python micro framework for building web applications.
#  -  49949 keras-team/keras         : Deep Learning for humans
#  -  45056 ansible/ansible          : Ansible is a radically simple IT automation platform that makes your applications and systems easier to deploy and maintain. Automate everything from code deployment to network configuration to cloud management, in a language that approaches plain English, using SSH, with no agents to install on remote systems. https://docs.ansible.com.
#  -  43659 psf/requests             : A simple, yet elegant HTTP library.
#  -  38504 scrapy/scrapy            : Scrapy, a fast high-level web crawling & scraping framework for Python.
#  -  36144 home-assistant/core      : :house_with_garden: Open source home automation that puts local control and privacy first
#  -  35252 soimort/you-get          : :arrow_double_down: Dumb downloader that scrapes the web
#  -  34795 huggingface/transformers : 🤗Transformers: State-of-the-art Natural Language Processing for Pytorch and TensorFlow 2.0.
#  -  30376 XX-net/XX-Net            : A proxy tool to bypass GFW.
#
#
# language: ruby
#  - stars  name                       description
#  -  31669 discourse/discourse      : A platform for community discussion. Free, open, simple.
#  -  23272 Homebrew/brew            : 🍺 The missing package manager for macOS (or Linux)
#  -  21957 tootsuite/mastodon       : Your self-hosted, globally interconnected microblogging community
#  -  21152 heartcombo/devise        : Flexible authentication solution for Rails with Warden.
#  -  20719 hashicorp/vagrant        : Vagrant is a tool for building and distributing development environments.
#  -  12729 CocoaPods/CocoaPods      : The Cocoa Dependency Manager.
#  -  12512 diaspora/diaspora        : A privacy-aware, distributed, open source social network.
#  -  11077 sinatra/sinatra          : Classy web-development dressed in a DSL (official / canonical repo)
#  -  11066 rubocop-hq/rubocop       : A Ruby static code analyzer and formatter, based on the community Ruby style guide.
#  -  11024 gollum/gollum            : A simple, Git-powered wiki with a sweet API and local frontend.
#
#
# language: typescript
#  - stars  name                       description
#  -  64910 microsoft/TypeScript     : TypeScript is a superset of JavaScript that compiles to clean JavaScript output.
#  -  63926 ant-design/ant-design    : 🌈  A UI Design Language and React UI library
#  -  54456 reduxjs/redux            : Predictable state container for JavaScript apps
#  -  53940 storybookjs/storybook    : 📓 The UI component explorer. Develop, document, & test for React, Vue, Angular, Ember, Web Components, & more!
#  -  41882 ionic-team/ionic-framework: A powerful cross-platform UI toolkit for building native-quality iOS, Android, and Progressive Web Apps with HTML, CSS, and JavaScript.
#  -  37523 grafana/grafana          : The tool for beautiful monitoring and metric analytics & dashboards for Graphite, InfluxDB & Prometheus & More
#  -  34266 vercel/hyper             : A terminal built on web technologies
#  -  32708 facebook/jest            : Delightful JavaScript Testing.
#  -  30860 nestjs/nest              : A progressive Node.js framework for building efficient, scalable, and enterprise-grade server-side applications on top of TypeScript & JavaScript (ES6, ES7, ES8) 🚀
#  -  27952 vuetifyjs/vuetify        : 🐉 Material Component Framework for Vue

# %% [markdown]
# # Projects Summary

# %%
projects = projects.set_index('name')
projects.head(5)
# Out:
#                              lang   stars  commits  issues  tags  releases  \
# name
# vuejs/vue              javascript  173633     3127    9211   250       208
# facebook/react         javascript  157151    13618    9635   131        90
# twbs/bootstrap         javascript  144624    20098   19637    62        62
# d3/d3                  javascript   93988     4279    2056   267       159
# facebook/react-native  javascript   90624    21174   20262   348       148
#
#                                     last_commit  \
# name
# vuejs/vue             2020-10-05 14:57:24+00:00
# facebook/react        2020-10-09 13:29:30+00:00
# twbs/bootstrap        2020-10-07 14:03:53+00:00
# d3/d3                 2020-09-23 16:56:59+00:00
# facebook/react-native 2020-10-10 09:51:59+00:00
#
#                                                              description  \
# name
# vuejs/vue              🖖 Vue.js is a progressive, incrementally-adopt...
# facebook/react         A declarative, efficient, and flexible JavaScr...
# twbs/bootstrap         The most popular HTML, CSS, and JavaScript fra...
# d3/d3                  Bring data to life with SVG, Canvas and HTML. ...
# facebook/react-native   A framework for building native apps with React.
#
#                                                             url discarded  \
# name
# vuejs/vue                          https://github.com/vuejs/vue     False
# facebook/react                https://github.com/facebook/react     False
# twbs/bootstrap                https://github.com/twbs/bootstrap     False
# d3/d3                                  https://github.com/d3/d3     False
# facebook/react-native  https://github.com/facebook/react-native     False
#
#                        software  shared  few_releases  date_releases selected
# name
# vuejs/vue                  True   False         False          False     True
# facebook/react             True   False         False          False     True
# twbs/bootstrap             True   False         False          False     True
# d3/d3                      True   False         False          False     True
# facebook/react-native      True   False         False          False     True

# %%
projects.describe()
# Out:
#                stars     commits        issues         tags    releases
# count     100.000000    100.0000    100.000000   100.000000  100.000000
# mean    36133.630000  13047.5400   6735.850000   188.410000  107.050000
# std     28690.667876  12243.8419   6692.668913   199.726737  146.495518
# min      7388.000000   2030.0000      0.000000    12.000000    0.000000
# 25%     18357.250000   4260.7500   2211.500000    58.500000   23.000000
# 50%     30953.000000   8362.5000   4189.500000   130.500000   60.500000
# 75%     45140.750000  20134.0000   9035.000000   217.500000  145.000000
# max    173633.000000  55176.0000  28232.000000  1064.000000  829.000000

# %%
github_projects.to_pickle('github_projects.zip')
github_projects.to_csv('github_projects.csv')

# %%
projects.to_pickle('projects.zip')
projects.to_csv('projects.csv')
