# %% [markdown]
# Build project dataset
#  - 100 projects, 10 for each of the most popular 10 programming languages

# %%
import requests
import json
import datetime

import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Language Selection
#
# The language selection comes from the top 10 technologies from Stackoverflow survey on 2019

# %%
languages = [
    "javascript",
    "typescript",
    "java",
    "python",
    "php",
    "c++",
    "c#",
    "c",
    "ruby",
    "go"
]
projects_per_lang = 30

# %% [markdown]
# # GitHub Search
#
# To search GitHub, we need an API key, which is founded on the [Developer settings](https://github.com/settings/tokens).
# The following file is private, therefore not versioned.

# %%
token=!cat token
headers = {'Authorization': f'Bearer {token[0]}'}

# %% [markdown]
# Github GraphQL query to search repositories:

# %%
query = '''
    query($qnt: Int!, $query: String!) {
        search(
            query: $query,
            type: REPOSITORY,
            first: $qnt
        ) {
            repositoryCount
            nodes {
                ... on Repository {
                    name: nameWithOwner
                    description
                    url
                    stars: stargazers { totalCount }
                    issues{ totalCount }
                    releases { totalCount }
                    commits: object(expression: "HEAD") {
                        ... on Commit { 
                            last_commit: committedDate
                            history{ totalCount }
                        }
                    }
                    tags: refs(refPrefix: "refs/tags/") { totalCount }
                }
            }
        }
    }
'''

# %%
def process_language(lang, data):
    """ Create pandas dataframe from GitHub query response """
    project_lang_data = data['data']['search']['nodes']
    for project_data in project_lang_data:
        project_data['lang'] = lang
        
        # flatten results
        project_data['last_commit'] = project_data['commits']['last_commit']
        project_data['commits'] = project_data['commits']['history']
        for key in project_data.keys():
            if isinstance(project_data[key], dict) and 'totalCount' in project_data[key]:
                project_data[key] = project_data[key]['totalCount']
                
    df = pd.DataFrame.from_dict(data['data']['search']['nodes'])
    return df

# %%
print(f'Searching GitHub on {datetime.date.today()}')
github_projects = pd.DataFrame(columns=['name', 'lang', 'stars', 'commits', 'issues', 'tags', 'releases', 'last_commit', 'description', 'url'])

for lang in languages:
    print(f'Searching lang {lang}')
    response = requests.post('https://api.github.com/graphql', headers=headers, json={
        'query': query,
        'variables': { 'query': f'language:{lang} stars:>5000 sort:stars-desc', 'qnt': projects_per_lang }
    })
    if response.ok:
        data = json.loads(response.content)
        project_lang_df = process_language(lang, data)
        github_projects = pd.concat([github_projects, project_lang_df])
# Out:
# Searching GitHub on 2020-09-17
# Searching lang javascript
# Searching lang typescript
# Searching lang java
# Searching lang python
# Searching lang php
# Searching lang c++
# Searching lang c#
# Searching lang c
# Searching lang ruby
# Searching lang go

# %%
github_projects.last_commit = pd.to_datetime(github_projects.last_commit)
github_projects.stars = pd.to_numeric(github_projects.stars)
github_projects.commits = pd.to_numeric(github_projects.commits)
github_projects.issues = pd.to_numeric(github_projects.issues)
github_projects.releases = pd.to_numeric(github_projects.releases)
github_projects.tags = pd.to_numeric(github_projects.tags)

# %%
github_projects.head(10)
# Out:
#                              name        lang   stars  commits  issues  tags  \
# 0       freeCodeCamp/freeCodeCamp  javascript  314790    26196   14740     0
# 1                       vuejs/vue  javascript  172170     3115    9182   250
# 2                  facebook/react  javascript  156002    13577    9569   131
# 3                  twbs/bootstrap  javascript  144147    20025   19587    61
# 4               airbnb/javascript  javascript   99727     1834    1023    94
# 5                           d3/d3  javascript   93718     4277    2052   266
# 6           facebook/react-native  javascript   90144    20985   20126   347
# 7       facebook/create-react-app  javascript   82013     2605    6203   362
# 8  trekhleb/javascript-algorithms  javascript   81004      823     157     0
# 9                     axios/axios  javascript   77061      962    2561    45
#
#    releases               last_commit  \
# 0         0 2020-09-17 18:00:58+00:00
# 1       208 2020-09-16 01:33:45+00:00
# 2        90 2020-09-17 18:57:44+00:00
# 3        61 2020-09-17 17:01:04+00:00
# 4         0 2020-09-05 20:32:14+00:00
# 5       158 2020-09-02 17:08:35+00:00
# 6       147 2020-09-17 23:06:48+00:00
# 7        74 2020-09-16 23:18:51+00:00
# 8         0 2020-08-21 05:29:58+00:00
# 9        24 2020-09-12 04:29:35+00:00
#
#                                          description  \
# 0  freeCodeCamp.org's open source codebase and cu...
# 1  🖖 Vue.js is a progressive, incrementally-adopt...
# 2  A declarative, efficient, and flexible JavaScr...
# 3  The most popular HTML, CSS, and JavaScript fra...
# 4                             JavaScript Style Guide
# 5  Bring data to life with SVG, Canvas and HTML. ...
# 6   A framework for building native apps with React.
# 7    Set up a modern web app by running one command.
# 8  📝 Algorithms and data structures implemented i...
# 9  Promise based HTTP client for the browser and ...
#
#                                                  url
# 0       https://github.com/freeCodeCamp/freeCodeCamp
# 1                       https://github.com/vuejs/vue
# 2                  https://github.com/facebook/react
# 3                  https://github.com/twbs/bootstrap
# 4               https://github.com/airbnb/javascript
# 5                           https://github.com/d3/d3
# 6           https://github.com/facebook/react-native
# 7       https://github.com/facebook/create-react-app
# 8  https://github.com/trekhleb/javascript-algorithms
# 9                     https://github.com/axios/axios

# %%
github_projects.shape
# Out:
# (300, 10)

# %% [markdown]
# # Project filtering

# %%
def select_projects(projects):
    for lang, data in projects.groupby(["lang"]):
        data = data[data.discarded == False].nlargest(n=10, columns="stars")
        projects.loc[projects.name.isin(data.name), 'selected'] = True
    return projects[(projects.selected == True) & (projects.discarded == False)].copy()

# %%
def discard_projects(projects, discard, reason):
    projects.loc[projects.name.isin(discard.name), 'discarded'] = reason

# %%
def remove_inactive_projects(projects, age):
    """ Remove inactive projects """
    selected_projects = projects[projects.last_commit > age]
    discarded_projects = projects[~projects.name.isin(selected_projects.name)]
    return [selected_projects, discarded_projects, discarded_projects.shape[0]]

# %%
def remove_small_projects(projects, min_commits):
    """ Remove projects with less commits than min_commits"""
    selected_projects = projects[projects.commits >= min_commits]
    discarded_projects = projects[~projects.name.isin(selected_projects.name)]
    return [selected_projects, discarded_projects, discarded_projects.shape[0]]

# %%
def remove_big_projects(projects, max_percent_commits):
    """ Remove projects with more commits than a percentage of total """
    sum_commits = projects.commits.sum()
    projects['perc_commits'] = projects.commits / sum_commits

    selected_projects = projects[projects.perc_commits <= max_percent_commits]
    discarded_projects = projects[~projects.name.isin(selected_projects.name)]
    return [selected_projects, discarded_projects, discarded_projects.shape[0]]

# %%
def remove_non_software_projects(projects):
    # c#
    projects.loc[projects.name == 'dotnet/AspNetCore.Docs', 'software'] = False
    # go:
    projects.loc[projects.name == 'avelino/awesome-go', 'software'] = False
    projects.loc[projects.name == 'astaxie/build-web-application-with-golang', 'software'] = False

    # java:
    projects.loc[projects.name == 'CyC2018/CS-Notes', 'software'] = False
    projects.loc[projects.name == 'Snailclimb/JavaGuide', 'software'] = False
    projects.loc[projects.name == 'iluwatar/java-design-patterns', 'software'] = False
    projects.loc[projects.name == 'eugenp/tutorials', 'software'] = False
  
    
    # javascript:
    projects.loc[projects.name == 'freeCodeCamp/freeCodeCamp', 'software'] = False
    projects.loc[projects.name == '30-seconds/30-seconds-of-code', 'software'] = False

    # python:
    projects.loc[projects.name == 'public-apis/public-apis', 'software'] = False
    projects.loc[projects.name == 'tensorflow/models', 'software'] = False

    # ruby:
    projects.loc[projects.name == 'freeCodeCamp/devdocs', 'software'] = False
    
    # typescript
    projects.loc[projects.name == 'DefinitelyTyped/DefinitelyTyped', 'software'] = False
    
    
    """ Remove non software projects """
    selected_projects = projects[projects.software == True]
    discarded_projects = projects[~projects.name.isin(selected_projects.name)]
    return [selected_projects, discarded_projects, discarded_projects.shape[0]]

# %%
def remove_shared_repo_projects(projects):
    # c
    projects.loc[projects.name == 'curl/curl', 'shared'] = True
    projects.loc[projects.name == 'git/git', 'shared'] = True
    projects.loc[projects.name == 'libuv/libuv', 'shared'] = True
    projects.loc[projects.name == 'openssl/openssl', 'shared'] = True
    projects.loc[projects.name == 'redis/redis', 'shared'] = True
    projects.loc[projects.name == 'bilibili/ijkplayer', 'shared'] = True
    projects.loc[projects.name == 'facebook/zstd', 'shared'] = True

    # c#
    projects.loc[projects.name == 'dotnet-architecture/eShopOnContainers', 'shared'] = True
    projects.loc[projects.name == 'dotnet/aspnetcore', 'shared'] = True
    projects.loc[projects.name == 'dotnet/roslyn', 'shared'] = True
    projects.loc[projects.name == 'PowerShell/PowerShell', 'shared'] = True
    projects.loc[projects.name == 'AvaloniaUI/Avalonia', 'shared'] = True
    projects.loc[projects.name == 'OpenRA/OpenRA', 'shared'] = True
    projects.loc[projects.name == 'Unity-Technologies/ml-agents', 'shared'] = True

    # c++
    projects.loc[projects.name == 'BVLC/caffe', 'shared'] = True
    projects.loc[projects.name == 'grpc/grpc', 'shared'] = True
    projects.loc[projects.name == 'rethinkdb/rethinkdb', 'shared'] = True

    # go
    projects.loc[projects.name == 'ethereum/go-ethereum', 'shared'] = True
    projects.loc[projects.name == 'moby/moby', 'shared'] = True
    projects.loc[projects.name == 'golang/go', 'shared'] = True
    projects.loc[projects.name == 'pingcap/tidb', 'shared'] = True
    projects.loc[projects.name == 'syncthing/syncthing', 'shared'] = True

    # java
    projects.loc[projects.name == 'google/guava', 'shared'] = True
    projects.loc[projects.name == 'ReactiveX/RxJava', 'shared'] = True
    projects.loc[projects.name == 'zxing/zxing', 'shared'] = True

    # javascript
    projects.loc[projects.name == 'facebook/create-react-app', 'shared'] = True
    projects.loc[projects.name == 'mui-org/material-ui', 'shared'] = True

    # php
    projects.loc[projects.name == 'symfony/symfony', 'shared'] = True

    # python
    projects.loc[projects.name == 'scikit-learn/scikit-learn', 'shared'] = True

    # ruby
    projects.loc[projects.name == 'fastlane/fastlane', 'shared'] = True
    projects.loc[projects.name == 'rails/rails', 'shared'] = True
    projects.loc[projects.name == 'rapid7/metasploit-framework', 'shared'] = True
    projects.loc[projects.name == 'jekyll/jekyll', 'shared'] = True
    projects.loc[projects.name == 'ruby/ruby', 'shared'] = True
    projects.loc[projects.name == 'elastic/logstash', 'shared'] = True
    
    # typescript
    projects.loc[projects.name == 'angular/angular', 'shared'] = True
    projects.loc[projects.name == 'denoland/deno', 'shared'] = True
    projects.loc[projects.name == 'microsoft/vscode', 'shared'] = True
    projects.loc[projects.name == 'pixijs/pixi.js', 'shared'] = True
    
    """ Remove shared repo projects """
    selected_projects = projects[projects.shared == False]
    discarded_projects = projects[~projects.name.isin(selected_projects.name)]
    return [selected_projects, discarded_projects, discarded_projects.shape[0]]

# %%
def remove_few_releasesprojects(projects):
    """ Remove projects with fewer releases than 10 """

    # go
    projects.loc[projects.name == 'minio/minio', 'few_releases'] = True
    
    selected_projects = projects[projects.few_releases == False]
    discarded_projects = projects[~projects.name.isin(selected_projects.name)]
    return [selected_projects, discarded_projects, discarded_projects.shape[0]]

# %% [markdown]
# ## Discard projects
#
#  - Inactive
#  - Too small
#  - Too big
#  - Non software
#  - Shared Repo

# %%
today = pd.to_datetime('now').tz_localize('UTC').normalize()
delta = pd.to_timedelta(30*6, unit='d')

age = today - delta
min_commits = 2000
max_percent_commits = 0.05

# %%
def scan(all_projects, fnc, label, **params):
    converged = False
    cnt_discarded = 0
    while not converged:
        projects = select_projects(all_projects)
        params['projects'] = projects
        [s,d,n] = fnc(**params)
        discard_projects(all_projects, d, label)
        converged = (n == 0)
        cnt_discarded += n
        if n:
            print(f' - discarded {n} - {label}')
    return cnt_discarded

# %%
all_projects = github_projects.copy()
all_projects["discarded"] = False
all_projects["software"] = True
all_projects["shared"] = False
all_projects["few_releases"] = False
projects = select_projects(all_projects)
projects.boxplot('commits')
# Out:
# <AxesSubplot:>

# %%
all_projects = github_projects.copy()
all_projects["discarded"] = False
all_projects["software"] = True
all_projects["shared"] = False
all_projects["few_releases"] = False

round = 1
fully_converged = False
while not fully_converged:
    cnt_discarded = 0
    
    print(f'Round {round}')
    cnt_discarded += scan(all_projects, remove_inactive_projects, 'inactivity', **{ 'age': age })
    cnt_discarded += scan(all_projects, remove_small_projects, 'small', **{ 'min_commits': min_commits })
    cnt_discarded += scan(all_projects, remove_non_software_projects, 'non_software')
    cnt_discarded += scan(all_projects, remove_big_projects, 'big', **{ 'max_percent_commits': max_percent_commits })
    cnt_discarded += scan(all_projects, remove_shared_repo_projects, 'shared')
    cnt_discarded += scan(all_projects, remove_few_releasesprojects, 'few_releases')
    
    
    projects = select_projects(all_projects)
    projects.boxplot('commits')
    
    fully_converged = (cnt_discarded == 0)
    print(f'Discarded {cnt_discarded} projects\n')
    round += 1
# Out:
# Round 1
#  - discarded 1 - inactivity
#  - discarded 24 - small
#  - discarded 9 - small
#  - discarded 10 - non_software
#  - discarded 1 - big
#  - discarded 2 - big
#  - discarded 2 - big
#  - discarded 2 - big
#  - discarded 23 - shared
#  - discarded 6 - shared
#  - discarded 2 - shared
# Discarded 82 projects
#
# Round 2
#  - discarded 6 - inactivity
#  - discarded 1 - inactivity
#  - discarded 13 - small
#  - discarded 4 - small
#  - discarded 3 - small
#  - discarded 1 - small
#  - discarded 1 - small
#  - discarded 1 - small
#  - discarded 2 - non_software
#  - discarded 2 - big
#  - discarded 6 - shared
#  - discarded 1 - shared
#  - discarded 1 - few_releases
# Discarded 42 projects
#
# Round 3
#  - discarded 1 - small
#  - discarded 1 - non_software
# Discarded 2 projects
#
# Round 4
# Discarded 0 projects

# %%
all_projects.loc[all_projects.discarded != False, ['name', 'discarded', 'commits', 'tags', 'last_commit']].sort_values(['discarded','commits'], ascending=[True,False])
# Out:
#                                                  name     discarded  commits  \
# 0                                      torvalds/linux           big   950368
# 19                                          mono/mono           big   122147
# 5                                         php/php-src           big   120746
# 13                             Homebrew/homebrew-cask           big   116305
# 3                                         apple/swift           big   111769
# 8                                   gitlabhq/gitlabhq           big   104472
# 9                                       FFmpeg/FFmpeg           big    99224
# 0                               tensorflow/tensorflow           big    95682
# 1                               kubernetes/kubernetes           big    94239
# 11          julycoding/The-Art-Of-Programming-By-July    inactivity     3633
# 22                                     vurtun/nuklear    inactivity     1712
# 17                                twbs/bootstrap-sass    inactivity     1032
# 12  SamyPesse/How-to-Make-a-Computer-Operating-System    inactivity      243
# 17                          ageitgey/face_recognition    inactivity      194
# 15                             cfenollosa/os-tutorial    inactivity      147
# 7                                              wg/wrk    inactivity       76
# 19                        Awesome-HarmonyOS/HarmonyOS    inactivity       74
# 15                    DefinitelyTyped/DefinitelyTyped  non_software    71302
# 0                           freeCodeCamp/freeCodeCamp  non_software    26196
# 29                                   eugenp/tutorials  non_software    20395
# 27                             dotnet/AspNetCore.Docs  non_software    11038
# 5                                   tensorflow/models  non_software     5861
# 7           astaxie/build-web-application-with-golang  non_software     5111
# 13                      30-seconds/30-seconds-of-code  non_software     5003
# 0                                    CyC2018/CS-Notes  non_software     3641
# 3                                  avelino/awesome-go  non_software     3526
# 6                                freeCodeCamp/devdocs  non_software     3362
# 2                       iluwatar/java-design-patterns  non_software     2914
# 1                                Snailclimb/JavaGuide  non_software     2587
# 1                             public-apis/public-apis  non_software     2170
# 0                                         rails/rails        shared    77715
# 0                                    microsoft/vscode        shared    70850
# 10                                      dotnet/roslyn        shared    64228
# 15                                          ruby/ruby        shared    63058
# 4                                             git/git        shared    60430
# 10                        rapid7/metasploit-framework        shared    58057
# 4                                     symfony/symfony        shared    50861
# 14                                          grpc/grpc        shared    46783
# 3                                   dotnet/aspnetcore        shared    44760
# 0                                           golang/go        shared    44755
# 2                                           moby/moby        shared    38939
# 15                                rethinkdb/rethinkdb        shared    33430
# 22                                      OpenRA/OpenRA        shared    27492
# 20                                    openssl/openssl        shared    27109
# 16                                          curl/curl        shared    26232
# 14                          scikit-learn/scikit-learn        shared    26117
# 2                                     angular/angular        shared    18794
# 3                                   fastlane/fastlane        shared    15595
# 17                                AvaloniaUI/Avalonia        shared    13861
# 14                                mui-org/material-ui        shared    12609
# 16                               ethereum/go-ethereum        shared    12003
# 18                                       pingcap/tidb        shared    11776
# 1                                       jekyll/jekyll        shared    11090
# 2                                         redis/redis        shared     9650
# 20                                   elastic/logstash        shared     9631
# 2                               PowerShell/PowerShell        shared     8300
# 27                                      facebook/zstd        shared     8015
# 8                                    ReactiveX/RxJava        shared     5780
# 13                                     pixijs/pixi.js        shared     5416
# 11                                       google/guava        shared     5333
# 18                                        libuv/libuv        shared     4710
# 1                                       denoland/deno        shared     4306
# 12                                         BVLC/caffe        shared     4156
# 6               dotnet-architecture/eShopOnContainers        shared     3563
# 20                                        zxing/zxing        shared     3547
# 7                           facebook/create-react-app        shared     2605
# 6                                  bilibili/ijkplayer        shared     2599
# 18                       Unity-Technologies/ml-agents        shared     2540
# 13                                    ariya/phantomjs         small     1958
# 3                                 puppeteer/puppeteer         small     1952
# 21                                       nothings/stb         small     1940
# 13                                    square/retrofit         small     1857
# 4                                   airbnb/javascript         small     1834
# 13                                       junegunn/fzf         small     1822
# 24                            JamesNK/Newtonsoft.Json         small     1821
# 3                                TheAlgorithms/Python         small     1726
# 14                        kilimchoi/engineering-blogs         small     1702
# 21                              capistrano/capistrano         small     1666
# 12                                PHPMailer/PHPMailer         small     1627
# 2                                  microsoft/terminal         small     1626
# 2                                vinta/awesome-python         small     1572
# 6                                        nvbn/thefuck         small     1567
# 11              josephmisiti/awesome-machine-learning         small     1444
# 0                     shadowsocks/shadowsocks-windows         small     1434
# 12                               StackExchange/Dapper         small     1415
# 5                                       gin-gonic/gin         small     1401
# 27                                        skylot/jadx         small     1326
# 17                                        stedolan/jq         small     1323
# 28                                     alibaba/arthas         small     1301
# 19                             Blankj/AndroidUtilCode         small     1297
# 10                                    cdr/code-server         small     1269
# 10                                      httpie/httpie         small     1258
# 1                          blueimp/jQuery-File-Upload         small     1249
# 11                     thangchung/awesome-dotnet-core         small     1230
# 16                                 TheAlgorithms/Java         small     1217
# 18                              airbnb/lottie-android         small     1212
# 8                           domnikl/DesignPatternsPHP         small     1085
# 22                            JakeWharton/butterknife         small     1016
# 2                             danielmiessler/SecLists         small      987
# 3                                   Genymobile/scrcpy         small      974
# 25                                    App-vNext/Polly         small      966
# 9                                         axios/axios         small      962
# 15                                  caddyserver/caddy         small      849
# 6                                        fatedier/frp         small      847
# 8                      trekhleb/javascript-algorithms         small      823
# 13                           NickeManarin/ScreenToGif         small      733
# 23                              crossoverJie/JCSprout         small      704
# 1                                  CodeHubApp/CodeHub         small      593
# 25                          robertdavidgraham/masscan         small      576
# 9                                     macrozheng/mall         small      560
# 5                        bayandin/awesome-awesomeness         small      527
# 7                                 doocs/advanced-java         small      505
# 21             GoogleCloudPlatform/microservices-demo         small      497
# 21                      proxyee-down-org/proxyee-down         small      474
# 6                                   kdn251/interviews         small      445
# 14                                   pjreddie/darknet         small      440
# 0                    donnemartin/system-design-primer         small      315
# 8                                        2dust/v2rayN         small      278
# 16              minimaxir/big-list-of-naughty-strings         small      271
# 3                        MisterBooo/LeetCodeAnimation         small      241
# 26                     ityouknow/spring-boot-examples         small      165
# 17                                 FiloSottile/mkcert         small      137
# 7                          mxgmn/WaveFunctionCollapse         small      114
# 11                           FortAwesome/Font-Awesome         small       70
# 24              kon9chunkit/GitHub-Chinese-Top-Charts         small       58
#
#     tags               last_commit
# 0    666 2020-09-17 18:30:36+00:00
# 19   464 2020-09-16 15:24:16+00:00
# 5   1071 2020-09-17 21:47:36+00:00
# 13   114 2020-09-18 00:06:12+00:00
# 3   1692 2020-09-17 20:59:52+00:00
# 8   1243 2020-09-18 00:09:39+00:00
# 9    335 2020-09-17 21:47:10+00:00
# 0    116 2020-09-18 00:22:50+00:00
# 1    706 2020-09-18 00:28:45+00:00
# 11     0 2018-06-20 02:30:28+00:00
# 22     0 2019-12-01 23:01:55+00:00
# 17    61 2019-02-13 18:58:58+00:00
# 12    12 2015-10-29 19:04:29+00:00
# 17     2 2020-02-20 14:20:21+00:00
# 15     0 2018-11-03 00:25:59+00:00
# 7     20 2019-04-18 01:51:32+00:00
# 19     0 2019-08-25 16:38:35+00:00
# 15     1 2020-09-17 23:17:22+00:00
# 0      0 2020-09-17 18:00:58+00:00
# 29     0 2020-09-17 21:22:49+00:00
# 27    36 2020-09-17 13:16:06+00:00
# 5     15 2020-09-17 22:43:50+00:00
# 7      0 2020-05-29 02:12:00+00:00
# 13     6 2020-09-16 12:58:28+00:00
# 0      0 2020-05-26 17:54:11+00:00
# 3      0 2020-09-17 18:12:52+00:00
# 6      0 2020-03-22 14:21:16+00:00
# 2     17 2020-09-13 15:35:23+00:00
# 1      0 2020-09-17 05:39:26+00:00
# 1      0 2020-07-22 08:14:20+00:00
# 0    428 2020-09-17 22:45:29+00:00
# 0    160 2020-09-18 00:13:29+00:00
# 10   141 2020-09-18 00:10:12+00:00
# 15  1125 2020-09-17 15:30:47+00:00
# 4    776 2020-09-09 20:53:09+00:00
# 10   693 2020-09-17 21:18:07+00:00
# 4    510 2020-09-17 09:07:30+00:00
# 14   196 2020-09-18 00:25:06+00:00
# 3    125 2020-09-17 23:49:38+00:00
# 0    293 2020-09-17 23:22:34+00:00
# 2    327 2020-09-17 18:42:49+00:00
# 15   139 2020-07-14 08:53:39+00:00
# 22   374 2020-09-15 08:16:50+00:00
# 20   315 2020-09-18 00:31:48+00:00
# 16   198 2020-09-17 14:28:18+00:00
# 14   112 2020-09-17 22:22:09+00:00
# 2    571 2020-09-17 16:32:19+00:00
# 3   1135 2020-09-16 16:28:51+00:00
# 17    32 2020-09-17 20:37:10+00:00
# 14   283 2020-09-17 21:07:47+00:00
# 16   176 2020-09-17 08:23:56+00:00
# 18   117 2020-09-17 12:08:34+00:00
# 1    144 2020-09-17 15:00:26+00:00
# 2    240 2020-09-17 15:20:10+00:00
# 20   231 2020-09-17 09:39:10+00:00
# 2     92 2020-09-14 18:10:12+00:00
# 27    59 2020-09-14 21:56:30+00:00
# 8    240 2020-09-12 10:13:57+00:00
# 13   124 2020-09-16 23:22:11+00:00
# 11    90 2020-09-17 15:21:07+00:00
# 18   231 2020-09-03 19:38:02+00:00
# 1    133 2020-09-17 18:38:57+00:00
# 12    14 2020-02-13 07:20:36+00:00
# 6     15 2020-09-15 11:04:07+00:00
# 20    27 2020-09-14 15:03:09+00:00
# 7    362 2020-09-16 23:18:51+00:00
# 6     78 2020-09-15 07:15:25+00:00
# 18    74 2020-09-17 16:03:54+00:00
# 13    23 2020-07-13 15:08:08+00:00
# 3     52 2020-09-14 11:42:32+00:00
# 21     0 2020-07-13 11:46:06+00:00
# 13    54 2020-09-15 15:56:31+00:00
# 4     94 2020-09-05 20:32:14+00:00
# 13    90 2020-09-12 12:14:32+00:00
# 24    62 2020-03-25 20:35:34+00:00
# 3      0 2020-09-17 09:37:53+00:00
# 14     0 2020-04-28 14:57:45+00:00
# 21   101 2020-08-26 15:57:51+00:00
# 12    61 2020-09-07 15:04:19+00:00
# 2     56 2020-09-18 00:13:11+00:00
# 2      0 2020-09-12 07:33:13+00:00
# 6     81 2020-07-16 21:56:58+00:00
# 11     0 2020-09-11 16:00:31+00:00
# 0     55 2020-09-16 13:19:46+00:00
# 12    61 2020-08-19 01:54:34+00:00
# 5     22 2020-09-14 02:40:20+00:00
# 27    14 2020-09-17 18:03:17+00:00
# 17    11 2020-06-08 16:35:13+00:00
# 28    30 2020-09-14 09:32:04+00:00
# 19   115 2020-09-08 07:52:50+00:00
# 10    48 2020-08-29 21:23:20+00:00
# 10    37 2020-08-19 08:39:13+00:00
# 1    134 2020-09-18 00:19:54+00:00
# 11     0 2020-08-28 07:37:36+00:00
# 16     0 2020-09-17 07:39:38+00:00
# 18    84 2020-09-12 22:53:27+00:00
# 8      0 2020-09-02 20:23:35+00:00
# 22    48 2020-09-04 02:00:12+00:00
# 2     11 2020-09-17 13:16:24+00:00
# 3     20 2020-09-17 11:09:43+00:00
# 25    29 2020-05-02 11:42:54+00:00
# 9     45 2020-09-12 04:29:35+00:00
# 15    85 2020-09-17 23:23:58+00:00
# 6     54 2020-09-07 07:45:44+00:00
# 8      0 2020-08-21 05:29:58+00:00
# 13    57 2020-09-14 12:31:25+00:00
# 23     1 2020-05-18 13:54:42+00:00
# 1     39 2020-05-06 02:29:18+00:00
# 25     8 2019-09-22 17:53:17+00:00
# 9      2 2020-09-17 12:43:24+00:00
# 5      0 2020-09-06 08:47:27+00:00
# 7      0 2020-09-17 01:36:14+00:00
# 21     7 2020-09-10 23:00:18+00:00
# 21    50 2020-08-11 09:34:24+00:00
# 6      0 2020-06-06 02:37:07+00:00
# 14     0 2020-08-16 16:17:19+00:00
# 0      0 2020-08-02 18:13:17+00:00
# 8     50 2020-09-01 00:38:06+00:00
# 16     0 2020-05-26 02:39:03+00:00
# 3      0 2020-08-24 01:27:49+00:00
# 26     0 2020-04-18 05:17:32+00:00
# 17    11 2020-03-22 02:12:54+00:00
# 7      0 2020-07-18 10:50:09+00:00
# 11    62 2020-07-15 21:34:39+00:00
# 24     0 2020-09-10 03:47:42+00:00

# %%
all_projects[all_projects.discarded != False].groupby(['discarded']).count().name.sum()
# Out:
# 125

# %% [markdown]
# ## Project list for manual inspection

# %%
for lang, data in projects.groupby(["lang"]):
    print(f'language: {lang}')
    #for i, project in data.iterrows():
    print(f" - {'stars':6} {'name':25}  {'description'}")
    for project in data.itertuples():
        print(f" - {project.stars:6} {project.name:25}: {project.description}")
    print("\n")
# Out:
# language: c
#  - stars  name                       description
#  -  48417 netdata/netdata          : Real-time performance monitoring, done right! https://www.netdata.cloud
#  -  21777 obsproject/obs-studio    : OBS Studio - Free and open source software for live streaming and screen recording
#  -  20878 ggreer/the_silver_searcher: A code-searching tool similar to ack, but faster.
#  -  18888 tmux/tmux                : tmux source code
#  -  13243 taosdata/TDengine        : An open-source big data platform designed and optimized for the Internet of Things (IoT).
#  -  13126 radareorg/radare2        : UNIX-like reverse engineering framework and command-line toolset
#  -  12990 mpv-player/mpv           : 🎥 Command line video player
#  -  12641 nginx/nginx              : An official read-only mirror of http://hg.nginx.org/nginx/ which is updated hourly. Pull requests on GitHub cannot be accepted and will be automatically closed. The proper way to submit changes to nginx is via the nginx development mailing list, see http://nginx.org/en/docs/contributing_changes.html
#  -  12390 coolsnowwolf/lede        : Lean's OpenWrt source
#
#
# language: c#
#  - stars  name                       description
#  -  18269 Wox-launcher/Wox         : Launcher for Windows, an alternative to Alfred and Launchy.
#  -  15757 0xd4d/dnSpy              : .NET debugger and assembly editor
#  -  13799 ShareX/ShareX            : ShareX is a free and open source program that lets you capture or record any area of your screen and share it with a single press of a key. It also allows uploading images, text or other types of files to many supported destinations you can choose from.
#  -  11056 icsharpcode/ILSpy        : .NET Decompiler with support for PDB generation, ReadyToRun, Metadata (&more) - cross-platform!
#  -   9605 MaterialDesignInXAML/MaterialDesignInXamlToolkit: Google's Material Design in XAML & WPF, for C# & VB.Net.
#  -   9464 dotnet/efcore            : EF Core is a modern object-database mapper for .NET. It supports LINQ queries, change tracking, updates, and schema migrations.
#  -   8807 aspnetboilerplate/aspnetboilerplate: ASP.NET Boilerplate - Web Application Framework
#  -   8114 SignalR/SignalR          : Incredibly simple real-time web for .NET
#  -   7996 jellyfin/jellyfin        : The Free Software Media System
#  -   7496 AutoMapper/AutoMapper    : A convention-based object-object mapper in .NET.
#
#
# language: c++
#  - stars  name                       description
#  -  85821 electron/electron        : :electron: Build cross-platform desktop apps with JavaScript, HTML, and CSS
#  -  48336 opencv/opencv            : Open Source Computer Vision Library
#  -  45144 bitcoin/bitcoin          : Bitcoin Core integration/staging tree
#  -  43757 protocolbuffers/protobuf : Protocol Buffers - Google's data interchange format
#  -  41864 pytorch/pytorch          : Tensors and Dynamic neural networks in Python with strong GPU acceleration
#  -  37134 microsoft/PowerToys      : Windows system utilities to maximize productivity
#  -  36376 tesseract-ocr/tesseract  : Tesseract Open Source OCR Engine (main repository)
#  -  35560 x64dbg/x64dbg            : An open-source x64/x32 debugger for windows.
#  -  33286 godotengine/godot        : Godot Engine – Multi-platform 2D and 3D game engine
#  -  23550 ocornut/imgui            : Dear ImGui: Bloat-free Graphical User interface for C++ with minimal dependencies
#
#
# language: go
#  - stars  name                       description
#  -  46672 gohugoio/hugo            : The world’s fastest framework for building websites.
#  -  35406 gogs/gogs                : Gogs is a painless self-hosted Git service
#  -  34987 v2ray/v2ray-core         : A platform for building proxies to bypass network restrictions.
#  -  33000 syncthing/syncthing      : Open Source Continuous File Synchronization
#  -  32923 prometheus/prometheus    : The Prometheus monitoring system and time series database.
#  -  32800 etcd-io/etcd             : Distributed reliable key-value store for the most critical data of a distributed system
#  -  30763 traefik/traefik          : The Cloud Native Edge Router
#  -  24881 astaxie/beego            : beego is an open-source, high-performance web framework for the Go programming language.
#  -  24396 istio/istio              : Connect, secure, control, and observe services.
#  -  23771 hashicorp/terraform      : Terraform enables you to safely and predictably create, change, and improve infrastructure. It is an open source tool that codifies APIs into declarative configuration files that can be shared amongst team members, treated as code, edited, reviewed, and versioned.
#
#
# language: java
#  - stars  name                       description
#  -  51167 elastic/elasticsearch    : Open Source, Distributed, RESTful Search Engine
#  -  50554 spring-projects/spring-boot: Spring Boot
#  -  39292 spring-projects/spring-framework: Spring Framework
#  -  38244 square/okhttp            : Square’s meticulous HTTP client for Java and Kotlin.
#  -  33552 apache/dubbo             : Apache Dubbo is a high-performance, java based, open source RPC framework.
#  -  31708 PhilJay/MPAndroidChart   : A powerful 🚀 Android chart view / graph view library, supporting line- bar- pie- radar- bubble- and candlestick charts as well as scaling, panning and animations.
#  -  29883 bumptech/glide           : An image loading and caching library for Android focused on smooth scrolling
#  -  24735 netty/netty              : Netty project - an event-driven asynchronous network application framework
#
#
# language: javascript
#  - stars  name                       description
#  - 172170 vuejs/vue                : 🖖 Vue.js is a progressive, incrementally-adoptable JavaScript framework for building UI on the web.
#  - 156002 facebook/react           : A declarative, efficient, and flexible JavaScript library for building user interfaces.
#  - 144147 twbs/bootstrap           : The most popular HTML, CSS, and JavaScript framework for developing responsive, mobile first projects on the web.
#  -  93718 d3/d3                    : Bring data to life with SVG, Canvas and HTML. :bar_chart::chart_with_upwards_trend::tada:
#  -  90144 facebook/react-native    : A framework for building native apps with React.
#  -  73030 nodejs/node              : Node.js JavaScript runtime :sparkles::turtle::rocket::sparkles:
#  -  63469 mrdoob/three.js          : JavaScript 3D library.
#  -  59509 angular/angular.js       : AngularJS - HTML enhanced for web apps!
#  -  55617 webpack/webpack          : A bundler for javascript and friends. Packs many modules into a few bundled assets. Code Splitting allows for loading parts of the application on demand. Through "loaders", modules can be CommonJs, AMD, ES6 modules, CSS, Images, JSON, Coffeescript, LESS, ... and your custom stuff.
#  -  53977 jquery/jquery            : jQuery JavaScript Library
#
#
# language: php
#  - stars  name                       description
#  -  61495 laravel/laravel          : A PHP framework for web artisans
#  -  24687 fzaninotto/Faker         : Faker is a PHP library that generates fake data for you
#  -  23795 composer/composer        : Dependency Manager for PHP
#  -  22084 laravel/framework        : None
#  -  19881 guzzle/guzzle            : Guzzle, an extensible PHP HTTP client
#  -  18074 bcit-ci/CodeIgniter      : Open Source PHP Framework (originally from EllisLab)
#  -  17856 Seldaek/monolog          : Sends your logs to files, sockets, inboxes, databases and various web services
#  -  16539 sebastianbergmann/phpunit: The PHP Unit Testing framework.
#  -  14679 briannesbitt/Carbon      : A simple PHP API extension for DateTime.
#  -  14286 WordPress/WordPress      : WordPress, Git-ified. Synced via SVN every 15 minutes, including branches and tags! This repository is just a mirror of the WordPress subversion repository. Please do not send pull requests. Submit patches to https://core.trac.wordpress.org/ instead.
#
#
# language: python
#  - stars  name                       description
#  -  70846 ytdl-org/youtube-dl      : Command-line program to download videos from YouTube.com and other video sites
#  -  52038 pallets/flask            : The Python micro framework for building web applications.
#  -  52009 django/django            : The Web framework for perfectionists with deadlines.
#  -  49758 keras-team/keras         : Deep Learning for humans
#  -  44775 ansible/ansible          : Ansible is a radically simple IT automation platform that makes your applications and systems easier to deploy and maintain. Automate everything from code deployment to network configuration to cloud management, in a language that approaches plain English, using SSH, with no agents to install on remote systems. https://docs.ansible.com.
#  -  43519 psf/requests             : A simple, yet elegant HTTP library.
#  -  38284 scrapy/scrapy            : Scrapy, a fast high-level web crawling & scraping framework for Python.
#  -  35491 home-assistant/core      : :house_with_garden: Open source home automation that puts local control and privacy first
#  -  34966 soimort/you-get          : :arrow_double_down: Dumb downloader that scrapes the web
#  -  33796 huggingface/transformers : 🤗Transformers: State-of-the-art Natural Language Processing for Pytorch and TensorFlow 2.0.
#
#
# language: ruby
#  - stars  name                       description
#  -  31514 discourse/discourse      : A platform for community discussion. Free, open, simple.
#  -  29449 huginn/huginn            : Create agents that monitor and act on your behalf.  Your agents are standing by!
#  -  23015 Homebrew/brew            : 🍺 The missing package manager for macOS (or Linux)
#  -  21831 tootsuite/mastodon       : Your self-hosted, globally interconnected microblogging community
#  -  21099 heartcombo/devise        : Flexible authentication solution for Rails with Warden.
#  -  20616 hashicorp/vagrant        : Vagrant is a tool for building and distributing development environments.
#  -  14894 forem/forem              : For empowering community 🌱
#  -  12686 CocoaPods/CocoaPods      : The Cocoa Dependency Manager.
#  -  12502 diaspora/diaspora        : A privacy-aware, distributed, open source social network.
#  -  11056 sinatra/sinatra          : Classy web-development dressed in a DSL (official / canonical repo)
#
#
# language: typescript
#  - stars  name                       description
#  -  64373 microsoft/TypeScript     : TypeScript is a superset of JavaScript that compiles to clean JavaScript output.
#  -  63409 ant-design/ant-design    : 🌈  A UI Design Language and React UI library
#  -  54309 reduxjs/redux            : Predictable state container for JavaScript apps
#  -  53488 storybookjs/storybook    : 📓 The UI component explorer. Develop, document, & test for React, Vue, Angular, Ember, Web Components, & more!
#  -  41759 ionic-team/ionic-framework: A powerful cross-platform UI toolkit for building native-quality iOS, Android, and Progressive Web Apps with HTML, CSS, and JavaScript.
#  -  37204 grafana/grafana          : The tool for beautiful monitoring and metric analytics & dashboards for Graphite, InfluxDB & Prometheus & More
#  -  34122 vercel/hyper             : A terminal built on web technologies
#  -  32462 facebook/jest            : Delightful JavaScript Testing.
#  -  30236 nestjs/nest              : A progressive Node.js framework for building efficient, scalable, and enterprise-grade server-side applications on top of TypeScript & JavaScript (ES6, ES7, ES8) 🚀
#  -  27591 vuetifyjs/vuetify        : 🐉 Material Component Framework for Vue

# %% [markdown]
# # Projects Summary

# %%
projects.describe()
# Out:
#                stars       commits        issues         tags    releases
# count      97.000000     97.000000     97.000000    97.000000   97.000000
# mean    37345.680412  13310.649485   6816.134021   188.443299   97.845361
# std     28690.895862  12231.206664   6847.125004   208.601343  128.462165
# min      7496.000000   2000.000000      0.000000     0.000000    0.000000
# 25%     18888.000000   4396.000000   2052.000000    49.000000   11.000000
# 50%     32800.000000   8169.000000   4203.000000   130.000000   46.000000
# 75%     46672.000000  20242.000000   9034.000000   219.000000  147.000000
# max    172170.000000  54775.000000  28078.000000  1076.000000  644.000000

# %%
fig, ax = plt.subplots(1, 5, figsize=(10, 5))

projects.boxplot('stars', ax=ax[0])
projects.boxplot('commits', ax=ax[1])
projects.boxplot('issues', ax=ax[2])
projects.boxplot('tags', ax=ax[3])
projects.boxplot('releases', ax=ax[4])

plt.tight_layout()

# %%
projects_bylang = projects.groupby('lang')

# %%
summary = pd.DataFrame()
summary['stars_mean'] = projects_bylang.stars.mean().round(1)
summary['stars_std'] = projects_bylang.stars.std().round(1)
summary['stars_sum'] = projects_bylang.stars.sum()
summary['commits_min'] = projects_bylang.commits.min().round(1)
summary['commits_max'] = projects_bylang.commits.max().round(1)
summary['commits_std'] = projects_bylang.commits.std().round(1)
summary['commits_mean'] = projects_bylang.commits.mean().round(1)
summary['tags_min'] = projects_bylang.commits.min().round(1)
summary['tags_max'] = projects_bylang.commits.max().round(1)
summary['tags_mean'] = projects_bylang.commits.mean().round(1)

summary
# Out:
#             stars_mean  stars_std  stars_sum  commits_min  commits_max  \
# c              19372.2    11528.6     174350         2055        48744
# c#             11036.3     3682.4     110363         2179        18133
# c++            43082.8    16582.5     430828         3911        30399
# go             31959.9     6798.8     319599         3650        26731
# java           37391.9     9494.1     299135         2064        54775
# javascript     96178.3    44812.7     961783         3115        35028
# php            23337.6    13874.1     233376         2391        42368
# python         45548.2    11305.3     455482         2309        50663
# ruby           19866.2     7082.7     198662         3324        39319
# typescript     43895.3    13858.7     438953         2000        31048
#
#             commits_std  commits_mean  tags_min  tags_max  tags_mean
# c               14723.3       13581.1      2055     48744    13581.1
# c#               4745.2        6493.0      2179     18133     6493.0
# c++             12064.7       16588.1      3911     30399    16588.1
# go               7362.3        9480.0      3650     26731     9480.0
# java            18410.1       16095.2      2064     54775    16095.2
# javascript      11112.8       15617.7      3115     35028    15617.7
# php             13369.0       12357.2      2391     42368    12357.2
# python          15886.0       15811.6      2309     50663    15811.6
# ruby            11437.7       13312.4      3324     39319    13312.4
# typescript      11394.5       14354.1      2000     31048    14354.1

# %%
github_projects.to_pickle('github_projects.zip')
github_projects.to_csv('github_projects.csv')

# %%
projects.to_pickle('projects.zip')
projects.to_csv('projects.csv')
