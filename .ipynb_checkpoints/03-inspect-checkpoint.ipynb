# %%
import pandas as pd
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from scipy import stats
import re
pd.options.display.max_rows = 500

# %%
releases = pd.read_pickle('releases.zip')

# %%
releases[releases.range_recall < 1][['range_recall', 'project', 'name', 'base_releases', 'range_base_releases']]
# Out:
#      range_recall                           project                name  \
# 84       0.981221                       nodejs/node              v0.5.0
# 118      0.914062                       nodejs/node              v0.7.0
# 160      0.897959                       nodejs/node              v0.9.0
# 222      0.921569                       nodejs/node             v0.11.0
# 258      0.743644                       nodejs/node              v1.0.0
# 282      0.962500                       nodejs/node              v2.0.0
# 45       0.137931                   webpack/webpack              v1.8.0
# 136      0.998808                   webpack/webpack              v4.0.0
# 163      0.190476             ant-design/ant-design               3.6.1
# 62       0.975000        ionic-team/ionic-framework              v4.2.0
# 64       0.975000        ionic-team/ionic-framework              v4.3.0
# 98       0.000000        ionic-team/ionic-framework              v5.0.0
# 58       0.000000                     facebook/jest              v5.0.3
# 174      0.989172                 vuetifyjs/vuetify              v2.0.0
# 16       0.949714       spring-projects/spring-boot      v1.2.0.RELEASE
# 25       0.987654       spring-projects/spring-boot      v1.3.0.RELEASE
# 34       0.998589       spring-projects/spring-boot      v1.4.0.RELEASE
# 42       0.996495       spring-projects/spring-boot      v1.5.0.RELEASE
# 65       0.988313       spring-projects/spring-boot      v2.0.0.RELEASE
# 75       0.972028       spring-projects/spring-boot      v2.1.0.RELEASE
# 93       0.990408       spring-projects/spring-boot      v2.2.0.RELEASE
# 104      0.989336       spring-projects/spring-boot      v2.3.0.RELEASE
# 2        0.000000  spring-projects/spring-framework      v3.0.1.RELEASE
# 130      0.999379  spring-projects/spring-framework      v5.2.0.RELEASE
# 49       0.216216                      apache/dubbo         dubbo-2.6.0
# 41       0.791667                       netty/netty   netty-3.7.0.Final
# 43       0.970588                       netty/netty   netty-3.8.0.Final
# 47       0.923077                       netty/netty   netty-3.9.0.Final
# 50       0.972222                       netty/netty   netty-3.9.2.Final
# 58       0.750000                       netty/netty  netty-3.10.0.Final
# 14       0.000000                  alibaba/fastjson              1.1.42
# 61       0.000000               ytdl-org/youtube-dl          2012.02.26
# 71       0.000000               ytdl-org/youtube-dl          2013.01.02
# 79       0.000000               ytdl-org/youtube-dl          2013.01.27
# 90       0.000000               ytdl-org/youtube-dl          2013.03.29
# 201      0.000000               ytdl-org/youtube-dl          2013.11.09
# 373      0.000000               ytdl-org/youtube-dl        2014.04.04.3
# 24       0.998336                     pallets/flask                 1.0
# 5        0.901627                     django/django                 1.1
# 10       0.969099                     django/django                 1.2
# 18       0.983492                     django/django                 1.3
# 2        0.000000                   ansible/ansible                0.01
# 51       0.631579                   laravel/laravel              v5.2.0
# 89       0.679245                   laravel/laravel              v6.0.0
# 12       0.992222                 laravel/framework              v4.1.0
# 44       0.880903                 laravel/framework              v4.2.0
# 67       0.964187                 laravel/framework              v5.0.0
# 150      0.983568                 laravel/framework              v5.2.0
# 196      0.966825                 laravel/framework                 5.3
# 229      0.982836                 laravel/framework              v5.4.0
# 266      0.989390                 laravel/framework              v5.5.0
# 317      0.995392                 laravel/framework              v5.6.0
# 358      0.979112                 laravel/framework              v5.7.0
# 427      0.956522                 laravel/framework              v6.0.0
# 101      0.949686                     guzzle/guzzle               6.0.0
# 43       0.952703                   Seldaek/monolog               2.0.0
# 173      0.994932         sebastianbergmann/phpunit               4.0.0
# 316      0.935065         sebastianbergmann/phpunit               5.4.0
# 342      0.839506         sebastianbergmann/phpunit               5.7.0
# 370      0.963158         sebastianbergmann/phpunit               6.0.0
# 506      0.936275         sebastianbergmann/phpunit               9.0.0
# 418      0.200000               WordPress/WordPress               5.0.5
# 64       0.023810                 electron/electron              v0.9.5
# 58       0.997389                     opencv/opencv               4.0.0
# 81       0.997166                   bitcoin/bitcoin             v0.15.0
# 7        0.055556                       aria2/aria2       release-0.3.3
# 1        0.000000                  Wox-launcher/Wox          v1.0.0.219
# 1        0.000000                     dotnet/efcore               1.0.1
# 8        0.966667                     dotnet/efcore           rel/1.1.0
# 25       0.000000                     dotnet/efcore             v2.1.10
# 33       0.000000                     dotnet/efcore             v2.1.19
# 37       0.462121                     dotnet/efcore               2.2.0
# 39       0.000000                     dotnet/efcore              v2.2.1
# 48       0.000000                     dotnet/efcore              v3.0.1
# 2        0.000000                 jellyfin/jellyfin             v10.0.2
# 7        0.078431                 cefsharp/CefSharp             v1.19.0
# 18       0.113752                 taosdata/TDengine         ver-1.6.5.9
# 29       0.000000                 taosdata/TDengine         ver-2.0.2.0
# 33       0.061776                 taosdata/TDengine         ver-2.0.3.1
# 359      0.967742                       nginx/nginx       release-1.1.0
# 388      0.960000                       nginx/nginx       release-1.3.0
# 413      0.833333                       nginx/nginx       release-1.5.0
# 2        0.120879               discourse/discourse              v0.8.2
# 190      0.000000                  v2ray/v2ray-core               v2.43
# 43       0.927711             prometheus/prometheus              v1.3.0
#
#                                          base_releases    range_base_releases
# 84   [v0.4.4, v0.4.8, v0.4.6, v0.4.2, v0.4.1, v0.4....              [v0.4.12]
# 118           [v0.6.2, v0.6.5, v0.6.3, v0.6.7, v0.6.6]              [v0.6.21]
# 160                   [v0.8.1, v0.8.0, v0.8.2, v0.8.3]              [v0.8.28]
# 222                        [v0.10.1, v0.10.2, v0.10.0]             [v0.10.48]
# 258                                         [v0.11.14]             [v0.12.18]
# 282                                           [v1.8.1]               [v1.8.4]
# 45                                            [v1.7.3]               [v1.7.4]
# 136  [v3.0.0, v3.10.0, v3.9.0, v3.7.0, v3.8.0, v3.5...              [v3.12.0]
# 163                              [3.5.4, 3.5.2, 3.5.1]                [3.6.0]
# 62                                            [v4.1.2]               [v4.1.3]
# 64                                            [v4.2.0]               [v4.2.1]
# 98                                          [v4.11.10]             [v4.11.11]
# 58                                            [v0.5.2]              [v0.10.0]
# 174  [v1.4.1, v1.5.15, v1.5.11, v1.5.13, v1.5.9, v1...              [v1.5.24]
# 16   [v1.1.5.RELEASE, v1.1.8.RELEASE, v1.1.6.RELEAS...      [v1.1.12.RELEASE]
# 25   [v1.1.0.RELEASE, v1.2.4.RELEASE, v1.2.6.RELEAS...       [v1.2.8.RELEASE]
# 34   [v1.3.7.RELEASE, v1.3.5.RELEASE, v1.3.3.RELEAS...       [v1.3.8.RELEASE]
# 42   [v1.4.4.RELEASE, v1.4.3.RELEASE, v1.4.2.RELEAS...       [v1.4.7.RELEASE]
# 65   [v1.5.9.RELEASE, v1.5.1.RELEASE, v1.5.7.RELEAS...      [v1.5.22.RELEASE]
# 75   [v2.0.5.RELEASE, v2.0.3.RELEASE, v2.0.6.RELEAS...       [v2.0.9.RELEASE]
# 93   [v2.1.8.RELEASE, v2.1.4.RELEASE, v2.1.6.RELEAS...      [v2.1.17.RELEASE]
# 104  [v2.1.14.RELEASE, v2.2.6.RELEASE, v2.2.4.RELEA...      [v2.2.10.RELEASE]
# 2                                     [v3.0.0.RELEASE]     [v3.0.1.RELEASE.A]
# 130  [v5.1.6.RELEASE, v5.1.8.RELEASE, v5.1.5.RELEAS...      [v5.1.17.RELEASE]
# 49                                       [dubbo-2.5.8]         [dubbo-2.5.10]
# 41                                 [netty-3.6.6.Final]   [netty-3.6.10.Final]
# 43                                 [netty-3.7.0.Final]    [netty-3.7.1.Final]
# 47                                 [netty-3.8.0.Final]    [netty-3.8.3.Final]
# 50                                 [netty-3.9.1.Final]  [netty-3.9.1.1.Final]
# 58                                 [netty-3.9.6.Final]    [netty-3.9.9.Final]
# 14                                    [1.1.33, 1.1.36]               [1.1.37]
# 61                                        [2012.01.08]           [2012.02.22]
# 71                                        [2012.12.11]           [2012.12.99]
# 79                                        [2013.01.13]         [2013.01.17.1]
# 90                            [2013.02.25, 2012.02.22]         [2013.03.24.2]
# 201                                       [2013.09.10]           [2013.11.07]
# 373                                     [2014.04.04.1]         [2014.04.04.2]
# 24                [0.12.2, 0.12, 0.11, 0.12.3, 0.12.1]               [0.12.5]
# 5                                                [1.0]                [1.0.4]
# 10                                               [1.1]                [1.1.4]
# 18                                             [1.2.1]                [1.2.7]
# 2                                                   []                [0.0.2]
# 51                                   [v5.1.3, v5.1.11]              [v5.1.33]
# 89                  [v5.8.3, v5.8.17, v5.8.16, v5.8.0]              [v5.8.35]
# 12   [v4.0.8, v4.0.6, v4.0.10, v4.0.4, v4.0.2, v4.0...              [v4.0.11]
# 44   [v4.1.0, v4.1.24, v4.1.17, v4.1.4, v4.1.1, v4....              [v4.1.31]
# 67   [v4.2.3, v4.2.16, v4.1.0, v4.2.2, v4.2.14, v4....              [v4.2.22]
# 150  [v5.1.26, v5.1.8, v5.1.11, v5.1.27, v5.1.2, v5...              [v5.1.46]
# 196  [v5.2.21, v5.2.37, v5.2.14, v5.2.5, v5.2.22, v...              [v5.2.45]
# 229  [v5.3.19, v5.3.11, v5.3.27, v5.3.2, v5.3.7, v5...              [v5.3.31]
# 266  [v5.4.28, v5.4.20, v5.4.13, v5.4.29, v5.4.21, ...              [v5.4.36]
# 317  [v5.5.32, v5.5.1, v5.5.25, v5.5.33, v5.5.10, v...              [v5.5.50]
# 358  [v5.6.25, v5.6.18, v5.6.10, v5.6.26, v5.6.5, v...              [v5.6.40]
# 427  [v5.8.14, v5.8.22, v5.8.15, v5.8.30, v5.8.23, ...              [v5.8.38]
# 101                                            [5.3.0]                [5.3.4]
# 43   [1.20.0, 1.24.0, 1.18.2, 1.18.0, 1.22.1, 1.21....               [1.25.5]
# 173  [3.7.1, 3.7.25, 3.7.6, 3.7.18, 3.7.10, 3.5.14,...               [3.7.38]
# 316  [5.2.0, 5.3.4, 5.3.0, 5.3.2, 5.1.0, 4.8.26, 5....                [5.3.5]
# 342  [5.6.6, 5.6.4, 5.6.2, 5.6.0, 5.6.7, 5.6.5, 5.6...                [5.6.8]
# 370  [5.7.8, 5.7.1, 5.7.6, 5.7.4, 5.7.2, 5.6.0, 5.7...               [5.7.27]
# 506                      [8.5.0, 7.5.20, 8.5.2, 8.5.1]                [8.5.8]
# 418                                            [5.0.3]                [5.0.4]
# 64                                    [v0.8.7, v0.8.6]               [v0.9.3]
# 58                        [3.4.4, 3.4.3, 3.4.2, 3.4.1]               [3.4.11]
# 81                         [v0.14.0, v0.10.0, v0.13.0]              [v0.14.3]
# 7                                      [release-0.2.1]        [release-0.3.2]
# 1                                                   []           [v1.0.0.185]
# 1                                                   []                [1.0.0]
# 8                                   [rel/1.0.1, 1.0.1]                [1.0.6]
# 25                                            [v2.2.1]               [v2.1.8]
# 33                                           [v2.1.14]              [v2.1.18]
# 37                 [2.1.2, 2.1.4, 2.1.0, 2.1.3, 2.1.1]              [v2.1.22]
# 39                                             [2.2.0]          [release/2.2]
# 48                               [v3.0.0, release/2.2]          [release/3.0]
# 2                                                   []              [v10.0.1]
# 7                                              [v0.11]                [v0.12]
# 18                          [ver-1.6.5.6, ver-1.6.5.4]          [ver-1.6.5.8]
# 29                          [ver-2.0.1.1, ver-2.0.1.0]          [ver-2.0.1.9]
# 33   [ver-2.0.2.0, ver-2.0.3.0, ver-2.0.2.1, ver-2....          [ver-2.0.3.0]
# 359                                    [release-1.0.5]       [release-1.0.15]
# 388                                    [release-1.2.0]        [release-1.2.9]
# 413                                    [release-1.4.0]        [release-1.4.7]
# 2                                     [v0.8.0, v0.8.1]               [v0.8.1]
# 190                                            [v2.42]              [v2.42.1]
# 43                            [v1.2.2, v1.2.1, v1.2.0]               [v1.2.3]
