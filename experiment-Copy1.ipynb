# %% [markdown]
# # Imports

# %%
import datetime
import json

# %% [markdown]
# ##  Releasy development version

# %%
import os
import sys

releasy_module = os.path.abspath(os.path.join('..','..','..','dev','releasy'))
if releasy_module not in sys.path:
    sys.path.insert(0, releasy_module)

# %%
for mod in sorted(sys.modules.keys()):
    if mod.startswith("releasy"):
        del sys.modules[mod]

# %%
from releasy.miner.vcs.miner import Miner
from releasy.miner.vcs.git import GitVcs

# %%
from releasy.miner.vcs import miner as releasy_miner
from releasy.miner.vcs import git as releasy_git

# %%
import importlib
importlib.reload(releasy_miner)
importlib.reload(releasy_git)
# Out:
# <module 'releasy.miner.vcs.git' from '/home/felipecrp/dev/releasy/releasy/miner/vcs/git.py'>

# %% [markdown]
# ## Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy.stats import wilcoxon
from scipy.stats import ranksums

# %%
# %matplotlib inline
# %matplotlib notebook
pd.options.display.max_rows = 1000

# %% [markdown]
# # Variables

# %%
repo_path = os.path.join('..','..','..','repos')

# %%
projects = pd.read_pickle("projects.zip")
projects["data"] = None

# %%
# projects.loc[projects.index.isin(bkp.index), "data"] = bkp.data
# projects = projects[projects.index == "git/git"]

# %% [markdown]
# # Process Repos

# %%
count = 1
for name, project in projects[(projects.data.isnull())].iterrows():
    print(f"{datetime.datetime.now()} - {count:3} - Processing {name}")
    project_group, project_name = name.split("/") 
    path = os.path.join(repo_path, project_group, f"{project_name}.git")
    projects.loc[name, "path"] = path    
    
    params = {}
    miner = releasy_miner.Miner(name=name,vcs=releasy_git.GitVcs(path), **params)
    project = miner.mine_commits()
    projects.loc[name, "data"] = project
    count += 1
print(f"{datetime.datetime.now()} - Ended")
# Out:
# 2019-11-24 00:40:26.008224 -   1 - Processing freeCodeCamp/freeCodeCamp
# 2019-11-24 00:40:26.012081 -   2 - Processing vuejs/vue
# 2019-11-24 00:40:26.576361 -   3 - Processing facebook/react
# 2019-11-24 00:40:29.793343 -   4 - Processing twbs/bootstrap
# 2019-11-24 00:40:36.043708 -   5 - Processing facebook/react-native
# 2019-11-24 00:40:40.400982 -   6 - Processing facebook/create-react-app
# 2019-11-24 00:40:40.565624 -   7 - Processing axios/axios
# 2019-11-24 00:40:40.603775 -   8 - Processing nodejs/node
# 2019-11-24 00:41:35.674016 -   9 - Processing FortAwesome/Font-Awesome
# 2019-11-24 00:41:35.732818 -  10 - Processing angular/angular.js
# 2019-11-24 00:41:37.831409 -  11 - Processing microsoft/vscode
# 2019-11-24 00:44:59.369035 -  12 - Processing microsoft/TypeScript
# 2019-11-24 00:45:51.116359 -  13 - Processing angular/angular
# 2019-11-24 00:45:55.001527 -  14 - Processing ant-design/ant-design
# 2019-11-24 00:45:57.646349 -  15 - Processing reduxjs/redux
# 2019-11-24 00:45:57.816560 -  16 - Processing storybookjs/storybook
# 2019-11-24 00:46:26.945853 -  17 - Processing denoland/deno
# 2019-11-24 00:46:27.077939 -  18 - Processing ionic-team/ionic
# 2019-11-24 00:46:30.477369 -  19 - Processing grafana/grafana
# 2019-11-24 00:46:46.641839 -  20 - Processing cdr/code-server
# 2019-11-24 00:46:46.682592 -  21 - Processing elastic/elasticsearch

# %%
projects.loc[projects.data == 1, "data"] = None

# %%
projects.shape
# Out:
# (99, 8)

# %% [markdown]
# ## Check tags

# %%
# bkp = projects.copy()

# %%
# projects = bkp[projects.data.notnull()].copy()

# %%
projects.shape
# Out:
# (94, 8)

# %%
projects["tags"] = projects["data"].apply(lambda project: len(project.tags))
projects["releases"] = 0
projects["percent_releases"] = 0
projects["releases"] = projects["data"].apply(lambda project: len(project.releases))
projects.loc[projects["tags"] > 0,"percent_releases"] = projects["releases"]/projects["tags"]

# %% [markdown]
# ## Promise 1: Projects often use tags to represent software releases

# %%
projects[projects.releases > 0].shape[0] / projects.shape[0]
# Out:
# 0.9292929292929293

# %% [markdown]
# ## Peril 1: Projects do not use tags

# %%
projects[projects.releases == 0].shape[0] / projects.shape[0]
# Out:
# 0.0707070707070707

# %%
list(projects[projects.tags == 0].index)
# Out:
# ['freeCodeCamp/freeCodeCamp',
#  'mxgmn/WaveFunctionCollapse',
#  'pjreddie/darknet',
#  'huginn/huginn',
#  'freeCodeCamp/devdocs']

# %%
list(projects[projects.releases == 0].index)
# Out:
# ['freeCodeCamp/freeCodeCamp',
#  'mxgmn/WaveFunctionCollapse',
#  'curl/curl',
#  'pjreddie/darknet',
#  'huginn/huginn',
#  'freeCodeCamp/devdocs',
#  'ruby/ruby']

# %%
projects[projects.percent_releases < 1][["tags","releases","percent_releases"]]
# Out:
#                                            tags  releases  percent_releases
# name
# freeCodeCamp/freeCodeCamp                     0         0          0.000000
# d3/d3                                       260       259          0.996154
# facebook/react-native                       307       305          0.993485
# facebook/create-react-app                   324       323          0.996914
# nodejs/node                                 543       540          0.994475
# microsoft/vscode                            142       137          0.964789
# microsoft/TypeScript                        110       109          0.990909
# angular/angular                             311       309          0.993569
# ant-design/ant-design                       285       284          0.996491
# ionic-team/ionic                            174       173          0.994253
# square/okhttp                                80        79          0.987500
# google/guava                                 88        83          0.943182
# josephmisiti/awesome-machine-learning         0         0          0.000000
# ansible/ansible                             264       263          0.996212
# scikit-learn/scikit-learn                    92        91          0.989130
# symfony/symfony                             420       411          0.978571
# microsoft/terminal                           35        29          0.828571
# apple/swift                                1120       561          0.500893
# bitcoin/bitcoin                             216       215          0.995370
# protocolbuffers/protobuf                     61        60          0.983607
# nwjs/nw.js                                  239       236          0.987448
# x64dbg/x64dbg                                28        26          0.928571
# PowerShell/PowerShell                        62        50          0.806452
# aspnet/AspNetCore                            65        61          0.938462
# mxgmn/WaveFunctionCollapse                    0         0          0.000000
# dotnet/coreclr                               77        75          0.974026
# dotnet/roslyn                                95        43          0.452632
# antirez/redis                               222       218          0.981982
# discourse/discourse                         305       304          0.996721
# fastlane/fastlane                           997       954          0.956871
# huginn/huginn                                 0         0          0.000000
# freeCodeCamp/devdocs                          0         0          0.000000
# golang/go                                   235       129          0.548936
# moby/moby                                   198       195          0.984848
# astaxie/build-web-application-with-golang     0         0          0.000000
# syncthing/syncthing                         345       342          0.991304
# etcd-io/etcd                                160       159          0.993750

# %%
project_df["created_at"] = pd.to_datetime(project_df["created_at"])

# %%
project_df["n_tags"] = project_df["data"].apply(lambda project: len(project.tags))
project_df["n_releases"] = 0
project_df["p_releases"] = 0
project_df["n_releases"] = project_df["data"].apply(lambda project: len(project.releases))
project_df.loc[project_df["n_tags"] > 0,"p_releases"] = project_df["n_releases"]/project_df["n_tags"]

# %%
project_df.loc[(project_df.n_releases < 5), "discarded_by"] = "few releases"
project_df.loc[(project_df.p_releases < 0.85), "discarded_by"] = "nom semantic"
project_df.loc[(project_df.created_at > "2018-10-01"), "discarded_by"] = "too young"
project_df.loc[(project_df.stars < 1000), "discarded_by"] = "few stars"

# %%
project_df[(project_df.created_at > "2018-10-01")]

# %%
summary = pd.DataFrame()
summary["n_projects"] = project_df[(project_df.discarded_by.isnull())].groupby(["language"])["n_releases"].count()
summary["older_project_birth"] = project_df[(project_df.discarded_by.isnull())].groupby(["language"])["created_at"].min()
summary["younger_project_birth"] = project_df[(project_df.discarded_by.isnull())].groupby(["language"])["created_at"].max()
summary["min_stars"] = project_df[(project_df.discarded_by.isnull())].groupby(["language"])["stars"].min()
summary["max_stars"] = project_df[(project_df.discarded_by.isnull())].groupby(["language"])["stars"].max()
summary["min_releases"] = project_df[(project_df.discarded_by.isnull())].groupby(["language"])["n_releases"].min()
summary["max_releases"] = project_df[(project_df.discarded_by.isnull())].groupby(["language"])["n_releases"].max()
summary["mean_releases"] = project_df[(project_df.discarded_by.isnull())].groupby(["language"])["n_releases"].mean().round(0)
summary["std_deviation_releases"] = project_df[(project_df.discarded_by.isnull())].groupby(["language"])["n_releases"].std().round(0)
summary["total_releases"] = project_df[(project_df.discarded_by.isnull())].groupby(["language"])["n_releases"].sum()
summary

# %%
summary.total_releases.sum()

# %%
project_df[(project_df.discarded_by.notnull()) & (project_df.language == "Go")].sort_values(by=["n_releases"], ascending=False)
# Out:
#                    name language          created_at  stars  p_releases  \
# 162  go-martini/martini       Go 2013-10-30 02:34:07  10719         1.0
# 164       gocolly/colly       Go 2017-09-29 14:08:49   9072         1.0
# 152  avelino/awesome-go       Go 2014-07-06 13:42:15  48855         0.0
# 167   golang/groupcache       Go 2013-07-22 21:55:07   7896         0.0
# 168          andlabs/ui       Go 2014-02-17 23:44:00   7153         0.0
#
#      n_releases  n_tags  percent_releases prefixes                data  \
# 162           3       3               NaN      NaN  go-martini/martini
# 164           3       3               NaN      NaN       gocolly/colly
# 152           0       0               NaN      NaN  avelino/awesome-go
# 167           0       0               NaN      NaN   golang/groupcache
# 168           0       1               NaN      NaN          andlabs/ui
#
#                                                  url  \
# 162  https://api.github.com/repos/go-martini/martini
# 164       https://api.github.com/repos/gocolly/colly
# 152  https://api.github.com/repos/avelino/awesome-go
# 167   https://api.github.com/repos/golang/groupcache
# 168          https://api.github.com/repos/andlabs/ui
#
#                                      git_url  discarded_by
# 162  git://github.com/go-martini/martini.git  few releases
# 164       git://github.com/gocolly/colly.git  few releases
# 152  git://github.com/avelino/awesome-go.git  nom semantic
# 167   git://github.com/golang/groupcache.git  nom semantic
# 168          git://github.com/andlabs/ui.git  nom semantic

# %%
project_df[(project_df.n_tags < 5)].sort_values(by=["n_releases"], ascending=False)
# Out:
#                                       name language          created_at  \
# 41           NationalSecurityAgency/ghidra     Java 2019-03-01 03:27:48
# 81                          doctrine/lexer      PHP 2013-01-12 18:58:26
# 165                          gocolly/colly       Go 2017-09-29 14:08:49
# 163                     go-martini/martini       Go 2013-10-30 02:34:07
# 130                          lpereira/lwan        C 2012-01-28 00:48:12
# 139                      imathis/octopress     Ruby 2009-10-18 21:41:32
# 131                         zserge/webview        C 2017-08-19 08:26:00
# 125                             liuliu/ccv        C 2010-09-15 15:59:47
# 119                           nothings/stb        C 2014-05-25 16:51:23
# 47                    vinta/awesome-python   Python 2014-06-27 21:00:06
# 136                gali8/Tesseract-OCR-iOS        C 2013-04-30 10:38:14
# 116                         vurtun/nuklear        C 2015-03-25 13:32:06
# 153                     avelino/awesome-go       Go 2014-07-06 13:42:15
# 100         thangchung/awesome-dotnet-core       C# 2016-03-17 03:52:09
# 50   josephmisiti/awesome-machine-learning   Python 2014-07-15 19:11:19
# 168                      golang/groupcache       Go 2013-07-22 21:55:07
# 169                             andlabs/ui       Go 2014-02-17 23:44:00
# 173                         keybase/client       Go 2015-01-11 17:17:12
#
#      stars  p_releases  n_releases  n_tags  percent_releases prefixes  \
# 41   17883         1.0           4       4               NaN      NaN
# 81    8014         1.0           4       4               NaN      NaN
# 165   9073         1.0           3       3               NaN      NaN
# 163  10719         1.0           3       3               NaN      NaN
# 130   5064         1.0           2       2               NaN      NaN
# 139   9503         1.0           1       1               NaN      NaN
# 131   4901         1.0           1       1               NaN      NaN
# 125   6557         0.0           0       0               NaN      NaN
# 119  10960         0.0           0       0               NaN      NaN
# 47   74680         0.0           0       0               NaN      NaN
# 136   3934         0.0           0       0               NaN      NaN
# 116  13040         0.0           0       0               NaN      NaN
# 153  48855         0.0           0       0               NaN      NaN
# 100  10290         0.0           0       0               NaN      NaN
# 50   42263         0.0           0       0               NaN      NaN
# 168   7896         0.0           0       0               NaN      NaN
# 169   7153         0.0           0       1               NaN      NaN
# 173   6025         0.0           0       0               NaN      NaN
#
#                                       data  \
# 41           NationalSecurityAgency/ghidra
# 81                          doctrine/lexer
# 165                          gocolly/colly
# 163                     go-martini/martini
# 130                          lpereira/lwan
# 139                      imathis/octopress
# 131                         zserge/webview
# 125                             liuliu/ccv
# 119                           nothings/stb
# 47                    vinta/awesome-python
# 136                gali8/Tesseract-OCR-iOS
# 116                         vurtun/nuklear
# 153                     avelino/awesome-go
# 100         thangchung/awesome-dotnet-core
# 50   josephmisiti/awesome-machine-learning
# 168                      golang/groupcache
# 169                             andlabs/ui
# 173                         keybase/client
#
#                                                    url  \
# 41   https://api.github.com/repos/NationalSecurityA...
# 81         https://api.github.com/repos/doctrine/lexer
# 165         https://api.github.com/repos/gocolly/colly
# 163    https://api.github.com/repos/go-martini/martini
# 130         https://api.github.com/repos/lpereira/lwan
# 139     https://api.github.com/repos/imathis/octopress
# 131        https://api.github.com/repos/zserge/webview
# 125            https://api.github.com/repos/liuliu/ccv
# 119          https://api.github.com/repos/nothings/stb
# 47   https://api.github.com/repos/vinta/awesome-python
# 136  https://api.github.com/repos/gali8/Tesseract-O...
# 116        https://api.github.com/repos/vurtun/nuklear
# 153    https://api.github.com/repos/avelino/awesome-go
# 100  https://api.github.com/repos/thangchung/awesom...
# 50   https://api.github.com/repos/josephmisiti/awes...
# 168     https://api.github.com/repos/golang/groupcache
# 169            https://api.github.com/repos/andlabs/ui
# 173        https://api.github.com/repos/keybase/client
#
#                                                git_url  discarded_by
# 41   git://github.com/NationalSecurityAgency/ghidra...      few tags
# 81                 git://github.com/doctrine/lexer.git      few tags
# 165                 git://github.com/gocolly/colly.git      few tags
# 163            git://github.com/go-martini/martini.git      few tags
# 130                 git://github.com/lpereira/lwan.git      few tags
# 139             git://github.com/imathis/octopress.git      few tags
# 131                git://github.com/zserge/webview.git      few tags
# 125                    git://github.com/liuliu/ccv.git  nom semantic
# 119                  git://github.com/nothings/stb.git  nom semantic
# 47           git://github.com/vinta/awesome-python.git  nom semantic
# 136       git://github.com/gali8/Tesseract-OCR-iOS.git  nom semantic
# 116                git://github.com/vurtun/nuklear.git  nom semantic
# 153            git://github.com/avelino/awesome-go.git  nom semantic
# 100  git://github.com/thangchung/awesome-dotnet-cor...  nom semantic
# 50   git://github.com/josephmisiti/awesome-machine-...  nom semantic
# 168             git://github.com/golang/groupcache.git  nom semantic
# 169                    git://github.com/andlabs/ui.git  nom semantic
# 173                git://github.com/keybase/client.git  nom semantic

# %%
project_df[project_df.p_releases > 0.85].groupby("language").count()
# Out:
#             name  stars  p_releases  n_releases  n_tags  percent_releases  \
# language
# C             15     15          15          15      15                15
# C#            15     15          15          15      15                15
# C++           15     15          15          15      15                15
# Go            14     14          14          14      14                14
# Java          15     15          15          15      15                15
# JavaScript    16     16          16          16      16                16
# PHP           15     15          15          15      15                15
# Python        15     15          15          15      15                15
# Ruby          15     15          15          15      15                15
# TypeScript    15     15          15          15      15                15
#
#             prefixes  data  url  git_url  discarded_by
# language
# C                  0    15   15       15            12
# C#                 0    15   15       15            14
# C++                0    15   15       15            14
# Go                 0    14   14       14            10
# Java               3    15   15       15            14
# JavaScript         5    16   16       16            16
# PHP                0    15   15       15            14
# Python             0    15   15       15            13
# Ruby               0    15   15       15            14
# TypeScript         2    15   15       15            15

# %%
project_df[(project_df.n_tags < 10)].head(20)
# Out:
#                                       name language  stars  p_releases  \
# 41           NationalSecurityAgency/ghidra     Java  17859    1.000000
# 46                    vinta/awesome-python   Python  74541    0.000000
# 49   josephmisiti/awesome-machine-learning   Python  42243    0.000000
# 55                      google/python-fire   Python  15522    1.000000
# 59                         tflearn/tflearn   Python   9293    1.000000
# 77                      doctrine/inflector      PHP   8187    1.000000
# 93                   apache/incubator-brpc      C++   9268    1.000000
# 96          thangchung/awesome-dotnet-core       C#  10284    0.000000
# 99                     AvaloniaUI/Avalonia       C#   7394    1.000000
# 111                         vurtun/nuklear        C  13034    0.000000
# 114                           nothings/stb        C  10955    0.000000
# 115                          andlabs/libui        C   8994    0.428571
# 120                             liuliu/ccv        C   6557    0.000000
# 125                          lpereira/lwan        C   5063    1.000000
# 126                         zserge/webview        C   4901    1.000000
# 130                          cinder/Cinder        C   3955    1.000000
# 133                      imathis/octopress     Ruby   9503    1.000000
# 147                     avelino/awesome-go       Go  48824    0.000000
# 154                             go-kit/kit       Go  15149    1.000000
# 157                     go-martini/martini       Go  10715    1.000000
#
#      n_releases  n_tags  percent_releases prefixes  \
# 41            4       4            100.00      NaN
# 46            0       0              0.00      NaN
# 49            0       0              0.00      NaN
# 55            6       6            100.00      NaN
# 59            7       7            100.00      NaN
# 77            5       5            100.00      NaN
# 93            6       6            100.00      NaN
# 96            0       0              0.00      NaN
# 99            8       8            100.00      NaN
# 111           0       0              0.00      NaN
# 114           0       0              0.00      NaN
# 115           3       7             42.86      NaN
# 120           0       0              0.00      NaN
# 125           2       2            100.00      NaN
# 126           1       1            100.00      NaN
# 130           9       9            100.00      NaN
# 133           1       1            100.00      NaN
# 147           0       0              0.00      NaN
# 154           9       9            100.00      NaN
# 157           3       3            100.00      NaN
#
#                                       data  \
# 41           NationalSecurityAgency/ghidra
# 46                    vinta/awesome-python
# 49   josephmisiti/awesome-machine-learning
# 55                      google/python-fire
# 59                         tflearn/tflearn
# 77                      doctrine/inflector
# 93                   apache/incubator-brpc
# 96          thangchung/awesome-dotnet-core
# 99                     AvaloniaUI/Avalonia
# 111                         vurtun/nuklear
# 114                           nothings/stb
# 115                          andlabs/libui
# 120                             liuliu/ccv
# 125                          lpereira/lwan
# 126                         zserge/webview
# 130                          cinder/Cinder
# 133                      imathis/octopress
# 147                     avelino/awesome-go
# 154                             go-kit/kit
# 157                     go-martini/martini
#
#                                                    url  \
# 41   https://api.github.com/repos/NationalSecurityA...
# 46   https://api.github.com/repos/vinta/awesome-python
# 49   https://api.github.com/repos/josephmisiti/awes...
# 55     https://api.github.com/repos/google/python-fire
# 59        https://api.github.com/repos/tflearn/tflearn
# 77     https://api.github.com/repos/doctrine/inflector
# 93   https://api.github.com/repos/apache/incubator-...
# 96   https://api.github.com/repos/thangchung/awesom...
# 99    https://api.github.com/repos/AvaloniaUI/Avalonia
# 111        https://api.github.com/repos/vurtun/nuklear
# 114          https://api.github.com/repos/nothings/stb
# 115         https://api.github.com/repos/andlabs/libui
# 120            https://api.github.com/repos/liuliu/ccv
# 125         https://api.github.com/repos/lpereira/lwan
# 126        https://api.github.com/repos/zserge/webview
# 130         https://api.github.com/repos/cinder/Cinder
# 133     https://api.github.com/repos/imathis/octopress
# 147    https://api.github.com/repos/avelino/awesome-go
# 154            https://api.github.com/repos/go-kit/kit
# 157    https://api.github.com/repos/go-martini/martini
#
#                                                git_url discarded_by
# 41   git://github.com/NationalSecurityAgency/ghidra...          NaN
# 46           git://github.com/vinta/awesome-python.git          NaN
# 49   git://github.com/josephmisiti/awesome-machine-...          NaN
# 55             git://github.com/google/python-fire.git          NaN
# 59                git://github.com/tflearn/tflearn.git          NaN
# 77             git://github.com/doctrine/inflector.git          NaN
# 93          git://github.com/apache/incubator-brpc.git          NaN
# 96   git://github.com/thangchung/awesome-dotnet-cor...          NaN
# 99            git://github.com/AvaloniaUI/Avalonia.git          NaN
# 111                git://github.com/vurtun/nuklear.git          NaN
# 114                  git://github.com/nothings/stb.git          NaN
# 115                 git://github.com/andlabs/libui.git          NaN
# 120                    git://github.com/liuliu/ccv.git          NaN
# 125                 git://github.com/lpereira/lwan.git          NaN
# 126                git://github.com/zserge/webview.git          NaN
# 130                 git://github.com/cinder/Cinder.git          NaN
# 133             git://github.com/imathis/octopress.git          NaN
# 147            git://github.com/avelino/awesome-go.git          NaN
# 154                    git://github.com/go-kit/kit.git          NaN
# 157            git://github.com/go-martini/martini.git          NaN

# %%
project_df[(project_df.p_releases < 0.85) & (project_df.discarded_by.isnull()) & (project_df.n_tags > 0)].head(20)
# Out:
#                             name language  stars  p_releases  n_releases  \
# 80                    BVLC/caffe      C++  29282    0.428571           6
# 110                    curl/curl        C  15248    0.000000           0
# 112              openssl/openssl        C  11540    0.000000           0
# 115                andlabs/libui        C   8994    0.428571           3
# 132  rapid7/metasploit-framework     Ruby  18557    0.591241         324
#
#      n_tags  percent_releases prefixes                         data  \
# 80       14             42.86      NaN                   BVLC/caffe
# 110     184              0.00      NaN                    curl/curl
# 112     299              0.00      NaN              openssl/openssl
# 115       7             42.86      NaN                andlabs/libui
# 132     548             59.12      NaN  rapid7/metasploit-framework
#
#                                                    url  \
# 80             https://api.github.com/repos/BVLC/caffe
# 110             https://api.github.com/repos/curl/curl
# 112       https://api.github.com/repos/openssl/openssl
# 115         https://api.github.com/repos/andlabs/libui
# 132  https://api.github.com/repos/rapid7/metasploit...
#
#                                               git_url discarded_by
# 80                    git://github.com/BVLC/caffe.git          NaN
# 110                    git://github.com/curl/curl.git          NaN
# 112              git://github.com/openssl/openssl.git          NaN
# 115                git://github.com/andlabs/libui.git          NaN
# 132  git://github.com/rapid7/metasploit-framework.git          NaN

# %%
for name,project_data in projects_data.items():
    if "discarded_by" in project_data:
        continue
    project = project_data["data"]
    tags = project.tags
    nom_release_tags = [tag for tag in project.tags if not tag.release or tag.name.startswith("zone") or tag.name.startswith("ngcontainer")]
    if len(tags) > 0:
        percent_releases = round(100*(1-len(nom_release_tags)/len(tags)),2)
    else:
        percent_releases = 0
    project_data["percent_releases"] = percent_releases
    
    prefixes = []
    for release in project.releases:
        if release.prefix not in prefixes:
            prefixes.append(release.prefix)

    print(f"{project.name:30} {percent_releases:10} {len(project.releases):10}/{len(project.tags)}")
    print("  Prefixes:")
    for prefix in prefixes:
         print(f"    - {str(prefix):30}")

    print("  Non releases:")            
    for tag in tags:
        if not tag.release:
           print(f"    - {tag.name}")
#        print(f"-- {tag.name:30} {tag.release != None}")
    print("---")
# Out:
# vuejs/vue                           100.0        248/248
#   Prefixes:
#     -
#     - v
#   Non releases:
# ---
# facebook/react                      100.0        116/116
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# twbs/bootstrap                      100.0         55/55
#   Prefixes:
#     - v
#   Non releases:
# ---
# facebook/react-native               99.35        305/307
#   Prefixes:
#     - v
#     -
#   Non releases:
#     - docusaurus-A
#     - latest
# ---
# jquery/jquery                       100.0        148/148
#   Prefixes:
#     -
#   Non releases:
# ---
# hakimel/reveal.js                   100.0         25/25
#   Prefixes:
#     -
#   Non releases:
# ---
# socketio/socket.io                  100.0        128/128
#   Prefixes:
#     -
#   Non releases:
# ---
# Semantic-Org/Semantic-UI            100.0        159/159
#   Prefixes:
#     -
#   Non releases:
# ---
# expressjs/express                   100.0        277/277
#   Prefixes:
#     -
#   Non releases:
# ---
# lodash/lodash                       100.0        400/400
#   Prefixes:
#     -
#   Non releases:
# ---
# zeit/next.js                        100.0        544/544
#   Prefixes:
#     -
#     - v
#   Non releases:
# ---
# apache/incubator-echarts            100.0         88/88
#   Prefixes:
#     -
#     - v
#   Non releases:
# ---
# Dogfalo/materialize                 100.0         44/44
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# impress/impress.js                  100.0         13/13
#   Prefixes:
#     -
#   Non releases:
# ---
# serverless/serverless               98.31        116/118
#   Prefixes:
#     - v
#     - beta
#     -
#   Non releases:
#     - alpha
#     - beta1
# ---
# angular/angular                     97.11        302/311
#   Prefixes:
#     -
#   Non releases:
#     - starting
#     - ngcontainer_0.3.0
#     - ngcontainer_0.3.1
#     - ngcontainer_0.3.2
#     - ngcontainer_0.3.3
#     - ngcontainer_0.4.0
#     - patch_sync
#     - ngcontainer_0.5.0
#     - ngcontainer_0.9.0
# ---
# ant-design/ant-design               99.65        284/285
#   Prefixes:
#     -
#   Non releases:
#     - resource
# ---
# storybookjs/storybook               100.0        591/591
#   Prefixes:
#     - v
#   Non releases:
# ---
# ionic-team/ionic                    99.43        173/174
#   Prefixes:
#     - v
#     -
#   Non releases:
#     - testing
# ---
# vuetifyjs/vuetify                   100.0        234/234
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# nestjs/nest                         100.0        103/103
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# ReactiveX/rxjs                      100.0        111/111
#   Prefixes:
#     -
#   Non releases:
# ---
# akveo/ngx-admin                     100.0         23/23
#   Prefixes:
#     - v
#   Non releases:
# ---
# NativeScript/NativeScript           98.36         60/61
#   Prefixes:
#     - v
#     -
#     - release-
#   Non releases:
#     - e2e-ios-safe-area
# ---
# ionic-team/ionicons                 100.0         87/87
#   Prefixes:
#     - v
#   Non releases:
# ---
# formatjs/react-intl                 100.0         91/91
#   Prefixes:
#     - v
#   Non releases:
# ---
# BabylonJS/Babylon.js                100.0        117/117
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# cyclejs/cyclejs                     98.88         88/89
#   Prefixes:
#     - v
#   Non releases:
#     - unified-tag
# ---
# spring-projects/spring-boot         100.0        123/123
#   Prefixes:
#     - v
#   Non releases:
# ---
# ReactiveX/RxJava                    92.92        197/212
#   Prefixes:
#     -
#     - v
#   Non releases:
#     - rxjava-0.6.2
#     - rxjava-0.6.3
#     - rxjava-0.7.0
#     - rxjava-0.8.0
#     - rxjava-0.8.1
#     - rxjava-0.8.2
#     - rxjava-0.8.3
#     - rxjava-0.8.4
#     - rxjava-0.9.0
#     - rxjava-0.9.1
#     - rxjava-0.9.2
#     - rxjava-0.10.0
#     - rxjava-0.10.1
#     - rxjava-0.11.0
#     - rxjava-0.11.1
# ---
# google/guava                        85.23         75/88
#   Prefixes:
#     - v
#   Non releases:
#     - jdk5-backport-branch-point
#     - jdk5-backport-base
#     - jdk5-backport-v16.0-rc1
#     - jdk5-backport-v16.0
#     - jdk5-backport-v17.0-rc1
#     - jdk5-backport-v17.0-rc2
#     - jdk5-backport-release
#     - jdk5-backport-v17.0
#     - jdk5-backport-v17.0-post
#     - release
#     - jdk5-backport-v17.0-compatibility
#     - released-all-futures
#     - failureaccess-v1.0.1
# ---
# spring-projects/spring-framework      100.0        149/149
#   Prefixes:
#     - v
#   Non releases:
# ---
# apache/dubbo                        100.0         62/62
#   Prefixes:
#     - dubbo-
#   Non releases:
# ---
# PhilJay/MPAndroidChart              100.0         44/44
#   Prefixes:
#     - v
#   Non releases:
# ---
# bumptech/glide                      100.0         37/37
#   Prefixes:
#     - v
#   Non releases:
# ---
# zxing/zxing                         100.0         27/27
#   Prefixes:
#     - BS-
#     - ZXingTest-
#     - zxing-
#     - BSGlass-
#   Non releases:
# ---
# netty/netty                          99.5        200/201
#   Prefixes:
#     - netty-
#   Non releases:
#     - netty-tag
# ---
# Netflix/Hystrix                     100.0        151/151
#   Prefixes:
#     -
#     - hystrix-
#     - v
#   Non releases:
# ---
# NationalSecurityAgency/ghidra       100.0          4/4
#   Prefixes:
#     - Ghidra_
#   Non releases:
# ---
# square/picasso                      100.0         21/21
#   Prefixes:
#     - picasso-parent-
#     -
#   Non releases:
# ---
# google/gson                         100.0         40/40
#   Prefixes:
#     -
#     - gson-
#     - gson-parent-
#   Non releases:
# ---
# nostra13/Android-Universal-Image-Loader      100.0         15/15
#   Prefixes:
#     - v
#   Non releases:
# ---
# libgdx/libgdx                       100.0         45/45
#   Prefixes:
#     -
#     - gdx-parent-
#   Non releases:
# ---
# vinta/awesome-python                    0          0/0
#   Prefixes:
#   Non releases:
# ---
# pallets/flask                       100.0         30/30
#   Prefixes:
#     -
#   Non releases:
# ---
# django/django                       100.0        217/217
#   Prefixes:
#     -
#   Non releases:
# ---
# josephmisiti/awesome-machine-learning          0          0/0
#   Prefixes:
#   Non releases:
# ---
# psf/requests                        100.0        137/137
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# scrapy/scrapy                       98.81         83/84
#   Prefixes:
#     -
#     - scrapy-
#   Non releases:
#     - hojo
# ---
# pandas-dev/pandas                   100.0        102/102
#   Prefixes:
#     -
#     - v
#     - debian/
#   Non releases:
# ---
# tornadoweb/tornado                  100.0         59/59
#   Prefixes:
#     - v
#   Non releases:
# ---
# encode/django-rest-framework        100.0        112/112
#   Prefixes:
#     -
#   Non releases:
# ---
# google/python-fire                  100.0          6/6
#   Prefixes:
#     - v
#   Non releases:
# ---
# huge-success/sanic                  100.0         32/32
#   Prefixes:
#     -
#     - v
#   Non releases:
# ---
# kivy/kivy                           100.0         27/27
#   Prefixes:
#     -
#   Non releases:
# ---
# quantopian/zipline                  96.15         25/26
#   Prefixes:
#     - v
#     -
#   Non releases:
#     - keepalive
# ---
# tflearn/tflearn                     100.0          7/7
#   Prefixes:
#     -
#   Non releases:
# ---
# tensorflow/tensor2tensor            100.0         68/68
#   Prefixes:
#     - v
#     -
#     - v.
#   Non releases:
# ---
# ray-project/ray                     100.0         27/27
#   Prefixes:
#     - ray-
#     -
#   Non releases:
# ---
# Theano/Theano                       100.0         33/33
#   Prefixes:
#     - rel-
#   Non releases:
# ---
# laravel/laravel                     100.0         92/92
#   Prefixes:
#     - v
#   Non releases:
# ---
# fzaninotto/Faker                    100.0         10/10
#   Prefixes:
#     - v
#   Non releases:
# ---
# symfony/symfony                     97.86        411/420
#   Prefixes:
#     - v
#   Non releases:
#     - vPR3
#     - vPR4
#     - vPR5
#     - vPR6
#     - vPR8
#     - vPR9
#     - vPR10
#     - vPR11
#     - vPR12
# ---
# laravel/framework                   100.0        398/398
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# bcit-ci/CodeIgniter                 100.0         37/37
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# sebastianbergmann/phpunit           100.0        546/546
#   Prefixes:
#     -
#   Non releases:
# ---
# PHPMailer/PHPMailer                 100.0         54/54
#   Prefixes:
#     - phpmailer-
#     - v
#   Non releases:
# ---
# yiisoft/yii2                        100.0         33/33
#   Prefixes:
#     -
#   Non releases:
# ---
# slimphp/Slim                        100.0         93/93
#   Prefixes:
#     -
#   Non releases:
# ---
# phalcon/cphalcon                    100.0         96/96
#   Prefixes:
#     - phalcon-v
#     - v
#     - Dao-v
#   Non releases:
# ---
# ramsey/uuid                         100.0         46/46
#   Prefixes:
#     -
#   Non releases:
# ---
# octobercms/october                  100.0        141/141
#   Prefixes:
#     - v
#   Non releases:
# ---
# dingo/api                           100.0         53/53
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# mockery/mockery                     100.0         27/27
#   Prefixes:
#     -
#   Non releases:
# ---
# doctrine/inflector                  100.0          5/5
#   Prefixes:
#     - v
#   Non releases:
# ---
# tensorflow/tensorflow               100.0         79/79
#   Prefixes:
#     -
#     - v
#     - tflite-v
#   Non releases:
# ---
# opencv/opencv                       100.0         79/79
#   Prefixes:
#     -
#   Non releases:
# ---
# BVLC/caffe                          42.86          6/14
#   Prefixes:
#     - v
#     -
#   Non releases:
#     - bsd
#     - rcnn-release
#     - acm-mm-oss
#     - rc
#     - rc2
#     - rc3
#     - rc4
#     - rc5
# ---
# google/leveldb                      100.0         20/20
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# dmlc/xgboost                        100.0         14/14
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# facebook/rocksdb                    99.45        181/182
#   Prefixes:
#     - v
#     -
#     - rocksdb-
#   Non releases:
#     - do-not-use-me2
# ---
# CMU-Perceptual-Computing-Lab/openpose      100.0         13/13
#   Prefixes:
#     - v
#   Non releases:
# ---
# swoole/swoole-src                   100.0        290/290
#   Prefixes:
#     - v
#     - swoole-
#     -
#   Non releases:
# ---
# facebook/folly                      99.42        172/173
#   Prefixes:
#     - v
#     -
#   Non releases:
#     - deprecate-dynamic-initializer
# ---
# google/googletest                   100.0         14/14
#   Prefixes:
#     - release-
#     - v
#   Non releases:
# ---
# google/flatbuffers                  100.0         17/17
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# catchorg/Catch2                     100.0         91/91
#   Prefixes:
#     - v
#     - V
#     - v.
#   Non releases:
# ---
# microsoft/react-native-windows      99.68        631/633
#   Prefixes:
#     - v
#     -
#     - rnwcpp-
#     - vnext-
#     - react-native-windows-extended_v
#     - react-native-windows_v
#     - rnpm-plugin-windows_v
#     - rnpm-plugin-wpf_v
#   Non releases:
#     - latest
#     - vnext
# ---
# google/libphonenumber               100.0        111/111
#   Prefixes:
#     - libphonenumber-
#     - v
#   Non releases:
# ---
# microsoft/LightGBM                   90.0         18/20
#   Prefixes:
#     - v
#   Non releases:
#     - v1
#     - stable
# ---
# apache/incubator-brpc               100.0          6/6
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# dotnet/corefx                       100.0         76/76
#   Prefixes:
#     - System.Collections.Immutable-
#     - System.Reflection.Metadata-
#     - v
#   Non releases:
# ---
# aspnet/AspNetCore                   93.85         61/65
#   Prefixes:
#     - v
#     -
#   Non releases:
#     - beta6
#     - beta7
#     - beta8
#     - rc2
# ---
# thangchung/awesome-dotnet-core          0          0/0
#   Prefixes:
#   Non releases:
# ---
# aspnet/EntityFrameworkCore          100.0         54/54
#   Prefixes:
#     -
#     - rel/
#     - v
#   Non releases:
# ---
# aspnetboilerplate/aspnetboilerplate      100.0        182/182
#   Prefixes:
#     - v
#   Non releases:
# ---
# AvaloniaUI/Avalonia                 100.0          8/8
#   Prefixes:
#     -
#     - nuget-release-
#   Non releases:
# ---
# JamesNK/Newtonsoft.Json             100.0         61/61
#   Prefixes:
#     -
#   Non releases:
# ---
# NancyFx/Nancy                       100.0         47/47
#   Prefixes:
#     - v
#   Non releases:
# ---
# App-vNext/Polly                     100.0         26/26
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# dotnet/machinelearning              100.0         19/19
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# cefsharp/CefSharp                   100.0         88/88
#   Prefixes:
#     - v
#   Non releases:
# ---
# MahApps/MahApps.Metro               100.0         38/38
#   Prefixes:
#     -
#   Non releases:
# ---
# MonoGame/MonoGame                   100.0         14/14
#   Prefixes:
#     -
#     - v
#   Non releases:
# ---
# aspnet/Mvc                          100.0         49/49
#   Prefixes:
#     -
#     - rel/
#   Non releases:
# ---
# dotnet/orleans                       94.9         93/98
#   Prefixes:
#     - v
#     - orleans_
#     -
#   Non releases:
#     - Vsix-Templates-NuGet
#     - Template-NuGets-Restructure
#     - PostBuild.cmd
#     - geo-merge-baseline
#     - orleans-query-fork
# ---
# JeffreySu/WeiXinMPSDK               100.0         44/44
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# curl/curl                             0.0          0/184
#   Prefixes:
#   Non releases:
#     - curl-6_5
#     - curl-6_5_1
#     - curl-6_5_2
#     - v7_0_2beta
#     - curl-7_1_1
#     - curl-7_2
#     - curl-7_3
#     - curl-7_4_1
#     - curl-7_5
#     - pre-header-change
#     - curl-7_5_2
#     - curl_7_6-pre3
#     - curl-7_6-pre4
#     - curl-7_6
#     - curl-7_6_1-pre1
#     - curl-7_6_1-pre2
#     - curl-7_6_1-pre3
#     - curl-7_6_1
#     - curl-7_7_alpha2
#     - curl-7_7-beta1
#     - curl-7_7-beta2
#     - curl-7_7-beta3
#     - curl-7_7-beta5
#     - curl-7_7
#     - curl-7_7_1
#     - curl-7_7_2
#     - curl-7_7_3
#     - curl-7_8-pre2
#     - curl-7_8
#     - curl-7_8_1-pre3
#     - curl-7_8_1
#     - before_urldata_rename
#     - Curl_easy_1-1-7
#     - Curl_easy_1-1-8
#     - curl-7_9
#     - curl-7_9_1
#     - curl-7_9_2
#     - pre-host-cache
#     - curl-7_9_3-pre1
#     - curl-7_9_3-pre2
#     - curl-7_9_3-pre3
#     - curl-7_9_3
#     - curl-7_9_4
#     - curl-7_9_5-pre2
#     - curl-7_9_5-pre4
#     - curl-7_9_5
#     - curl-7_9_6
#     - curl-7_9_7-pre2
#     - curl-7_9_7
#     - curl-7_9_8
#     - curl-7_10
#     - curl-7_10_1
#     - curl-7_10_2
#     - curl-7_10_3
#     - curl-7_10_4
#     - curl-7_10_5
#     - curl-7_10_6
#     - pre-ares
#     - curl-7_10_7
#     - curl-7_10_8
#     - curl-7_11_0
#     - cares-1_1_0
#     - curl-7_11_1
#     - c-ares-1_2_0
#     - curl-7_11_2
#     - curl-7_12_0
#     - pre-aifix
#     - curl-7_12_1
#     - curl-7_12_2
#     - cares-1_2_1
#     - curl-7_12_3
#     - curl-7_13_0
#     - before_ftp_statemachine
#     - curl-7_13_1
#     - curl-7_13_2
#     - pre-sockfilt
#     - curl-7_14_0
#     - c-ares-1_3_0
#     - curl-7_14_1
#     - curl-7_15_0
#     - curl-7_15_1
#     - curl-7_15_2
#     - curl-7_15_3
#     - curl-7_15_4
#     - cares-1_3_1
#     - curl-7_15_5
#     - curl-7_15_6-prepipeline
#     - curl-7_16_0
#     - cares-1_3_2
#     - curl-7_16_1
#     - curl-7_16_2
#     - cares-1_4_0
#     - curl-7_16_3
#     - curl-7_16_4
#     - curl-7_17_0-preldapfix
#     - curl-7_17_0
#     - curl-7_17_1
#     - cares-1_5_0
#     - cares-1_5_1
#     - curl-7_18_0
#     - curl-7_18_1
#     - cares-1_5_2
#     - curl-7_18_2
#     - cares-1_5_3
#     - curl-7_19_0
#     - curl-7_19_1
#     - curl-7_19_2
#     - cares-1_6_0
#     - curl-7_19_3
#     - curl-7_19_4
#     - curl-7_19_5
#     - curl-7_19_6
#     - curl-7_19_7
#     - cares-1_7_0
#     - curl-7_20_0
#     - curl-7_20_1
#     - curl-7_21_0
#     - curl-7_21_1
#     - curl-7_21_2
#     - curl-7_21_3
#     - curl-7_21_4
#     - curl-7_21_5
#     - curl-7_21_6
#     - curl-7_21_7
#     - curl-7_22_0
#     - curl-7_23_0
#     - curl-7_23_1
#     - curl-7_24_0
#     - curl-7_25_0
#     - curl-7_26_0
#     - curl-7_27_0
#     - curl-7_28_0
#     - curl-7_28_1
#     - curl-7_29_0
#     - curl-7_30_0
#     - curl-7_31_0
#     - curl-7_32_0
#     - curl-7_33_0
#     - curl-7_34_0
#     - curl-7_35_0
#     - curl-7_36_0
#     - curl-7_37_0
#     - curl-7_37_0-annotated
#     - curl-7_37_1
#     - curl-7_38_0
#     - curl-7_39_0
#     - curl-7_40_0
#     - curl-7_41_0
#     - curl-7_42_0
#     - curl-7_42_1
#     - curl-7_43_0
#     - curl-7_44_0
#     - curl-7_45_0
#     - curl-7_46_0
#     - curl-7_47_0
#     - curl-7_47_1
#     - curl-7_48_0
#     - curl-7_49_0
#     - curl-7_49_1
#     - curl-7_50_0
#     - curl-7_50_1
#     - curl-7_50_2
#     - curl-7_50_3
#     - curl-7_51_0
#     - curl-7_52_0
#     - curl-7_52_1
#     - curl-7_53_0
#     - curl-7_53_1
#     - curl-7_54_0
#     - curl-7_54_1
#     - curl-7_55_0
#     - curl-7_55_1
#     - curl-7_56_0
#     - curl-7_56_1
#     - curl-7_57_0
#     - curl-7_58_0
#     - curl-7_59_0
#     - curl-7_60_0
#     - curl-7_61_0
#     - curl-7_61_1
#     - curl-7_62_0
#     - curl-7_63_0
#     - curl-7_64_0
#     - curl-7_64_1
# ---
# vurtun/nuklear                          0          0/0
#   Prefixes:
#   Non releases:
# ---
# openssl/openssl                       0.0          0/299
#   Prefixes:
#   Non releases:
#     - SSLeay_0_8_1b
#     - SSLeay_0_9_0b
#     - SSLeay_0_9_1b
#     - OpenSSL_0_9_1c
#     - OpenSSL_0_9_2b
#     - OpenSSL_0_9_3beta1
#     - OpenSSL_0_9_3beta2
#     - OpenSSL_0_9_3
#     - OpenSSL_0_9_3a
#     - OpenSSL_0_9_4
#     - OpenSSL_0_9_5beta1
#     - OpenSSL_0_9_5beta2
#     - OpenSSL_0_9_5a-beta1
#     - OpenSSL_0_9_5a-beta2
#     - OpenSSL_0_9_5a
#     - OpenSSL_0_9_5
#     - OpenSSL-engine-0_9_6-beta1
#     - OpenSSL-engine-0_9_6-beta2
#     - OpenSSL_0_9_6-beta3
#     - OpenSSL-engine-0_9_6-beta3
#     - OpenSSL-engine-0_9_6
#     - OpenSSL_0_9_6
#     - OpenSSL_0_9_6-beta1
#     - OpenSSL_0_9_6-beta2
#     - BEFORE_engine
#     - rsaref
#     - OpenSSL_0_9_6a-beta1
#     - OpenSSL-engine-0_9_6a-beta1
#     - OpenSSL_0_9_6a-beta2
#     - OpenSSL-engine-0_9_6a-beta2
#     - OpenSSL_0_9_6a-beta3
#     - OpenSSL-engine-0_9_6a-beta3
#     - OpenSSL-engine-0_9_6a
#     - OpenSSL_0_9_6a
#     - OpenSSL_0_9_6b
#     - OpenSSL-engine-0_9_6b
#     - OpenSSL_0_9_6c
#     - OpenSSL-engine-0_9_6c
#     - OpenSSL_0_9_6d-beta1
#     - OpenSSL-engine-0_9_6d-beta1
#     - OpenSSL_0_9_6d
#     - OpenSSL-engine-0_9_6d
#     - BEFORE_COMPAQ_PATCH
#     - AFTER_COMPAQ_PATCH
#     - OpenSSL_0_9_7-beta1
#     - OpenSSL_0_9_7-beta2
#     - OpenSSL_0_9_6e
#     - OpenSSL-engine-0_9_6e
#     - OpenSSL_0_9_7-beta3
#     - OpenSSL_0_9_6f
#     - OpenSSL-engine-0_9_6f
#     - OpenSSL_0_9_6g
#     - OpenSSL-engine-0_9_6g
#     - OpenSSL_0_9_7-beta4
#     - OpenSSL_0_9_6h
#     - OpenSSL-engine-0_9_6h
#     - OpenSSL_0_9_7-beta5
#     - STATE_before_zlib
#     - STATE_after_zlib
#     - OpenSSL_0_9_7-beta6
#     - OpenSSL_0_9_7
#     - OpenSSL_0_9_7a
#     - OpenSSL_0_9_6i
#     - OpenSSL-engine-0_9_6i
#     - OpenSSL_0_9_6j
#     - OpenSSL_0_9_7b
#     - OpenSSL-engine-0_9_6j
#     - OpenSSL_0_9_7c
#     - OpenSSL_0_9_6k
#     - OpenSSL-engine-0_9_6k
#     - BEN_FIPS_TEST_1
#     - BEN_FIPS_TEST_2
#     - BEN_FIPS_TEST_3
#     - OpenSSL_0_9_6l
#     - OpenSSL-engine-0_9_6l
#     - BEN_FIPS_TEST_4
#     - BEN_FIPS_TEST_5
#     - LEVITTE_before_const
#     - LEVITTE_after_const
#     - OpenSSL_0_9_6m
#     - OpenSSL-engine-0_9_6m
#     - OpenSSL_0_9_7d
#     - OpenSSL_0_9_7e
#     - BEN_FIPS_TEST_6
#     - BEN_FIPS_TEST_7
#     - OpenSSL_0_9_7f
#     - OpenSSL_0_9_7g
#     - OpenSSL_0_9_8-beta1
#     - OpenSSL_0_9_8-beta2
#     - BEN_FIPS_TEST_8
#     - OpenSSL_0_9_8-beta3
#     - OpenSSL_0_9_8-beta4
#     - FIPS_TEST_9
#     - OpenSSL_0_9_8-beta5
#     - OpenSSL_0_9_8-beta6
#     - FIPS_TEST_10
#     - OpenSSL_0_9_8
#     - OpenSSL_0_9_7h
#     - OpenSSL_0_9_8a
#     - OpenSSL_0_9_7i
#     - OpenSSL_FIPS_1_0
#     - OpenSSL_0_9_8b
#     - OpenSSL_0_9_7j
#     - OpenSSL_0_9_7k
#     - OpenSSL_0_9_8c
#     - OpenSSL_0_9_8d
#     - OpenSSL_0_9_7l
#     - OpenSSL_0_9_8e
#     - OpenSSL_0_9_7m
#     - FIPS_098_TEST_1
#     - FIPS_098_TEST_2
#     - FIPS_098_TEST_3
#     - FIPS_098_TEST_4
#     - FIPS_098_TEST_5
#     - FIPS_098_TEST_6
#     - FIPS_098_TEST_7
#     - FIPS_098_TEST_8
#     - OpenSSL-fips-1_2_0
#     - OpenSSL_0_9_8f
#     - OpenSSL_0_9_8g
#     - OpenSSL_0_9_8h
#     - OpenSSL_0_9_8i
#     - OpenSSL_0_9_8j
#     - OpenSSL_0_9_8k
#     - OpenSSL_1_0_0-beta1
#     - OpenSSL_1_0_0-beta2
#     - OpenSSL_1_0_0-beta3
#     - OpenSSL_0_9_8l
#     - OpenSSL_1_0_0-beta4
#     - OpenSSL_1_0_0-beta5
#     - OpenSSL_0_9_8m-beta1
#     - OpenSSL_0_9_8m
#     - OpenSSL_0_9_8n
#     - OpenSSL_1_0_0
#     - OpenSSL_1_0_0a
#     - OpenSSL_0_9_8o
#     - OpenSSL_1_0_0b
#     - OpenSSL_0_9_8p
#     - OpenSSL_1_0_0c
#     - OpenSSL_0_9_8q
#     - OpenSSL_0_9_8r
#     - OpenSSL_1_0_0d
#     - OpenSSL_1_0_0e
#     - OpenSSL-fips-1_2_1
#     - OpenSSL-fips-1_2_2
#     - OpenSSL-fips-1_2_3
#     - OpenSSL-fips-2_0-rc1
#     - OpenSSL-fips-2_0-rc2
#     - OpenSSL-fips-2_0-rc3
#     - OpenSSL-fips-2_0-rc4
#     - OpenSSL-fips-2_0-rc5
#     - OpenSSL-fips-2_0-rc6
#     - OpenSSL-fips-2_0-rc7
#     - OpenSSL_1_0_1-beta1
#     - OpenSSL-fips-2_0-rc8
#     - OpenSSL_1_0_0f
#     - OpenSSL_0_9_8s
#     - OpenSSL_0_9_8t
#     - OpenSSL_1_0_0g
#     - OpenSSL-fips-2_0
#     - OpenSSL-fips-2_0-rc9
#     - OpenSSL_1_0_1-beta2
#     - OpenSSL_1_0_1-beta3
#     - OpenSSL_0_9_8u
#     - OpenSSL_1_0_0h
#     - OpenSSL_1_0_1
#     - OpenSSL_1_0_0i
#     - OpenSSL_0_9_8v
#     - OpenSSL_1_0_1a
#     - OpenSSL_0_9_8w
#     - OpenSSL_1_0_1b
#     - OpenSSL_0_9_8x
#     - OpenSSL_1_0_0j
#     - OpenSSL_1_0_1c
#     - OpenSSL-fips-2_0_1
#     - OpenSSL-fips-2_0-pl1
#     - OpenSSL_0_9_8y
#     - OpenSSL_1_0_1d
#     - OpenSSL_1_0_0k
#     - OpenSSL_1_0_1e
#     - OpenSSL-fips-2_0_2
#     - OpenSSL-fips-2_0_3
#     - OpenSSL-fips-2_0_5
#     - OpenSSL-fips-2_0_4
#     - OpenSSL_1_0_1f
#     - OpenSSL_1_0_0l
#     - OpenSSL_1_0_2-beta1
#     - OpenSSL_1_0_1g
#     - OpenSSL-fips-2_0_6
#     - OpenSSL_0_9_8za
#     - OpenSSL_1_0_0m
#     - OpenSSL_1_0_1h
#     - OpenSSL-fips-2_0_7
#     - OpenSSL_1_0_2-beta2
#     - OpenSSL_1_0_1i
#     - OpenSSL_1_0_0n
#     - OpenSSL_0_9_8zb
#     - OpenSSL_1_0_2-beta3
#     - OpenSSL_0_9_8zc
#     - OpenSSL_1_0_0o
#     - OpenSSL_1_0_1j
#     - OpenSSL-fips-2_0_8
#     - OpenSSL_1_0_1k
#     - OpenSSL_1_0_0p
#     - OpenSSL_0_9_8zd
#     - OpenSSL_1_0_1l
#     - OpenSSL_1_0_0q
#     - OpenSSL_0_9_8ze
#     - OpenSSL_1_0_2
#     - master-post-reformat
#     - master-post-auto-reformat
#     - master-pre-auto-reformat
#     - master-pre-reformat
#     - OpenSSL_1_0_2-post-reformat
#     - OpenSSL_1_0_2-post-auto-reformat
#     - OpenSSL_1_0_2-pre-auto-reformat
#     - OpenSSL_1_0_2-pre-reformat
#     - OpenSSL_1_0_1-post-reformat
#     - OpenSSL_1_0_1-post-auto-reformat
#     - OpenSSL_1_0_1-pre-auto-reformat
#     - OpenSSL_1_0_1-pre-reformat
#     - OpenSSL_1_0_0-post-reformat
#     - OpenSSL_1_0_0-post-auto-reformat
#     - OpenSSL_1_0_0-pre-auto-reformat
#     - OpenSSL_1_0_0-pre-reformat
#     - OpenSSL_0_9_8-post-reformat
#     - OpenSSL_0_9_8-post-auto-reformat
#     - OpenSSL_0_9_8-pre-auto-reformat
#     - OpenSSL_0_9_8-pre-reformat
#     - OpenSSL_1_0_2a
#     - OpenSSL_1_0_1m
#     - OpenSSL_1_0_0r
#     - OpenSSL_0_9_8zf
#     - OpenSSL-fips-2_0_9
#     - OpenSSL_1_0_2b
#     - OpenSSL_1_0_1n
#     - OpenSSL_1_0_0s
#     - OpenSSL_0_9_8zg
#     - OpenSSL_1_0_2c
#     - OpenSSL_1_0_1o
#     - OpenSSL_1_0_2d
#     - OpenSSL_1_0_1p
#     - OpenSSL_1_0_2e
#     - OpenSSL_1_0_1q
#     - OpenSSL_1_0_0t
#     - OpenSSL_0_9_8zh
#     - OpenSSL_1_1_0-pre1
#     - OpenSSL_1_1_0-pre2
#     - OpenSSL_1_0_2f
#     - OpenSSL_1_0_1r
#     - OpenSSL-fips-2_0_10
#     - OpenSSL-fips-2_0_11
#     - OpenSSL-fips-2_0_12
#     - OpenSSL_1_1_0-pre3
#     - OpenSSL_1_0_2g
#     - OpenSSL_1_0_1s
#     - OpenSSL_1_1_0-pre4
#     - OpenSSL_1_1_0-pre5
#     - OpenSSL_1_0_2h
#     - OpenSSL_1_0_1t
#     - OpenSSL_1_1_0-pre6
#     - OpenSSL_1_1_0
#     - OpenSSL_1_1_0a
#     - OpenSSL_1_0_2i
#     - OpenSSL_1_0_1u
#     - OpenSSL_1_1_0b
#     - OpenSSL_1_0_2j
#     - OpenSSL_1_1_0c
#     - OpenSSL-fips-2_0_13
#     - OpenSSL_1_1_0d
#     - OpenSSL_1_0_2k
#     - OpenSSL_1_1_0e
#     - OpenSSL-fips-2_0_14
#     - OpenSSL_1_1_0f
#     - OpenSSL_1_0_2l
#     - OpenSSL-fips-2_0_15
#     - OpenSSL-fips-2_0_16
#     - OpenSSL_1_1_0g
#     - OpenSSL_1_0_2m
#     - OpenSSL_1_0_2n
#     - OpenSSL_1_1_1-pre1
#     - OpenSSL_1_1_1-pre2
#     - OpenSSL_1_1_1-pre3
#     - OpenSSL_1_1_0h
#     - OpenSSL_1_0_2o
#     - OpenSSL_1_1_1-pre4
#     - OpenSSL_1_1_1-pre5
#     - OpenSSL_1_1_1-pre6
#     - OpenSSL_1_1_1-pre7
#     - OpenSSL_1_1_1-pre8
#     - OpenSSL_1_1_0i
#     - OpenSSL_1_0_2p
#     - OpenSSL_1_1_1-pre9
#     - OpenSSL_1_1_1
#     - OpenSSL_1_1_1a
#     - OpenSSL_1_1_0j
#     - OpenSSL_1_0_2q
#     - OpenSSL_1_1_1b
#     - OpenSSL_1_0_2r
# ---
# radareorg/radare2                   95.77         68/71
#   Prefixes:
#     -
#     - radare2-
#   Non releases:
#     - git
#     - radare2-windows-nightly
#     - termux
# ---
# nothings/stb                            0          0/0
#   Prefixes:
#   Non releases:
# ---
# andlabs/libui                       42.86          3/7
#   Prefixes:
#     - alpha
#   Non releases:
#     - alpha1
#     - alpha2
#     - alpha3
#     - alpha4
# ---
# cloudwu/skynet                      100.0         46/46
#   Prefixes:
#     - v
#   Non releases:
# ---
# Tencent/wcdb                        100.0         14/14
#   Prefixes:
#     - v
#   Non releases:
# ---
# jedisct1/libsodium                  100.0         34/34
#   Prefixes:
#     -
#   Non releases:
# ---
# libgit2/libgit2                     100.0         74/74
#   Prefixes:
#     - v
#   Non releases:
# ---
# liuliu/ccv                              0          0/0
#   Prefixes:
#   Non releases:
# ---
# cesanta/mongoose                    100.0         34/34
#   Prefixes:
#     -
#   Non releases:
# ---
# glfw/glfw                           100.0         11/11
#   Prefixes:
#     -
#   Non releases:
# ---
# videolan/vlc                         98.0         49/50
#   Prefixes:
#     -
#   Non releases:
#     - svn-trunk
# ---
# libevent/libevent                   100.0         56/56
#   Prefixes:
#     - release-
#   Non releases:
# ---
# lpereira/lwan                       100.0          2/2
#   Prefixes:
#     - v
#   Non releases:
# ---
# zserge/webview                      100.0          1/1
#   Prefixes:
#     -
#   Non releases:
# ---
# nanomsg/nanomsg                     100.0         19/19
#   Prefixes:
#     -
#   Non releases:
# ---
# laruence/yaf                        100.0         24/24
#   Prefixes:
#     - yaf-
#   Non releases:
# ---
# espressif/esp-idf                   100.0         54/54
#   Prefixes:
#     - v
#   Non releases:
# ---
# cinder/Cinder                       100.0          9/9
#   Prefixes:
#     - v
#   Non releases:
# ---
# rails/rails                         99.73        364/365
#   Prefixes:
#     - v
#   Non releases:
#     - list
# ---
# rapid7/metasploit-framework         59.12        324/548
#   Prefixes:
#     -
#     - v
#   Non releases:
#     - 20111205000001
#     - 20111213184834
#     - 20111214013016
#     - 20111219000001
#     - 20111227000001
#     - 20120103000001
#     - 2012022901
#     - 2012050901
#     - 2012051603
#     - 2012052303
#     - 2012071701
#     - 2012091201
#     - 2012091202
#     - 2012091901
#     - 2012092601
#     - 2012100301
#     - 2012101001
#     - 2012111401
#     - 2012112801
#     - 2012120701
#     - 2012121201
#     - 2012121901
#     - 2012121902
#     - 2012121903
#     - 2013010201
#     - 2013010202
#     - 2013010901
#     - 2013010902
#     - sprint-A01
#     - 2013011601
#     - 2013012301
#     - sprint-A02
#     - 2013013001
#     - 2013020601
#     - sprint-A03
#     - 2013021301
#     - 2013022001
#     - sprint-A04
#     - 2013022701
#     - 2013031101
#     - sprint-A05
#     - 2013032001
#     - sprint-A06
#     - 2013032701
#     - 2013040301
#     - 2013041001
#     - sprint-A07
#     - 2013041701
#     - 2013042401
#     - sprint-B00
#     - 2013050101
#     - sprint-B01
#     - 2013050801
#     - sprint-B02
#     - 2013052201
#     - 2013052901
#     - sprint-B03
#     - 2013060501
#     - 2013061201
#     - sprint-B04
#     - 2013061901
#     - 2013062601
#     - sprint-B05
#     - 2013070301
#     - 2013071001
#     - 2013071701
#     - sprint-B06
#     - 2013072401
#     - 2013080701
#     - sprint-C00
#     - 2013082102
#     - sprint-C01
#     - 2013090401
#     - hard-tabs
#     - sprint-C02
#     - 2013091801
#     - sprint-C03
#     - 2013092501
#     - 2013100201
#     - sprint-C04
#     - 2013100901
#     - 2013101601
#     - sprint-C05
#     - 2013103001
#     - cthulhutp
#     - 2013110601
#     - 2013111301
#     - sprint-C06
#     - 2013112001
#     - 2013112701
#     - sprint-D00
#     - 2013120401
#     - sprint-D01
#     - 2013121101
#     - 2013121801
#     - sprint-D02
#     - 2014010101
#     - sprint-D03
#     - 2014010801
#     - 2014011501
#     - sprint-D04
#     - 2014012201
#     - sprint-D05
#     - 2014020501
#     - 2014020502
#     - 2014021201
#     - sprint-D06
#     - 2014021901
#     - 2014022601
#     - sprint-D07
#     - 2014030501
#     - 2014031201
#     - sprint-D08
#     - 2014031901
#     - 2014032601
#     - sprint-E00
#     - 2014040901
#     - 2014040906
#     - 2014041601
#     - sprint-E01
#     - 2014042301
#     - 2014043001
#     - sprint-E02
#     - 2014050701
#     - 2014051401
#     - sprint-E03
#     - 2014052101
#     - 2014052801
#     - sprint-E04
#     - 2014060401
#     - 2014060501
#     - 2014061101
#     - sprint-E05
#     - 2014061801
#     - 2014062501
#     - sprint-E06
#     - 2014070201
#     - 2014070901
#     - sprint-E07
#     - 2014071601
#     - 2014072301
#     - 2014081301
#     - 2014082003
#     - 2014082101
#     - sprint-F00
#     - 2014082701
#     - 2014090301
#     - sprint-F01
#     - 2014091001
#     - sprint-F02
#     - 2014092401
#     - 2014092501
#     - 2014092602
#     - 2014100101
#     - 2014100201
#     - sprint-F03
#     - 2014100901
#     - 2014101501
#     - 2014101601
#     - sprint-F04
#     - 2014102201
#     - 2014102901
#     - sprint-F05
#     - 2014111001
#     - show
#     - sprint-F06
#     - 2014111901
#     - 2014120301
#     - sprint-F07
#     - 2014121601
#     - sprint-F08
#     - 2014122301
#     - sprint-G00
#     - sprint-F09
#     - 2015011401
#     - sprint-G01
#     - 2015012901
#     - 2015013101
#     - sprint-G02
#     - blog-20150205
#     - blog-20150212
#     - 2015021201
#     - sprint-G03
#     - blog-20150219
#     - 2015021901
#     - 2015022301
#     - blog-20150226
#     - 2015022302
#     - 2015022303
#     - sprint-G04
#     - blog-20150305
#     - 2015030501
#     - blog-20150311
#     - 2015031001
#     - sprint-G05
#     - sprint-G06
#     - 2015031701
#     - blog-20150320
#     - blog-20150327
#     - 2015032401
#     - sprint-G07
#     - 2015040202
#     - sprint-G08
#     - 2015041601
#     - 2015042001
#     - blog-20150506
#     - 2015050601
#     - 2015051401
#     - blog-20150522
#     - blog-20150528
#     - blog-20150604
#     - blog-20150612
#     - blog-20150618
#     - blog-20150626
#     - 2015063001
#     - blog-20150702
#     - 2015070901
#     - 2015071402
#     - blog-20150723
#     - blog-20150730
#     - blog-20150813
#     - 20150827
#     - blog-20150827
#     - blog-20151007
# ---
# imathis/octopress                   100.0          1/1
#   Prefixes:
#     - v
#   Non releases:
# ---
# ruby-grape/grape                    100.0         51/51
#   Prefixes:
#     - v
#   Non releases:
# ---
# teamcapybara/capybara               100.0        134/134
#   Prefixes:
#     -
#   Non releases:
# ---
# activeadmin/activeadmin             91.07         51/56
#   Prefixes:
#     - v
#   Non releases:
#     - form-builder-spec-pass-w-deprecations
#     - pre-PR-3486
#     - form-builder-spec-pass-w-deprecations2
#     - post-3560
#     - crm-ok
# ---
# resque/resque                        98.7         76/77
#   Prefixes:
#     - v
#   Non releases:
#     - semver
# ---
# carrierwaveuploader/carrierwave      100.0         59/59
#   Prefixes:
#     - v
#   Non releases:
# ---
# faker-ruby/faker                    100.0         55/55
#   Prefixes:
#     - v
#     -
#     - v.
#   Non releases:
# ---
# thoughtbot/factory_bot              88.24         75/85
#   Prefixes:
#     - v
#   Non releases:
#     - rel_1-0
#     - rel_1-1
#     - rel_1-1-1
#     - rel_1-1-2
#     - rel_1-1-3
#     - rel_1-1-4
#     - rel_1-1-5
#     - rel_1-2-0
#     - rel_1-2-1
#     - rel_1-2-2
# ---
# puppetlabs/puppet                   99.72        352/353
#   Prefixes:
#     - release-
#     -
#     - puppet-
#     - upstream/
#     - debian/
#     - tags/
#   Non releases:
#     - BetaOne
# ---
# mislav/will_paginate                100.0         49/49
#   Prefixes:
#     -
#     - v
#   Non releases:
# ---
# github/scientist                    100.0         12/12
#   Prefixes:
#     - v
#   Non releases:
# ---
# github/markup                       100.0         62/62
#   Prefixes:
#     - v
#   Non releases:
# ---
# lostisland/faraday                  100.0         65/65
#   Prefixes:
#     - v
#   Non releases:
# ---
# fog/fog                             100.0        173/173
#   Prefixes:
#     - v
#   Non releases:
# ---
# avelino/awesome-go                      0          0/0
#   Prefixes:
#   Non releases:
# ---
# gohugoio/hugo                       100.0         99/99
#   Prefixes:
#     - v
#   Non releases:
# ---
# gin-gonic/gin                       100.0         17/17
#   Prefixes:
#     - v
#   Non releases:
# ---
# astaxie/beego                       100.0         28/28
#   Prefixes:
#     - v
#   Non releases:
# ---
# kataras/iris                        95.56         43/45
#   Prefixes:
#     - v
#     -
#   Non releases:
#     - v4
#     - v5
# ---
# jinzhu/gorm                         100.0         13/13
#   Prefixes:
#     - v
#   Non releases:
# ---
# labstack/echo                       100.0         89/89
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# go-kit/kit                          100.0          9/9
#   Prefixes:
#     - v
#   Non releases:
# ---
# tsenart/vegeta                      100.0        167/167
#   Prefixes:
#     - cli/v
#     - lib/v
#     - v
#   Non releases:
# ---
# revel/revel                         100.0         23/23
#   Prefixes:
#     - v
#   Non releases:
# ---
# go-martini/martini                  100.0          3/3
#   Prefixes:
#     - v
#   Non releases:
# ---
# micro/go-micro                      100.0         59/59
#   Prefixes:
#     - v
#   Non releases:
# ---
# gocolly/colly                       100.0          3/3
#   Prefixes:
#     - v
#   Non releases:
# ---
# esimov/caire                        100.0          8/8
#   Prefixes:
#     - v
#     -
#   Non releases:
# ---
# stretchr/testify                    100.0         11/11
#   Prefixes:
#     - v
#   Non releases:
# ---
# golang/groupcache                       0          0/0
#   Prefixes:
#   Non releases:
# ---

# %%
f_releases = []
index = 0
last_project = None
for name,project_data in projects_data.items():
    if "percent_releases" in project_data and project_data["percent_releases"] > 90:
        project = project_data["data"]
        feature_releases = project.get_releases(skip_patches=True, skip_pre=True)
        feature_releases = sorted(feature_releases, key=lambda r: r.version)
        last_release = None
        for release in feature_releases:
            if release.patches:
                last_patch = release.patches[-1]
                maintenance_length = last_patch.time - release.time
                num_patches = len(release.patches)
            else:
                maintenance_length = pd.to_timedelta(0)
                last_patch = None
                num_patches = 0
            if release.pre_releases:
                first_pre_release = release.pre_releases[0]
                stage_length = release.time - first_pre_release.time 
                num_pre_releases = len(release.pre_releases)
            else:
                first_pre_release = None
                stage_length = pd.to_timedelta(0)
                num_pre_releases = 0

            if last_release and last_release.major != release.major:
                f_releases[index-1]["is_last_minor"] = True
            last_release = release
            
            if last_project and last_project != name:
                f_releases.pop()
                index -= 1
            last_project = name
            index += 1

            f_releases.append({
                "project": project.name,
                "release": release.name,
                "version": release.version,
                "is_last_minor": False,
                "time": pd.to_datetime(release.time, utc=True),
                "developtment_length": release.length,
                "last_patch": last_patch, 
                "last_patch_time": pd.to_datetime(last_patch.time, utc=True) if last_patch else None, 
                "maintenance_length": maintenance_length,
                "n_patches": num_patches,
                
                #"num_pre_releases": num_pre_releases,
                #"num_patches": num_patches,
                #"first_pre_release": first_pre_release, 
                #"stage_length": stage_length
            })

f_releases = pd.DataFrame(f_releases)    
f_releases = f_releases.sort_values(by=["project", "version"])

f_releases["maintenance_secs"] = f_releases["maintenance_length"].dt.total_seconds()
f_releases["time"] = f_releases["time"].dt.tz_convert(None)
f_releases["last_patch_time"] = f_releases["last_patch_time"].dt.tz_convert(None)

# remove releases sem manutenção
# f_releases = f_releases[f_releases.maintenance_length > pd.to_timedelta(0)].copy()

f_releases.to_excel("feature_releases_ds.xlsx")
f_releases.head(200)

# %%
fig = plt.figure()                                                                                                                                                                                                                                                             
ax = fig.add_subplot(111)

f_releases.boxplot("maintenance_length", by="is_last_minor", ax=ax)

def timeTicks(x, pos):
    return str(pd.to_timedelta(x))
    #d = datetime.timedelta(seconds=x)
    #return str(d)
    #return x / 60 / 60 / 24
formatter = matplotlib.ticker.FuncFormatter(timeTicks)                                                                                                                                                                                                                         
ax.yaxis.set_major_formatter(formatter)

plt.suptitle("")
plt.tight_layout()

# %% [markdown]
# ## Statistical Test

# %% [markdown]
# ## Analise pareada por Projeto

# %%
gr = f_releases.groupby(["project","is_last_minor"]).mean()

# %%
gr.shape

# %%
(gr.groupby(level=[0]).size() == 2)

# %%
# gr = gr.drop(index="akveo/ngx-admin")
gr = gr.drop(index="apache/dubbo")
gr = gr.drop(index="facebook/react-native")

# %%
gr.to_excel("pareado.xlsx")

# %%
gr.shape

# %%
a = gr.xs(True, level=1)["maintenance_secs"]

# %%
b = gr.xs(False, level=1)["maintenance_secs"]

# %%
wilcoxon(a,b)

# %% [markdown]
# ## Análise de todas as releases

# %%
a = f_releases[f_releases["is_last_minor"] == True]["maintenance_secs"]

# %%
b = f_releases[f_releases["is_last_minor"] == False]["maintenance_secs"]

# %%
ranksums(a,b)

# %% [markdown]
# ## Análise intra-projetos

# %%
intr_project_ds = pd.DataFrame()
intr_project_ds["project"] = f_releases["project"].unique()
intr_project_ds["n_feature_release"] = intr_project_ds["project"].apply(lambda project_name: len(f_releases[f_releases["project"] == project_name]))
intr_project_ds["n_last_minor"] = intr_project_ds["project"].apply(lambda project_name: len(f_releases[(f_releases["project"] == project_name) & (f_releases["is_last_minor"] == True)]))
intr_project_ds = intr_project_ds[intr_project_ds.n_last_minor > 0]
intr_project_ds["p-value"] = intr_project_ds["project"].apply(lambda project_name: ranksums(
    f_releases[(f_releases["is_last_minor"] == True) & (f_releases["project"] == project_name)]["maintenance_secs"],
    f_releases[(f_releases["is_last_minor"] == False) & (f_releases["project"] == project_name)]["maintenance_secs"]
)[1])
intr_project_ds["h0"] = intr_project_ds["p-value"] >= 0.05
intr_project_ds.to_excel("intr_project_ds.xlsx")
intr_project_ds

# %%
project_ds.head()

# %%
project_ds = f_releases.groupby(["project"])["project"]
a

# %%
f_releases.release.count() + f_releases.num_patches.sum() + f_releases.num_pre_releases.sum()

# %%
gr.to_csv("gr_releases.csv", sep=";")

# %%
f_releases.to_csv("releases.csv", sep=";")

# %%
f_releases[f_releases.is_last_minor == False]

# %%
for project in projects.values():
    feature_releases = project.get_releases(skip_patches=True, skip_pre=True)
    print(f"{project.name:20}")
    print(f"{'release':10} {'time':28} {'length':20} {'last_patch':10} {'maintenance':20}")
    for release in feature_releases:
        if release.name.startswith("ng") or release.name.startswith("zone"):
            continue
        if release.patches:
            last_patch = release.patches[-1]
            maintenance = last_patch.time - release.time
        else:
            maintenance = None
            last_patch = None
        if release.pre_releases:
            first_pre = release.pre_releases[0]
        else:
            first_pre = None
          
        print(f"{release.name:10} {str(release.time):28} {str(release.length):20} {str(first_pre):15} {str(last_patch):10} {str(maintenance):20}")

# %%
tags = project.tags
nom_release_tags = [tag for tag in project.tags if not tag.release or tag.name.startswith("zone") or tag.name.startswith("ngcontainer")]
percent_releases = round(100*(1-len(nom_release_tags)/len(tags)),2)
percent_releases

# %%
nom_release_tags

# %%
feature_releases = project.get_releases(skip_patches=True, skip_pre=True)
print(f"{'release':10} {'time':28} {'length':20} {'last_patch':10} {'maintenance':20}")
for release in feature_releases:
    if release.name.startswith("ng") or release.name.startswith("zone"):
        continue
    if release.patches:
        last_patch = release.patches[-1]
        maintenance = last_patch.time - release.time
    else:
        last_patch = None
    print(f"{release.name:10} {str(release.time):28} {str(release.length):20} {str(last_patch):10} {str(maintenance):20}")

# %%
release.patches[-1]

# %%
releases = project.get_releases(skip_pre=True)
for release in releases:
    if release.is_patch():
        print(f"{release.name:20} {str(release.time):30} {str(release.length):10}")
