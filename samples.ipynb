# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import re

pd.options.display.max_rows = 500
pd.options.display.max_columns = 50

# %%
releases = pd.read_pickle('samples2.zip')

# %%
releases[releases.time_precision < 1][["commits", "range_commits",'time_commits',"base_releases","range_base_releases", "time_precision", "range_precision", "time_recall", "range_recall"]]
# Out:
#                                    commits  range_commits  time_commits  \
# project                   name
# laravel/framework         v7.9.2         5              6             6
# nodejs/node               v0.11.1       69            123           122
# cefsharp/CefSharp         v1.21.0        5              6             6
# sebastianbergmann/phpunit 5.0.10         7             13            13
#
#                                         base_releases range_base_releases  \
# project                   name
# laravel/framework         v7.9.2   [v7.9.1, v6.18.11]            [v7.9.1]
# nodejs/node               v0.11.1  [v0.10.4, v0.11.0]           [v0.11.0]
# cefsharp/CefSharp         v1.21.0             [v0.12]           [v1.19.0]
# sebastianbergmann/phpunit 5.0.10      [5.0.9, 4.8.19]             [5.0.9]
#
#                                    time_precision  range_precision  \
# project                   name
# laravel/framework         v7.9.2         0.833333         0.833333
# ...

# %%
releases[releases.range_precision < 1][["commits", "range_commits",'time_commits',"base_releases","range_base_releases", "time_precision", "range_precision", "time_recall", "range_recall"]]
# Out:
#                                    commits  range_commits  time_commits  \
# project                   name
# laravel/framework         v7.9.2         5              6             6
# nodejs/node               v0.11.1       69            123           122
# cefsharp/CefSharp         v1.21.0        5              6             6
# sebastianbergmann/phpunit 5.0.10         7             13            13
#
#                                         base_releases range_base_releases  \
# project                   name
# laravel/framework         v7.9.2   [v7.9.1, v6.18.11]            [v7.9.1]
# nodejs/node               v0.11.1  [v0.10.4, v0.11.0]           [v0.11.0]
# cefsharp/CefSharp         v1.21.0             [v0.12]           [v1.19.0]
# sebastianbergmann/phpunit 5.0.10      [5.0.9, 4.8.19]             [5.0.9]
#
#                                    time_precision  range_precision  \
# project                   name
# laravel/framework         v7.9.2         0.833333         0.833333
# ...

# %%
releases[releases.time_recall < 1][["commits", "range_commits",'time_commits',"base_releases","range_base_releases", "time_precision", "range_precision", "time_recall", "range_recall"]]
# Out:
#                                          commits  range_commits  time_commits  \
# project                   name
# elastic/elasticsearch     v5.6.6              55             55            46
# sinatra/sinatra           1.4.0              498            498             3
# elastic/elasticsearch     v5.6.7              34             34            10
# etcd-io/etcd              v0.3.0             315            315           284
# ansible/ansible           v2.9.1             127            127           126
# sebastianbergmann/phpunit 7.0.0              219            219             4
# facebook/react            v15.6.0            196            196           147
# hashicorp/vagrant         v0.6.0             231            231            65
# ant-design/ant-design     1.6.4               39             39            38
# nginx/nginx               release-1.5.4       37             37            33
# alibaba/fastjson          1.1.157            534            534           510
# ...
