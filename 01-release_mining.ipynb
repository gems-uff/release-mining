# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import re

# %%
pd.options.display.max_rows = 500

# %%
import os
import sys

releasy_module = os.path.abspath(os.path.join('..','..','..','dev','releasy2'))
if releasy_module not in sys.path:
    sys.path.insert(0, releasy_module)
    
import releasy
from releasy.miner_git import GitVcs
from releasy.miner import TagReleaseMiner, PathCommitMiner, RangeCommitMiner, TimeCommitMiner, VersionReleaseMatcher, VersionReleaseSorter, TimeReleaseSorter, VersionWoPreReleaseMatcher

# %%
projects = pd.read_pickle('projects.zip')

# %%
releases = pd.DataFrame(columns=[
    "project","name", "lang","head", "time", "commits",
    "range_commits", "range_tpos", "range_fpos","range_fneg",
    "time_commits", "time_tpos", "time_fpos","time_fneg"])
    
count = 0
for i,project in enumerate(projects.itertuples()):
    path = os.path.abspath(os.path.join('..','..','..','repos2',project.name))
    
    try:
        print(f"{i+1:3} {project.name}")
        vcs = GitVcs(path)
        release_matcher = VersionWoPreReleaseMatcher()
        time_release_sorter = TimeReleaseSorter()
        version_release_sorter = VersionReleaseSorter()

        time_release_miner = TagReleaseMiner(vcs, release_matcher, time_release_sorter)
        time_release_set = time_release_miner.mine_releases()

        
        version_release_miner = TagReleaseMiner(vcs, release_matcher, version_release_sorter)
        version_release_set = version_release_miner.mine_releases()

        path_miner = PathCommitMiner(vcs, time_release_set)
        range_miner = RangeCommitMiner(vcs, version_release_set)
        time_miner = TimeCommitMiner(vcs, version_release_set)
    
        print(f" - parsing by path")
        path_release_set = path_miner.mine_commits()
        print(f" - parsing by time")
        time_release_set = time_miner.mine_commits()
        print(f" - parsing by range")
        range_release_set = range_miner.mine_commits()
        
        print("")
        stats = []
        for release in version_release_set:
            path_commits = set(path_release_set[release.name].commits)
            range_commits = set(range_release_set[release.name].commits)
            time_commits = set(time_release_set[release.name].commits)
    
            stats.append({
                "project": project.name,
                "name": release.name,
                "lang": project.lang,
                "head": release.head,
                "time": release.time,
                "commits": len(path_commits),
                "range_commits": len(range_commits),
                "range_tpos": len(path_commits & range_commits),
                "range_fpos": len(range_commits - path_commits),
                "range_fneg": len(path_commits - range_commits),
                "time_commits": len(time_commits),
                "time_tpos": len(path_commits & time_commits),
                "time_fpos": len(time_commits - path_commits),
                "time_fneg": len(path_commits - time_commits)
            })
        releases = releases.append(pd.DataFrame(stats))
    except Exception as e:
        print(f" - error: {e}")
    
releases_bkp = releases.copy()
# Out:
#   1 vuejs/vue
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#   2 facebook/react
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#   3 twbs/bootstrap
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#   4 d3/d3
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#   5 facebook/react-native
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#   6 facebook/create-react-app
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#   7 nodejs/node
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#   8 mrdoob/three.js
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#   9 mui-org/material-ui
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  10 angular/angular.js
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  11 microsoft/vscode
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  12 denoland/deno
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  13 angular/angular
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  14 microsoft/TypeScript
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  15 ant-design/ant-design
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  16 reduxjs/redux
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  17 storybookjs/storybook
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  18 ionic-team/ionic-framework
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  19 grafana/grafana
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  20 facebook/jest
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  21 elastic/elasticsearch
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  22 spring-projects/spring-boot
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  23 ReactiveX/RxJava
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  24 spring-projects/spring-framework
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  25 google/guava
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  26 square/okhttp
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  27 apache/dubbo
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  28 PhilJay/MPAndroidChart
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  29 bumptech/glide
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  30 zxing/zxing
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  31 ytdl-org/youtube-dl
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  32 pallets/flask
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  33 django/django
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  34 keras-team/keras
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  35 ansible/ansible
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  36 psf/requests
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  37 scikit-learn/scikit-learn
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  38 scrapy/scrapy
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  39 home-assistant/core
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  40 soimort/you-get
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  41 laravel/laravel
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  42 fzaninotto/Faker
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  43 symfony/symfony
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  44 composer/composer
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  45 laravel/framework
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  46 guzzle/guzzle
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  47 bcit-ci/CodeIgniter
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  48 Seldaek/monolog
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  49 sebastianbergmann/phpunit
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  50 briannesbitt/Carbon
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  51 electron/electron
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  52 opencv/opencv
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  53 bitcoin/bitcoin
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  54 protocolbuffers/protobuf
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  55 pytorch/pytorch
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  56 tesseract-ocr/tesseract
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  57 x64dbg/x64dbg
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  58 godotengine/godot
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  59 microsoft/PowerToys
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  60 BVLC/caffe
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  61 PowerShell/PowerShell
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  62 dotnet/aspnetcore
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  63 Wox-launcher/Wox
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  64 0xd4d/dnSpy
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  65 dotnet-architecture/eShopOnContainers
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  66 ShareX/ShareX
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  67 dotnet/roslyn
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  68 icsharpcode/ILSpy
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  69 dotnet/efcore
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  70 MaterialDesignInXAML/MaterialDesignInXamlToolkit
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  71 netdata/netdata
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  72 redis/redis
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  73 git/git
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  74 obsproject/obs-studio
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  75 ggreer/the_silver_searcher
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  76 tmux/tmux
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  77 curl/curl
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  78 libuv/libuv
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  79 numpy/numpy
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  80 openssl/openssl
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  81 rails/rails
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  82 jekyll/jekyll
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  83 discourse/discourse
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  84 fastlane/fastlane
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  85 huginn/huginn
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  86 Homebrew/brew
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  87 tootsuite/mastodon
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  88 rapid7/metasploit-framework
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  89 heartcombo/devise
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  90 hashicorp/vagrant
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  91 golang/go
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  92 moby/moby
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  93 gohugoio/hugo
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  94 gogs/gogs
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  95 v2ray/v2ray-core
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  96 syncthing/syncthing
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  97 etcd-io/etcd
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  98 prometheus/prometheus
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
#  99 containous/traefik
#  - parsing by path
#  - parsing by time
#  - parsing by range
#
# 100 ethereum/go-ethereum
#  - parsing by path
#  - parsing by time
#  - parsing by range

# %%
# releases_bkp = releases.copy()
releases = releases_bkp.copy()

# %%
releases['head'] = releases['head'].apply(lambda commit: commit.id)
releases['name'] = releases['name'].apply(lambda name: name.value)
releases.commits = pd.to_numeric(releases.commits)
releases.time = pd.to_datetime(releases.time, utc=True)
releases.range_commits = pd.to_numeric(releases.range_commits)
releases.range_tpos = pd.to_numeric(releases.range_tpos)
releases.range_fpos = pd.to_numeric(releases.range_fpos)
releases.range_fneg = pd.to_numeric(releases.range_fneg)
releases.time_commits = pd.to_numeric(releases.time_commits)
releases.time_tpos = pd.to_numeric(releases.time_tpos)
releases.time_fpos = pd.to_numeric(releases.time_fpos)
releases.time_fneg = pd.to_numeric(releases.time_fneg)

# %%
releases.dtypes
# Out:
# project                       object
# name                          object
# lang                          object
# head                          object
# time             datetime64[ns, UTC]
# commits                        int64
# range_commits                  int64
# range_tpos                     int64
# range_fpos                     int64
# range_fneg                     int64
# time_commits                   int64
# time_tpos                      int64
# time_fpos                      int64
# time_fneg                      int64
# dtype: object

# %%
def precision(row, column):
    if row[column+"_tpos"] + row[column+"_fpos"] == 0:
        return 0.0
    else:
        return row[column+"_tpos"] / (row[column+"_tpos"] + row[column+"_fpos"])
    
def recall(row, column):
    if row[column+"_tpos"] + row[column+"_fneg"] == 0:
        return 0.0
    else:
        return row[column+"_tpos"] / (row[column+"_tpos"] + row[column+"_fneg"])

# %%
releases['range_precision'] = releases.apply(precision, args=('range',), axis=1)
releases['range_recall'] = releases.apply(recall, args=('range',), axis=1)
releases['time_precision'] = releases.apply(precision, args=('time',), axis=1)
releases['time_recall'] = releases.apply(recall, args=('time',), axis=1)

# %%
type(releases.iloc[0]['commits'])
# Out:
# numpy.int64

# %%
releases
# Out:
#                   project     name        lang  \
# 0               vuejs/vue    0.6.0  javascript
# 1               vuejs/vue   v0.7.0  javascript
# 2               vuejs/vue   v0.7.1  javascript
# 3               vuejs/vue   v0.7.2  javascript
# 4               vuejs/vue   v0.7.3  javascript
# ..                    ...      ...         ...
# 153  ethereum/go-ethereum  v1.9.18          go
# 154  ethereum/go-ethereum  v1.9.19          go
# 155  ethereum/go-ethereum  v1.9.20          go
# 156  ethereum/go-ethereum        2          go
# 157  ethereum/go-ethereum     PoC6          go
#
#                                          head                      time  \
# 0    218557cdec830a629252f4a9e2643973dc1f1d2d 2013-12-08 00:32:17+00:00
# 1    f4861ca9905a170b9a4b185e8a2038dc7c11c58e 2013-12-24 03:31:05+00:00
# 2    590a7ee55b655f166ecdf8e7a5e22dab7a9e6dd7 2013-12-24 21:58:33+00:00
# 3    e78fb82212ac229c91fc8b1f09a84b24f577541a 2013-12-28 05:43:40+00:00
# 4    dcc839a4314de8825f7087f00c4e40ea2d22b46f 2014-01-06 19:13:12+00:00
# ..                                        ...                       ...
# 153  f5382591874220287de253bfc08b10afd5244927 2020-07-27 11:53:53+00:00
# 154  3e0641923d78bf1905e596a3a41a54277540bec7 2020-08-11 11:10:21+00:00
# 155  979fc96899c77876e15807005eadd936da17b6c2 2020-08-25 14:20:37+00:00
# 156  198ef97108ec257d49a7b593a9c6fe49961319c0 2014-05-28 09:53:10+00:00
# 157  dfe66cab3fb533003ddaec7250d8fffbf3fbad65 2014-10-09 16:16:19+00:00
#
#      commits  range_commits  range_tpos  range_fpos  range_fneg  time_commits  \
# 0        354            354         354           0           0           354
# 1         34             34          34           0           0            34
# 2          6              6           6           0           0             6
# 3          3              3           3           0           0             3
# 4         15             15          15           0           0            15
# ..       ...            ...         ...         ...         ...           ...
# 153       19             19          19           0           0            18
# 154       47             47          47           0           0            48
# 155       26             26          26           0           0            27
# 156      233              0           0           0         233             0
# 157       94             94          94           0           0           949
#
#      time_tpos  time_fpos  time_fneg  range_precision  range_recall  \
# 0          354          0          0              1.0           1.0
# 1           34          0          0              1.0           1.0
# 2            6          0          0              1.0           1.0
# 3            3          0          0              1.0           1.0
# 4           15          0          0              1.0           1.0
# ..         ...        ...        ...              ...           ...
# 153         18          0          1              1.0           1.0
# 154         47          1          0              1.0           1.0
# 155         26          1          0              1.0           1.0
# 156          0          0        233              0.0           0.0
# 157         57        892         37              1.0           1.0
#
#      time_precision  time_recall
# 0          1.000000     1.000000
# 1          1.000000     1.000000
# 2          1.000000     1.000000
# 3          1.000000     1.000000
# 4          1.000000     1.000000
# ..              ...          ...
# 153        1.000000     0.947368
# 154        0.979167     1.000000
# 155        0.962963     1.000000
# 156        0.000000     0.000000
# 157        0.060063     0.606383
#
# [15911 rows x 18 columns]

# %%
releases.dtypes
# Out:
# project                         object
# name                            object
# lang                            object
# head                            object
# time               datetime64[ns, UTC]
# commits                          int64
# range_commits                    int64
# range_tpos                       int64
# range_fpos                       int64
# range_fneg                       int64
# time_commits                     int64
# time_tpos                        int64
# time_fpos                        int64
# time_fneg                        int64
# range_precision                float64
# range_recall                   float64
# time_precision                 float64
# time_recall                    float64
# dtype: object

# %%
releases.to_pickle("releases.zip")
