# %%
import pandas as pd

import os

# %%
projects = pd.read_pickle('projects.zip')

# %% [markdown]
# # Clone Projects

# %%
clone_all = True
for i,project in enumerate(projects.itertuples()):
    project_path = os.path.abspath(os.path.join('..','..','..','repos2',project.name))
    git_path = os.path.abspath(os.path.join(project_path,'.git'))
    if clone_all or not os.path.exists(git_path):
        print(f"mkdir -p {project.name}; git clone git://github.com/{project.name} {project.name}")
# Out:
# mkdir -p vuejs/vue; git clone git://github.com/vuejs/vue vuejs/vue
# mkdir -p facebook/react; git clone git://github.com/facebook/react facebook/react
# mkdir -p twbs/bootstrap; git clone git://github.com/twbs/bootstrap twbs/bootstrap
# mkdir -p d3/d3; git clone git://github.com/d3/d3 d3/d3
# mkdir -p facebook/react-native; git clone git://github.com/facebook/react-native facebook/react-native
# mkdir -p nodejs/node; git clone git://github.com/nodejs/node nodejs/node
# mkdir -p mrdoob/three.js; git clone git://github.com/mrdoob/three.js mrdoob/three.js
# mkdir -p angular/angular.js; git clone git://github.com/angular/angular.js angular/angular.js
# mkdir -p webpack/webpack; git clone git://github.com/webpack/webpack webpack/webpack
# mkdir -p jquery/jquery; git clone git://github.com/jquery/jquery jquery/jquery
# mkdir -p microsoft/TypeScript; git clone git://github.com/microsoft/TypeScript microsoft/TypeScript
# mkdir -p ant-design/ant-design; git clone git://github.com/ant-design/ant-design ant-design/ant-design
# mkdir -p reduxjs/redux; git clone git://github.com/reduxjs/redux reduxjs/redux
# mkdir -p storybookjs/storybook; git clone git://github.com/storybookjs/storybook storybookjs/storybook
# mkdir -p ionic-team/ionic-framework; git clone git://github.com/ionic-team/ionic-framework ionic-team/ionic-framework
# mkdir -p grafana/grafana; git clone git://github.com/grafana/grafana grafana/grafana
# mkdir -p vercel/hyper; git clone git://github.com/vercel/hyper vercel/hyper
# mkdir -p facebook/jest; git clone git://github.com/facebook/jest facebook/jest
# mkdir -p nestjs/nest; git clone git://github.com/nestjs/nest nestjs/nest
# mkdir -p vuetifyjs/vuetify; git clone git://github.com/vuetifyjs/vuetify vuetifyjs/vuetify
# mkdir -p elastic/elasticsearch; git clone git://github.com/elastic/elasticsearch elastic/elasticsearch
# mkdir -p spring-projects/spring-boot; git clone git://github.com/spring-projects/spring-boot spring-projects/spring-boot
# mkdir -p spring-projects/spring-framework; git clone git://github.com/spring-projects/spring-framework spring-projects/spring-framework
# mkdir -p square/okhttp; git clone git://github.com/square/okhttp square/okhttp
# mkdir -p apache/dubbo; git clone git://github.com/apache/dubbo apache/dubbo
# mkdir -p PhilJay/MPAndroidChart; git clone git://github.com/PhilJay/MPAndroidChart PhilJay/MPAndroidChart
# mkdir -p bumptech/glide; git clone git://github.com/bumptech/glide bumptech/glide
# mkdir -p netty/netty; git clone git://github.com/netty/netty netty/netty
# mkdir -p alibaba/fastjson; git clone git://github.com/alibaba/fastjson alibaba/fastjson
# mkdir -p ctripcorp/apollo; git clone git://github.com/ctripcorp/apollo ctripcorp/apollo
# mkdir -p ytdl-org/youtube-dl; git clone git://github.com/ytdl-org/youtube-dl ytdl-org/youtube-dl
# mkdir -p pallets/flask; git clone git://github.com/pallets/flask pallets/flask
# mkdir -p django/django; git clone git://github.com/django/django django/django
# mkdir -p keras-team/keras; git clone git://github.com/keras-team/keras keras-team/keras
# mkdir -p ansible/ansible; git clone git://github.com/ansible/ansible ansible/ansible
# mkdir -p psf/requests; git clone git://github.com/psf/requests psf/requests
# mkdir -p scrapy/scrapy; git clone git://github.com/scrapy/scrapy scrapy/scrapy
# mkdir -p home-assistant/core; git clone git://github.com/home-assistant/core home-assistant/core
# mkdir -p soimort/you-get; git clone git://github.com/soimort/you-get soimort/you-get
# mkdir -p huggingface/transformers; git clone git://github.com/huggingface/transformers huggingface/transformers
# mkdir -p laravel/laravel; git clone git://github.com/laravel/laravel laravel/laravel
# mkdir -p fzaninotto/Faker; git clone git://github.com/fzaninotto/Faker fzaninotto/Faker
# mkdir -p composer/composer; git clone git://github.com/composer/composer composer/composer
# mkdir -p laravel/framework; git clone git://github.com/laravel/framework laravel/framework
# mkdir -p guzzle/guzzle; git clone git://github.com/guzzle/guzzle guzzle/guzzle
# mkdir -p bcit-ci/CodeIgniter; git clone git://github.com/bcit-ci/CodeIgniter bcit-ci/CodeIgniter
# mkdir -p Seldaek/monolog; git clone git://github.com/Seldaek/monolog Seldaek/monolog
# mkdir -p sebastianbergmann/phpunit; git clone git://github.com/sebastianbergmann/phpunit sebastianbergmann/phpunit
# mkdir -p briannesbitt/Carbon; git clone git://github.com/briannesbitt/Carbon briannesbitt/Carbon
# mkdir -p WordPress/WordPress; git clone git://github.com/WordPress/WordPress WordPress/WordPress
# mkdir -p electron/electron; git clone git://github.com/electron/electron electron/electron
# mkdir -p opencv/opencv; git clone git://github.com/opencv/opencv opencv/opencv
# mkdir -p bitcoin/bitcoin; git clone git://github.com/bitcoin/bitcoin bitcoin/bitcoin
# mkdir -p protocolbuffers/protobuf; git clone git://github.com/protocolbuffers/protobuf protocolbuffers/protobuf
# mkdir -p pytorch/pytorch; git clone git://github.com/pytorch/pytorch pytorch/pytorch
# mkdir -p microsoft/PowerToys; git clone git://github.com/microsoft/PowerToys microsoft/PowerToys
# mkdir -p tesseract-ocr/tesseract; git clone git://github.com/tesseract-ocr/tesseract tesseract-ocr/tesseract
# mkdir -p godotengine/godot; git clone git://github.com/godotengine/godot godotengine/godot
# mkdir -p ocornut/imgui; git clone git://github.com/ocornut/imgui ocornut/imgui
# mkdir -p aria2/aria2; git clone git://github.com/aria2/aria2 aria2/aria2
# mkdir -p Wox-launcher/Wox; git clone git://github.com/Wox-launcher/Wox Wox-launcher/Wox
# mkdir -p ShareX/ShareX; git clone git://github.com/ShareX/ShareX ShareX/ShareX
# mkdir -p icsharpcode/ILSpy; git clone git://github.com/icsharpcode/ILSpy icsharpcode/ILSpy
# mkdir -p MaterialDesignInXAML/MaterialDesignInXamlToolkit; git clone git://github.com/MaterialDesignInXAML/MaterialDesignInXamlToolkit MaterialDesignInXAML/MaterialDesignInXamlToolkit
# mkdir -p dotnet/efcore; git clone git://github.com/dotnet/efcore dotnet/efcore
# mkdir -p aspnetboilerplate/aspnetboilerplate; git clone git://github.com/aspnetboilerplate/aspnetboilerplate aspnetboilerplate/aspnetboilerplate
# mkdir -p SignalR/SignalR; git clone git://github.com/SignalR/SignalR SignalR/SignalR
# mkdir -p jellyfin/jellyfin; git clone git://github.com/jellyfin/jellyfin jellyfin/jellyfin
# mkdir -p AutoMapper/AutoMapper; git clone git://github.com/AutoMapper/AutoMapper AutoMapper/AutoMapper
# mkdir -p cefsharp/CefSharp; git clone git://github.com/cefsharp/CefSharp cefsharp/CefSharp
# mkdir -p netdata/netdata; git clone git://github.com/netdata/netdata netdata/netdata
# mkdir -p obsproject/obs-studio; git clone git://github.com/obsproject/obs-studio obsproject/obs-studio
# mkdir -p ggreer/the_silver_searcher; git clone git://github.com/ggreer/the_silver_searcher ggreer/the_silver_searcher
# mkdir -p tmux/tmux; git clone git://github.com/tmux/tmux tmux/tmux
# mkdir -p taosdata/TDengine; git clone git://github.com/taosdata/TDengine taosdata/TDengine
# mkdir -p radareorg/radare2; git clone git://github.com/radareorg/radare2 radareorg/radare2
# mkdir -p mpv-player/mpv; git clone git://github.com/mpv-player/mpv mpv-player/mpv
# mkdir -p nginx/nginx; git clone git://github.com/nginx/nginx nginx/nginx
# mkdir -p arendst/Tasmota; git clone git://github.com/arendst/Tasmota arendst/Tasmota
# mkdir -p allinurl/goaccess; git clone git://github.com/allinurl/goaccess allinurl/goaccess
# mkdir -p discourse/discourse; git clone git://github.com/discourse/discourse discourse/discourse
# mkdir -p Homebrew/brew; git clone git://github.com/Homebrew/brew Homebrew/brew
# mkdir -p tootsuite/mastodon; git clone git://github.com/tootsuite/mastodon tootsuite/mastodon
# mkdir -p heartcombo/devise; git clone git://github.com/heartcombo/devise heartcombo/devise
# mkdir -p hashicorp/vagrant; git clone git://github.com/hashicorp/vagrant hashicorp/vagrant
# mkdir -p CocoaPods/CocoaPods; git clone git://github.com/CocoaPods/CocoaPods CocoaPods/CocoaPods
# mkdir -p diaspora/diaspora; git clone git://github.com/diaspora/diaspora diaspora/diaspora
# mkdir -p sinatra/sinatra; git clone git://github.com/sinatra/sinatra sinatra/sinatra
# mkdir -p rubocop-hq/rubocop; git clone git://github.com/rubocop-hq/rubocop rubocop-hq/rubocop
# mkdir -p gollum/gollum; git clone git://github.com/gollum/gollum gollum/gollum
# mkdir -p gohugoio/hugo; git clone git://github.com/gohugoio/hugo gohugoio/hugo
# mkdir -p gogs/gogs; git clone git://github.com/gogs/gogs gogs/gogs
# mkdir -p v2ray/v2ray-core; git clone git://github.com/v2ray/v2ray-core v2ray/v2ray-core
# mkdir -p prometheus/prometheus; git clone git://github.com/prometheus/prometheus prometheus/prometheus
# mkdir -p etcd-io/etcd; git clone git://github.com/etcd-io/etcd etcd-io/etcd
# mkdir -p traefik/traefik; git clone git://github.com/traefik/traefik traefik/traefik
# mkdir -p astaxie/beego; git clone git://github.com/astaxie/beego astaxie/beego
# mkdir -p istio/istio; git clone git://github.com/istio/istio istio/istio
# mkdir -p hashicorp/terraform; git clone git://github.com/hashicorp/terraform hashicorp/terraform
# mkdir -p rclone/rclone; git clone git://github.com/rclone/rclone rclone/rclone

# %% [markdown]
# # Update Projects

# %%
for i,project in enumerate(projects.itertuples()):
    project_path = os.path.abspath(os.path.join('..','..','..','repos2',project.name))
    git_path = os.path.abspath(os.path.join(project_path,'.git'))
    if os.path.exists(git_path):
        print(f"cd {project_path}; git pull;")
# Out:
# cd C:\Users\felipecrp\Research\Release\repos2\vuejs\vue; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\facebook\react; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\twbs\bootstrap; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\d3\d3; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\facebook\react-native; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\nodejs\node; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\mrdoob\three.js; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\angular\angular.js; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\webpack\webpack; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\jquery\jquery; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\microsoft\TypeScript; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\ant-design\ant-design; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\reduxjs\redux; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\storybookjs\storybook; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\ionic-team\ionic-framework; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\grafana\grafana; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\vercel\hyper; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\facebook\jest; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\nestjs\nest; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\vuetifyjs\vuetify; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\elastic\elasticsearch; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\spring-projects\spring-boot; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\spring-projects\spring-framework; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\square\okhttp; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\apache\dubbo; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\PhilJay\MPAndroidChart; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\bumptech\glide; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\netty\netty; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\alibaba\fastjson; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\ctripcorp\apollo; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\ytdl-org\youtube-dl; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\pallets\flask; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\django\django; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\keras-team\keras; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\ansible\ansible; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\psf\requests; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\scrapy\scrapy; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\home-assistant\core; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\soimort\you-get; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\huggingface\transformers; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\laravel\laravel; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\fzaninotto\Faker; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\composer\composer; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\laravel\framework; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\guzzle\guzzle; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\bcit-ci\CodeIgniter; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\Seldaek\monolog; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\sebastianbergmann\phpunit; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\briannesbitt\Carbon; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\WordPress\WordPress; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\electron\electron; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\opencv\opencv; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\bitcoin\bitcoin; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\protocolbuffers\protobuf; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\pytorch\pytorch; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\microsoft\PowerToys; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\tesseract-ocr\tesseract; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\godotengine\godot; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\ocornut\imgui; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\aria2\aria2; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\Wox-launcher\Wox; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\ShareX\ShareX; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\icsharpcode\ILSpy; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\MaterialDesignInXAML\MaterialDesignInXamlToolkit; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\dotnet\efcore; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\aspnetboilerplate\aspnetboilerplate; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\SignalR\SignalR; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\jellyfin\jellyfin; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\AutoMapper\AutoMapper; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\cefsharp\CefSharp; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\netdata\netdata; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\obsproject\obs-studio; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\ggreer\the_silver_searcher; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\tmux\tmux; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\taosdata\TDengine; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\radareorg\radare2; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\mpv-player\mpv; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\nginx\nginx; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\arendst\Tasmota; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\allinurl\goaccess; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\discourse\discourse; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\Homebrew\brew; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\tootsuite\mastodon; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\heartcombo\devise; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\hashicorp\vagrant; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\CocoaPods\CocoaPods; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\diaspora\diaspora; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\sinatra\sinatra; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\rubocop-hq\rubocop; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\gollum\gollum; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\gohugoio\hugo; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\gogs\gogs; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\v2ray\v2ray-core; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\prometheus\prometheus; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\etcd-io\etcd; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\traefik\traefik; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\astaxie\beego; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\istio\istio; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\hashicorp\terraform; git pull;
# cd C:\Users\felipecrp\Research\Release\repos2\rclone\rclone; git pull;
