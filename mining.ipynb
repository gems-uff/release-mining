# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import re
import time

# %%
pd.options.display.max_rows = 700

# %%
import os
import sys

releasy_module = os.path.abspath(os.path.join('..','..','..','dev','releasy2'))
if releasy_module not in sys.path:
    sys.path.insert(0, releasy_module)
    
import releasy
from releasy.miner_git import GitVcs
from releasy.miner import TagReleaseMiner, TimeVersionReleaseSorter, TimeNaiveCommitMiner, PathCommitMiner, RangeCommitMiner, TimeCommitMiner, VersionReleaseMatcher, VersionReleaseSorter, TimeReleaseSorter, VersionWoPreReleaseMatcher

# %%
projects = pd.read_pickle('projects.zip')

# %%
projects
# Out:
#                                                         lang   stars  commits  \
# name
# vuejs/vue                                         javascript  173633     3127
# facebook/react                                    javascript  157151    13618
# twbs/bootstrap                                    javascript  144624    20098
# d3/d3                                             javascript   93988     4279
# facebook/react-native                             javascript   90624    21174
# nodejs/node                                       javascript   73625    31855
# mrdoob/three.js                                   javascript   63955    35292
# angular/angular.js                                javascript   59500     9036
# webpack/webpack                                   javascript   55847    12166
# vercel/next.js                                    javascript   54145     7016
# microsoft/TypeScript                              typescript   64910    31206
# ant-design/ant-design                             typescript   63926    19525
# reduxjs/redux                                     typescript   54456     3063
# storybookjs/storybook                             typescript   53940    30597
# ionic-team/ionic-framework                        typescript   41882    10550
# grafana/grafana                                   typescript   37523    26658
# vercel/hyper                                      typescript   34266     2030
# facebook/jest                                     typescript   32708     5077
# nestjs/nest                                       typescript   30860     6120
# vuetifyjs/vuetify                                 typescript   27952    10957
# elastic/elasticsearch                                   java   51561    55176
# spring-projects/spring-boot                             java   51005    29052
# spring-projects/spring-framework                        java   39624    21646
# square/okhttp                                           java   38392     4714
# apache/dubbo                                            java   33730     4404
# PhilJay/MPAndroidChart                                  java   31866     2066
# bumptech/glide                                          java   30014     2530
# netty/netty                                             java   24895     9988
# ctripcorp/apollo                                        java   22476     2419
# alibaba/fastjson                                        java   22463     3749
# django/django                                         python   52756    28840
# pallets/flask                                         python   52332     4021
# keras-team/keras                                      python   49949     5349
# ansible/ansible                                       python   45056    50771
# psf/requests                                          python   43659     5988
# scrapy/scrapy                                         python   38504     8509
# home-assistant/core                                   python   36144    30476
# soimort/you-get                                       python   35252     2320
# huggingface/transformers                              python   34795     5466
# XX-net/XX-Net                                         python   30376     2215
# laravel/laravel                                          php   61920     6365
# fzaninotto/Faker                                         php   24821     2614
# composer/composer                                        php   23952     9964
# laravel/framework                                        php   22329    29679
# guzzle/guzzle                                            php   20000     3544
# bcit-ci/CodeIgniter                                      php   18076    10156
# Seldaek/monolog                                          php   17928     2391
# sebastianbergmann/phpunit                                php   16600    14145
# briannesbitt/Carbon                                      php   14729     2748
# WordPress/WordPress                                      php   14385    42497
# electron/electron                                        c++   86283    24150
# opencv/opencv                                            c++   48855    29372
# bitcoin/bitcoin                                          c++   45395    25981
# protocolbuffers/protobuf                                 c++   44177     7672
# pytorch/pytorch                                          c++   43011    30547
# microsoft/PowerToys                                      c++   39205     3998
# tesseract-ocr/tesseract                                  c++   36695     4644
# godotengine/godot                                        c++   33725    30739
# ocornut/imgui                                            c++   23910     5967
# aria2/aria2                                              c++   21113     5271
# Wox-launcher/Wox                                          c#   18451     2740
# ShareX/ShareX                                             c#   13977     6408
# icsharpcode/ILSpy                                         c#   11179     6187
# MaterialDesignInXAML/MaterialDesignInXamlToolkit          c#    9697     2201
# dotnet/efcore                                             c#    9529    10640
# aspnetboilerplate/aspnetboilerplate                       c#    8896     6561
# jellyfin/jellyfin                                         c#    8185    18402
# SignalR/SignalR                                           c#    8130     4691
# AutoMapper/AutoMapper                                     c#    7544     3666
# cefsharp/CefSharp                                         c#    7388     5483
# netdata/netdata                                            c   48821    11400
# obsproject/obs-studio                                      c   22526     8754
# ggreer/the_silver_searcher                                 c   20985     2055
# tmux/tmux                                                  c   19085     9022
# taosdata/TDengine                                          c   13860     8534
# radareorg/radare2                                          c   13242    24801
# mpv-player/mpv                                             c   13130    48773
# nginx/nginx                                                c   12745     6766
# arendst/Tasmota                                            c   12401     8634
# allinurl/goaccess                                          c   12189     3214
# discourse/discourse                                     ruby   31669    39546
# Homebrew/brew                                           ruby   23272    23673
# tootsuite/mastodon                                      ruby   21957     9660
# heartcombo/devise                                       ruby   21152     3705
# hashicorp/vagrant                                       ruby   20719    13600
# CocoaPods/CocoaPods                                     ruby   12729     9029
# diaspora/diaspora                                       ruby   12512    20242
# sinatra/sinatra                                         ruby   11077     4206
# rubocop-hq/rubocop                                      ruby   11066     9874
# gollum/gollum                                           ruby   11024     2280
# gohugoio/hugo                                             go   47145     6020
# gogs/gogs                                                 go   35548     5471
# v2ray/v2ray-core                                          go   35246     5382
# prometheus/prometheus                                     go   33269     8216
# etcd-io/etcd                                              go   33056    16402
# traefik/traefik                                           go   31046     3766
# astaxie/beego                                             go   25010     3659
# istio/istio                                               go   24681    13683
# hashicorp/terraform                                       go   24008    27005
# rclone/rclone                                             go   23744     4816
#
#                                                   issues  tags  releases  \
# name
# vuejs/vue                                           9211   250       208
# facebook/react                                      9635   131        90
# twbs/bootstrap                                     19637    62        62
# d3/d3                                               2056   267       159
# facebook/react-native                              20262   348       148
# nodejs/node                                        12258   625       183
# mrdoob/three.js                                    10074   113       113
# angular/angular.js                                  9003   207         0
# webpack/webpack                                     7433   453       245
# vercel/next.js                                      7417   948       829
# microsoft/TypeScript                               27912   130       110
# ant-design/ant-design                              18975   418       366
# reduxjs/redux                                       1813    69        61
# storybookjs/storybook                               6331   890       606
# ionic-team/ionic-framework                         18165   247       216
# grafana/grafana                                    17713   217       192
# vercel/hyper                                        3102   101        64
# facebook/jest                                       5732   197       115
# nestjs/nest                                         2908   160        53
# vuetifyjs/vuetify                                   9131   374       361
# elastic/elasticsearch                              25051   282        33
# spring-projects/spring-boot                        19032   168        70
# spring-projects/spring-framework                   20080   191       188
# square/okhttp                                       3212   105         0
# apache/dubbo                                        3816    70        27
# PhilJay/MPAndroidChart                              4541    44        44
# bumptech/glide                                      3819    38        35
# netty/netty                                         5215   219         0
# ctripcorp/apollo                                    2215    27        27
# alibaba/fastjson                                    2850   128        80
# django/django                                          0   295         0
# pallets/flask                                       2000    32        10
# keras-team/keras                                   10280    50        23
# ansible/ansible                                    28232   334         3
# psf/requests                                        3250   139         0
# scrapy/scrapy                                       2309    96        17
# home-assistant/core                                16859   661       660
# soimort/you-get                                        0   144       105
# huggingface/transformers                            4594    41        37
# XX-net/XX-Net                                      12678   311       307
# laravel/laravel                                        0   118        46
# fzaninotto/Faker                                     567    12        11
# composer/composer                                   6181    86        86
# laravel/framework                                  14160   591       310
# guzzle/guzzle                                       1635   133        42
# bcit-ci/CodeIgniter                                 3137    38         0
# Seldaek/monolog                                      639    51        40
# sebastianbergmann/phpunit                           2816   618         0
# briannesbitt/Carbon                                  969   171       167
# WordPress/WordPress                                    0   449         0
# electron/electron                                  13825  1064       623
# opencv/opencv                                       7277    98        46
# bitcoin/bitcoin                                     5736   236        33
# protocolbuffers/protobuf                            4122    89        56
# pytorch/pytorch                                    16559    49        28
# microsoft/PowerToys                                 5421    23        23
# tesseract-ocr/tesseract                             1919    41         8
# godotengine/godot                                  24716    29        28
# ocornut/imgui                                       2770    68        68
# aria2/aria2                                         1403   150        22
# Wox-launcher/Wox                                    2782    42        38
# ShareX/ShareX                                       4257    66        66
# icsharpcode/ILSpy                                   1733    54        46
# MaterialDesignInXAML/MaterialDesignInXamlToolkit    1264    27        27
# dotnet/efcore                                      14647   106        78
# aspnetboilerplate/aspnetboilerplate                 4755   214       211
# jellyfin/jellyfin                                   2201    33        32
# SignalR/SignalR                                     3503    44        30
# AutoMapper/AutoMapper                               2564    49        35
# cefsharp/CefSharp                                   2340    98        85
# netdata/netdata                                     5807    44        37
# obsproject/obs-studio                                800   126       123
# ggreer/the_silver_searcher                           758    49         0
# tmux/tmux                                           2043    31        30
# taosdata/TDengine                                   1399    48         0
# radareorg/radare2                                   7575    83        64
# mpv-player/mpv                                      5930    76        76
# nginx/nginx                                            0   530         0
# arendst/Tasmota                                     7157    83        83
# allinurl/goaccess                                   1675    27         0
# discourse/discourse                                    0   352         0
# Homebrew/brew                                       2721   181       163
# tootsuite/mastodon                                  5744   153       144
# heartcombo/devise                                   3984   137        14
# hashicorp/vagrant                                   8615   145         0
# CocoaPods/CocoaPods                                 8111   208       168
# diaspora/diaspora                                   4625    88        84
# sinatra/sinatra                                      747   138         0
# rubocop-hq/rubocop                                  3939   151       109
# gollum/gollum                                       1037    83         0
# gohugoio/hugo                                       4949   140       140
# gogs/gogs                                           4632    60        60
# v2ray/v2ray-core                                    2315   350       247
# prometheus/prometheus                               3658   179       158
# etcd-io/etcd                                        5083   199       191
# traefik/traefik                                     4091   315       310
# astaxie/beego                                       2808    30         6
# istio/istio                                        11439   166       164
# hashicorp/terraform                                15744   162       132
# rclone/rclone                                       3500    78        70
#
#                                                                last_commit  \
# name
# vuejs/vue                                        2020-10-05 14:57:24+00:00
# facebook/react                                   2020-10-09 13:29:30+00:00
# twbs/bootstrap                                   2020-10-07 14:03:53+00:00
# d3/d3                                            2020-09-23 16:56:59+00:00
# facebook/react-native                            2020-10-10 09:51:59+00:00
# nodejs/node                                      2020-10-10 15:36:13+00:00
# mrdoob/three.js                                  2020-10-10 14:10:24+00:00
# angular/angular.js                               2020-10-08 18:16:57+00:00
# webpack/webpack                                  2020-10-10 19:03:10+00:00
# vercel/next.js                                   2020-10-10 10:22:45+00:00
# microsoft/TypeScript                             2020-10-10 06:23:12+00:00
# ant-design/ant-design                            2020-10-10 18:56:12+00:00
# reduxjs/redux                                    2020-10-04 20:09:11+00:00
# storybookjs/storybook                            2020-10-10 02:41:01+00:00
# ionic-team/ionic-framework                       2020-10-09 20:58:49+00:00
# grafana/grafana                                  2020-10-09 19:10:23+00:00
# vercel/hyper                                     2020-10-08 13:48:43+00:00
# facebook/jest                                    2020-10-10 11:57:09+00:00
# nestjs/nest                                      2020-10-06 06:55:37+00:00
# vuetifyjs/vuetify                                2020-10-10 16:33:16+00:00
# elastic/elasticsearch                            2020-10-09 06:52:34+00:00
# spring-projects/spring-boot                      2020-10-10 06:23:28+00:00
# spring-projects/spring-framework                 2020-10-10 14:35:56+00:00
# square/okhttp                                    2020-10-10 01:27:58+00:00
# apache/dubbo                                     2020-10-10 06:07:40+00:00
# PhilJay/MPAndroidChart                           2020-09-21 14:53:08+00:00
# bumptech/glide                                   2020-09-24 19:34:43+00:00
# netty/netty                                      2020-10-08 10:06:43+00:00
# ctripcorp/apollo                                 2020-10-03 11:24:30+00:00
# alibaba/fastjson                                 2020-10-10 18:01:23+00:00
# django/django                                    2020-10-09 10:59:00+00:00
# pallets/flask                                    2020-10-07 15:06:29+00:00
# keras-team/keras                                 2020-06-24 22:39:49+00:00
# ansible/ansible                                  2020-10-09 20:12:45+00:00
# psf/requests                                     2020-10-05 18:15:43+00:00
# scrapy/scrapy                                    2020-10-08 19:39:05+00:00
# home-assistant/core                              2020-10-10 18:42:19+00:00
# soimort/you-get                                  2020-10-06 13:21:53+00:00
# huggingface/transformers                         2020-10-10 07:55:11+00:00
# XX-net/XX-Net                                    2020-10-09 09:04:25+00:00
# laravel/laravel                                  2020-10-09 12:40:20+00:00
# fzaninotto/Faker                                 2020-05-11 08:39:57+00:00
# composer/composer                                2020-10-08 12:38:41+00:00
# laravel/framework                                2020-10-09 21:06:40+00:00
# guzzle/guzzle                                    2020-10-10 11:47:56+00:00
# bcit-ci/CodeIgniter                              2020-07-09 08:47:47+00:00
# Seldaek/monolog                                  2020-08-23 11:42:45+00:00
# sebastianbergmann/phpunit                        2020-10-06 09:41:30+00:00
# briannesbitt/Carbon                              2020-10-10 11:06:56+00:00
# WordPress/WordPress                              2020-10-10 19:14:04+00:00
# electron/electron                                2020-10-10 00:45:08+00:00
# opencv/opencv                                    2020-10-09 20:09:26+00:00
# bitcoin/bitcoin                                  2020-10-09 10:08:14+00:00
# protocolbuffers/protobuf                         2020-10-09 22:54:39+00:00
# pytorch/pytorch                                  2020-10-10 15:57:54+00:00
# microsoft/PowerToys                              2020-10-10 00:58:52+00:00
# tesseract-ocr/tesseract                          2020-10-10 10:52:53+00:00
# godotengine/godot                                2020-10-10 14:47:56+00:00
# ocornut/imgui                                    2020-10-08 14:01:59+00:00
# aria2/aria2                                      2020-06-25 02:42:25+00:00
# Wox-launcher/Wox                                 2020-08-20 23:39:33+00:00
# ShareX/ShareX                                    2020-10-09 09:04:15+00:00
# icsharpcode/ILSpy                                2020-10-07 21:59:22+00:00
# MaterialDesignInXAML/MaterialDesignInXamlToolkit 2020-10-03 22:23:47+00:00
# dotnet/efcore                                    2020-10-09 22:35:40+00:00
# aspnetboilerplate/aspnetboilerplate              2020-10-06 12:46:47+00:00
# jellyfin/jellyfin                                2020-10-10 06:59:13+00:00
# SignalR/SignalR                                  2020-05-29 23:09:38+00:00
# AutoMapper/AutoMapper                            2020-10-01 15:38:08+00:00
# cefsharp/CefSharp                                2020-10-10 10:34:21+00:00
# netdata/netdata                                  2020-10-10 01:19:01+00:00
# obsproject/obs-studio                            2020-10-10 02:56:58+00:00
# ggreer/the_silver_searcher                       2020-07-04 19:27:44+00:00
# tmux/tmux                                        2020-10-09 21:01:22+00:00
# taosdata/TDengine                                2020-10-10 06:49:03+00:00
# radareorg/radare2                                2020-10-10 09:38:01+00:00
# mpv-player/mpv                                   2020-10-09 17:06:27+00:00
# nginx/nginx                                      2020-10-08 14:44:34+00:00
# arendst/Tasmota                                  2020-10-10 18:50:11+00:00
# allinurl/goaccess                                2020-10-09 05:02:05+00:00
# discourse/discourse                              2020-10-09 21:50:00+00:00
# Homebrew/brew                                    2020-10-10 08:30:31+00:00
# tootsuite/mastodon                               2020-10-09 15:12:52+00:00
# heartcombo/devise                                2020-09-21 00:24:01+00:00
# hashicorp/vagrant                                2020-10-09 16:55:00+00:00
# CocoaPods/CocoaPods                              2020-10-10 05:56:45+00:00
# diaspora/diaspora                                2020-09-17 06:48:45+00:00
# sinatra/sinatra                                  2020-10-06 14:26:32+00:00
# rubocop-hq/rubocop                               2020-10-09 15:44:39+00:00
# gollum/gollum                                    2020-09-21 13:50:58+00:00
# gohugoio/hugo                                    2020-10-09 18:23:38+00:00
# gogs/gogs                                        2020-10-10 15:09:42+00:00
# v2ray/v2ray-core                                 2020-10-10 16:46:14+00:00
# prometheus/prometheus                            2020-10-08 13:52:19+00:00
# etcd-io/etcd                                     2020-10-10 00:32:15+00:00
# traefik/traefik                                  2020-10-09 10:41:38+00:00
# astaxie/beego                                    2020-10-10 14:10:43+00:00
# istio/istio                                      2020-10-10 00:51:09+00:00
# hashicorp/terraform                              2020-10-09 19:41:15+00:00
# rclone/rclone                                    2020-10-09 16:01:16+00:00
#
#                                                                                         description  \
# name
# vuejs/vue                                         🖖 Vue.js is a progressive, incrementally-adopt...
# facebook/react                                    A declarative, efficient, and flexible JavaScr...
# twbs/bootstrap                                    The most popular HTML, CSS, and JavaScript fra...
# d3/d3                                             Bring data to life with SVG, Canvas and HTML. ...
# facebook/react-native                              A framework for building native apps with React.
# nodejs/node                                       Node.js JavaScript runtime :sparkles::turtle::...
# mrdoob/three.js                                                              JavaScript 3D library.
# angular/angular.js                                          AngularJS - HTML enhanced for web apps!
# webpack/webpack                                   A bundler for javascript and friends. Packs ma...
# vercel/next.js                                                                  The React Framework
# microsoft/TypeScript                              TypeScript is a superset of JavaScript that co...
# ant-design/ant-design                                  🌈  A UI Design Language and React UI library
# reduxjs/redux                                       Predictable state container for JavaScript apps
# storybookjs/storybook                             📓 The UI component explorer. Develop, document...
# ionic-team/ionic-framework                        A powerful cross-platform UI toolkit for build...
# grafana/grafana                                   The tool for beautiful monitoring and metric a...
# vercel/hyper                                                   A terminal built on web technologies
# facebook/jest                                                        Delightful JavaScript Testing.
# nestjs/nest                                       A progressive Node.js framework for building e...
# vuetifyjs/vuetify                                            🐉 Material Component Framework for Vue
# elastic/elasticsearch                               Open Source, Distributed, RESTful Search Engine
# spring-projects/spring-boot                                                             Spring Boot
# spring-projects/spring-framework                                                   Spring Framework
# square/okhttp                                     Square’s meticulous HTTP client for the JVM, A...
# apache/dubbo                                      Apache Dubbo is a high-performance, java based...
# PhilJay/MPAndroidChart                            A powerful 🚀 Android chart view / graph view l...
# bumptech/glide                                    An image loading and caching library for Andro...
# netty/netty                                       Netty project - an event-driven asynchronous n...
# ctripcorp/apollo                                  Apollo（阿波罗）是携程框架部门研发的分布式配置中心，能够集中化管理应用不同环境、不同集...
# alibaba/fastjson                                           A fast JSON parser/generator for Java.
# django/django                                     The Web framework for perfectionists with dead...
# pallets/flask                                     The Python micro framework for building web ap...
# keras-team/keras                                                           Deep Learning for humans
# ansible/ansible                                   Ansible is a radically simple IT automation pl...
# psf/requests                                                    A simple, yet elegant HTTP library.
# scrapy/scrapy                                     Scrapy, a fast high-level web crawling & scrap...
# home-assistant/core                               :house_with_garden: Open source home automatio...
# soimort/you-get                                   :arrow_double_down: Dumb downloader that scrap...
# huggingface/transformers                          🤗Transformers: State-of-the-art Natural Langua...
# XX-net/XX-Net                                                           A proxy tool to bypass GFW.
# laravel/laravel                                                    A PHP framework for web artisans
# fzaninotto/Faker                                  Faker is a PHP library that generates fake dat...
# composer/composer                                                        Dependency Manager for PHP
# laravel/framework                                                                              None
# guzzle/guzzle                                                 Guzzle, an extensible PHP HTTP client
# bcit-ci/CodeIgniter                               Open Source PHP Framework (originally from Ell...
# Seldaek/monolog                                   Sends your logs to files, sockets, inboxes, da...
# sebastianbergmann/phpunit                                           The PHP Unit Testing framework.
# briannesbitt/Carbon                                        A simple PHP API extension for DateTime.
# WordPress/WordPress                               WordPress, Git-ified. Synced via SVN every 15 ...
# electron/electron                                 :electron: Build cross-platform desktop apps w...
# opencv/opencv                                                   Open Source Computer Vision Library
# bitcoin/bitcoin                                               Bitcoin Core integration/staging tree
# protocolbuffers/protobuf                          Protocol Buffers - Google's data interchange f...
# pytorch/pytorch                                   Tensors and Dynamic neural networks in Python ...
# microsoft/PowerToys                               Windows system utilities to maximize productivity
# tesseract-ocr/tesseract                           Tesseract Open Source OCR Engine (main reposit...
# godotengine/godot                                 Godot Engine – Multi-platform 2D and 3D game e...
# ocornut/imgui                                     Dear ImGui: Bloat-free Graphical User interfac...
# aria2/aria2                                       aria2 is a lightweight multi-protocol & multi-...
# Wox-launcher/Wox                                  Launcher for Windows, an alternative to Alfred...
# ShareX/ShareX                                     ShareX is a free and open source program that ...
# icsharpcode/ILSpy                                 .NET Decompiler with support for PDB generatio...
# MaterialDesignInXAML/MaterialDesignInXamlToolkit  Google's Material Design in XAML & WPF, for C#...
# dotnet/efcore                                     EF Core is a modern object-database mapper for...
# aspnetboilerplate/aspnetboilerplate                 ASP.NET Boilerplate - Web Application Framework
# jellyfin/jellyfin                                                    The Free Software Media System
# SignalR/SignalR                                            Incredibly simple real-time web for .NET
# AutoMapper/AutoMapper                             A convention-based object-object mapper in .NET.
# cefsharp/CefSharp                                 .NET (WPF and Windows Forms) bindings for the ...
# netdata/netdata                                   Real-time performance monitoring, done right! ...
# obsproject/obs-studio                             OBS Studio - Free and open source software for...
# ggreer/the_silver_searcher                        A code-searching tool similar to ack, but faster.
# tmux/tmux                                                                          tmux source code
# taosdata/TDengine                                 An open-source big data platform designed and ...
# radareorg/radare2                                 UNIX-like reverse engineering framework and co...
# mpv-player/mpv                                                          🎥 Command line video player
# nginx/nginx                                       An official read-only mirror of http://hg.ngin...
# arendst/Tasmota                                   Alternative firmware for ESP8266 with easy con...
# allinurl/goaccess                                 GoAccess is a real-time web log analyzer and i...
# discourse/discourse                               A platform for community discussion. Free, ope...
# Homebrew/brew                                     🍺 The missing package manager for macOS (or Li...
# tootsuite/mastodon                                Your self-hosted, globally interconnected micr...
# heartcombo/devise                                 Flexible authentication solution for Rails wit...
# hashicorp/vagrant                                 Vagrant is a tool for building and distributin...
# CocoaPods/CocoaPods                                                   The Cocoa Dependency Manager.
# diaspora/diaspora                                 A privacy-aware, distributed, open source soci...
# sinatra/sinatra                                   Classy web-development dressed in a DSL (offic...
# rubocop-hq/rubocop                                A Ruby static code analyzer and formatter, bas...
# gollum/gollum                                     A simple, Git-powered wiki with a sweet API an...
# gohugoio/hugo                                     The world’s fastest framework for building web...
# gogs/gogs                                                Gogs is a painless self-hosted Git service
# v2ray/v2ray-core                                  A platform for building proxies to bypass netw...
# prometheus/prometheus                             The Prometheus monitoring system and time seri...
# etcd-io/etcd                                      Distributed reliable key-value store for the m...
# traefik/traefik                                                  The Cloud Native Application Proxy
# astaxie/beego                                     beego is an open-source, high-performance web ...
# istio/istio                                         Connect, secure, control, and observe services.
# hashicorp/terraform                               Terraform enables you to safely and predictabl...
# rclone/rclone                                     "rsync for cloud storage" - Google Drive, Amaz...
#
#                                                                                                 url  \
# name
# vuejs/vue                                                              https://github.com/vuejs/vue
# facebook/react                                                    https://github.com/facebook/react
# twbs/bootstrap                                                    https://github.com/twbs/bootstrap
# d3/d3                                                                      https://github.com/d3/d3
# facebook/react-native                                      https://github.com/facebook/react-native
# nodejs/node                                                          https://github.com/nodejs/node
# mrdoob/three.js                                                  https://github.com/mrdoob/three.js
# angular/angular.js                                            https://github.com/angular/angular.js
# webpack/webpack                                                  https://github.com/webpack/webpack
# vercel/next.js                                                    https://github.com/vercel/next.js
# microsoft/TypeScript                                        https://github.com/microsoft/TypeScript
# ant-design/ant-design                                      https://github.com/ant-design/ant-design
# reduxjs/redux                                                      https://github.com/reduxjs/redux
# storybookjs/storybook                                      https://github.com/storybookjs/storybook
# ionic-team/ionic-framework                            https://github.com/ionic-team/ionic-framework
# grafana/grafana                                                  https://github.com/grafana/grafana
# vercel/hyper                                                        https://github.com/vercel/hyper
# facebook/jest                                                      https://github.com/facebook/jest
# nestjs/nest                                                          https://github.com/nestjs/nest
# vuetifyjs/vuetify                                              https://github.com/vuetifyjs/vuetify
# elastic/elasticsearch                                      https://github.com/elastic/elasticsearch
# spring-projects/spring-boot                          https://github.com/spring-projects/spring-boot
# spring-projects/spring-framework                  https://github.com/spring-projects/spring-fram...
# square/okhttp                                                      https://github.com/square/okhttp
# apache/dubbo                                                        https://github.com/apache/dubbo
# PhilJay/MPAndroidChart                                    https://github.com/PhilJay/MPAndroidChart
# bumptech/glide                                                    https://github.com/bumptech/glide
# netty/netty                                                          https://github.com/netty/netty
# ctripcorp/apollo                                                https://github.com/ctripcorp/apollo
# alibaba/fastjson                                                https://github.com/alibaba/fastjson
# django/django                                                      https://github.com/django/django
# pallets/flask                                                      https://github.com/pallets/flask
# keras-team/keras                                                https://github.com/keras-team/keras
# ansible/ansible                                                  https://github.com/ansible/ansible
# psf/requests                                                        https://github.com/psf/requests
# scrapy/scrapy                                                      https://github.com/scrapy/scrapy
# home-assistant/core                                          https://github.com/home-assistant/core
# soimort/you-get                                                  https://github.com/soimort/you-get
# huggingface/transformers                                https://github.com/huggingface/transformers
# XX-net/XX-Net                                                      https://github.com/XX-net/XX-Net
# laravel/laravel                                                  https://github.com/laravel/laravel
# fzaninotto/Faker                                                https://github.com/fzaninotto/Faker
# composer/composer                                              https://github.com/composer/composer
# laravel/framework                                              https://github.com/laravel/framework
# guzzle/guzzle                                                      https://github.com/guzzle/guzzle
# bcit-ci/CodeIgniter                                          https://github.com/bcit-ci/CodeIgniter
# Seldaek/monolog                                                  https://github.com/Seldaek/monolog
# sebastianbergmann/phpunit                              https://github.com/sebastianbergmann/phpunit
# briannesbitt/Carbon                                          https://github.com/briannesbitt/Carbon
# WordPress/WordPress                                          https://github.com/WordPress/WordPress
# electron/electron                                              https://github.com/electron/electron
# opencv/opencv                                                      https://github.com/opencv/opencv
# bitcoin/bitcoin                                                  https://github.com/bitcoin/bitcoin
# protocolbuffers/protobuf                                https://github.com/protocolbuffers/protobuf
# pytorch/pytorch                                                  https://github.com/pytorch/pytorch
# microsoft/PowerToys                                          https://github.com/microsoft/PowerToys
# tesseract-ocr/tesseract                                  https://github.com/tesseract-ocr/tesseract
# godotengine/godot                                              https://github.com/godotengine/godot
# ocornut/imgui                                                      https://github.com/ocornut/imgui
# aria2/aria2                                                          https://github.com/aria2/aria2
# Wox-launcher/Wox                                                https://github.com/Wox-launcher/Wox
# ShareX/ShareX                                                      https://github.com/ShareX/ShareX
# icsharpcode/ILSpy                                              https://github.com/icsharpcode/ILSpy
# MaterialDesignInXAML/MaterialDesignInXamlToolkit  https://github.com/MaterialDesignInXAML/Materi...
# dotnet/efcore                                                      https://github.com/dotnet/efcore
# aspnetboilerplate/aspnetboilerplate               https://github.com/aspnetboilerplate/aspnetboi...
# jellyfin/jellyfin                                              https://github.com/jellyfin/jellyfin
# SignalR/SignalR                                                  https://github.com/SignalR/SignalR
# AutoMapper/AutoMapper                                      https://github.com/AutoMapper/AutoMapper
# cefsharp/CefSharp                                              https://github.com/cefsharp/CefSharp
# netdata/netdata                                                  https://github.com/netdata/netdata
# obsproject/obs-studio                                      https://github.com/obsproject/obs-studio
# ggreer/the_silver_searcher                            https://github.com/ggreer/the_silver_searcher
# tmux/tmux                                                              https://github.com/tmux/tmux
# taosdata/TDengine                                              https://github.com/taosdata/TDengine
# radareorg/radare2                                              https://github.com/radareorg/radare2
# mpv-player/mpv                                                    https://github.com/mpv-player/mpv
# nginx/nginx                                                          https://github.com/nginx/nginx
# arendst/Tasmota                                                  https://github.com/arendst/Tasmota
# allinurl/goaccess                                              https://github.com/allinurl/goaccess
# discourse/discourse                                          https://github.com/discourse/discourse
# Homebrew/brew                                                      https://github.com/Homebrew/brew
# tootsuite/mastodon                                            https://github.com/tootsuite/mastodon
# heartcombo/devise                                              https://github.com/heartcombo/devise
# hashicorp/vagrant                                              https://github.com/hashicorp/vagrant
# CocoaPods/CocoaPods                                          https://github.com/CocoaPods/CocoaPods
# diaspora/diaspora                                              https://github.com/diaspora/diaspora
# sinatra/sinatra                                                  https://github.com/sinatra/sinatra
# rubocop-hq/rubocop                                            https://github.com/rubocop-hq/rubocop
# gollum/gollum                                                      https://github.com/gollum/gollum
# gohugoio/hugo                                                      https://github.com/gohugoio/hugo
# gogs/gogs                                                              https://github.com/gogs/gogs
# v2ray/v2ray-core                                                https://github.com/v2ray/v2ray-core
# prometheus/prometheus                                      https://github.com/prometheus/prometheus
# etcd-io/etcd                                                        https://github.com/etcd-io/etcd
# traefik/traefik                                                  https://github.com/traefik/traefik
# astaxie/beego                                                      https://github.com/astaxie/beego
# istio/istio                                                          https://github.com/istio/istio
# hashicorp/terraform                                          https://github.com/hashicorp/terraform
# rclone/rclone                                                      https://github.com/rclone/rclone
#
#                                                  discarded  software  shared  \
# name
# vuejs/vue                                            False      True   False
# facebook/react                                       False      True   False
# twbs/bootstrap                                       False      True   False
# d3/d3                                                False      True   False
# facebook/react-native                                False      True   False
# nodejs/node                                          False      True   False
# mrdoob/three.js                                      False      True   False
# angular/angular.js                                   False      True   False
# webpack/webpack                                      False      True   False
# vercel/next.js                                       False      True   False
# microsoft/TypeScript                                 False      True   False
# ant-design/ant-design                                False      True   False
# reduxjs/redux                                        False      True   False
# storybookjs/storybook                                False      True   False
# ionic-team/ionic-framework                           False      True   False
# grafana/grafana                                      False      True   False
# vercel/hyper                                         False      True   False
# facebook/jest                                        False      True   False
# nestjs/nest                                          False      True   False
# vuetifyjs/vuetify                                    False      True   False
# elastic/elasticsearch                                False      True   False
# spring-projects/spring-boot                          False      True   False
# spring-projects/spring-framework                     False      True   False
# square/okhttp                                        False      True   False
# apache/dubbo                                         False      True   False
# PhilJay/MPAndroidChart                               False      True   False
# bumptech/glide                                       False      True   False
# netty/netty                                          False      True   False
# ctripcorp/apollo                                     False      True   False
# alibaba/fastjson                                     False      True   False
# django/django                                        False      True   False
# pallets/flask                                        False      True   False
# keras-team/keras                                     False      True   False
# ansible/ansible                                      False      True   False
# psf/requests                                         False      True   False
# ...
# discourse/discourse                                  False      True   False
# Homebrew/brew                                        False      True   False
# tootsuite/mastodon                                   False      True   False
# heartcombo/devise                                    False      True   False
# hashicorp/vagrant                                    False      True   False
# CocoaPods/CocoaPods                                  False      True   False
# diaspora/diaspora                                    False      True   False
# sinatra/sinatra                                      False      True   False
# rubocop-hq/rubocop                                   False      True   False
# gollum/gollum                                        False      True   False
# gohugoio/hugo                                        False      True   False
# gogs/gogs                                            False      True   False
# v2ray/v2ray-core                                     False      True   False
# prometheus/prometheus                                False      True   False
# etcd-io/etcd                                         False      True   False
# traefik/traefik                                      False      True   False
# astaxie/beego                                        False      True   False
# istio/istio                                          False      True   False
# hashicorp/terraform                                  False      True   False
# rclone/rclone                                        False      True   False
#
#                                                   few_releases  date_releases  \
# name
# vuejs/vue                                                False          False
# facebook/react                                           False          False
# twbs/bootstrap                                           False          False
# d3/d3                                                    False          False
# facebook/react-native                                    False          False
# nodejs/node                                              False          False
# mrdoob/three.js                                          False          False
# angular/angular.js                                       False          False
# webpack/webpack                                          False          False
# vercel/next.js                                           False          False
# microsoft/TypeScript                                     False          False
# ant-design/ant-design                                    False          False
# reduxjs/redux                                            False          False
# storybookjs/storybook                                    False          False
# ionic-team/ionic-framework                               False          False
# grafana/grafana                                          False          False
# vercel/hyper                                             False          False
# facebook/jest                                            False          False
# nestjs/nest                                              False          False
# vuetifyjs/vuetify                                        False          False
# elastic/elasticsearch                                    False          False
# spring-projects/spring-boot                              False          False
# spring-projects/spring-framework                         False          False
# square/okhttp                                            False          False
# apache/dubbo                                             False          False
# PhilJay/MPAndroidChart                                   False          False
# bumptech/glide                                           False          False
# netty/netty                                              False          False
# ctripcorp/apollo                                         False          False
# alibaba/fastjson                                         False          False
# django/django                                            False          False
# pallets/flask                                            False          False
# keras-team/keras                                         False          False
# ansible/ansible                                          False          False
# psf/requests                                             False          False
# scrapy/scrapy                                            False          False
# home-assistant/core                                      False          False
# soimort/you-get                                          False          False
# huggingface/transformers                                 False          False
# XX-net/XX-Net                                            False          False
# laravel/laravel                                          False          False
# fzaninotto/Faker                                         False          False
# composer/composer                                        False          False
# laravel/framework                                        False          False
# guzzle/guzzle                                            False          False
# bcit-ci/CodeIgniter                                      False          False
# Seldaek/monolog                                          False          False
# sebastianbergmann/phpunit                                False          False
# briannesbitt/Carbon                                      False          False
# WordPress/WordPress                                      False          False
# electron/electron                                        False          False
# opencv/opencv                                            False          False
# bitcoin/bitcoin                                          False          False
# protocolbuffers/protobuf                                 False          False
# pytorch/pytorch                                          False          False
# microsoft/PowerToys                                      False          False
# tesseract-ocr/tesseract                                  False          False
# godotengine/godot                                        False          False
# ocornut/imgui                                            False          False
# aria2/aria2                                              False          False
# Wox-launcher/Wox                                         False          False
# ShareX/ShareX                                            False          False
# icsharpcode/ILSpy                                        False          False
# MaterialDesignInXAML/MaterialDesignInXamlToolkit         False          False
# dotnet/efcore                                            False          False
# aspnetboilerplate/aspnetboilerplate                      False          False
# jellyfin/jellyfin                                        False          False
# SignalR/SignalR                                          False          False
# AutoMapper/AutoMapper                                    False          False
# cefsharp/CefSharp                                        False          False
# netdata/netdata                                          False          False
# obsproject/obs-studio                                    False          False
# ggreer/the_silver_searcher                               False          False
# tmux/tmux                                                False          False
# taosdata/TDengine                                        False          False
# radareorg/radare2                                        False          False
# mpv-player/mpv                                           False          False
# nginx/nginx                                              False          False
# arendst/Tasmota                                          False          False
# allinurl/goaccess                                        False          False
# discourse/discourse                                      False          False
# Homebrew/brew                                            False          False
# tootsuite/mastodon                                       False          False
# heartcombo/devise                                        False          False
# hashicorp/vagrant                                        False          False
# CocoaPods/CocoaPods                                      False          False
# diaspora/diaspora                                        False          False
# sinatra/sinatra                                          False          False
# rubocop-hq/rubocop                                       False          False
# gollum/gollum                                            False          False
# gohugoio/hugo                                            False          False
# gogs/gogs                                                False          False
# v2ray/v2ray-core                                         False          False
# prometheus/prometheus                                    False          False
# etcd-io/etcd                                             False          False
# traefik/traefik                                          False          False
# astaxie/beego                                            False          False
# istio/istio                                              False          False
# hashicorp/terraform                                      False          False
# rclone/rclone                                            False          False
#
#                                                  selected
# name
# vuejs/vue                                            True
# facebook/react                                       True
# twbs/bootstrap                                       True
# d3/d3                                                True
# facebook/react-native                                True
# nodejs/node                                          True
# mrdoob/three.js                                      True
# angular/angular.js                                   True
# webpack/webpack                                      True
# vercel/next.js                                       True
# microsoft/TypeScript                                 True
# ant-design/ant-design                                True
# reduxjs/redux                                        True
# storybookjs/storybook                                True
# ionic-team/ionic-framework                           True
# grafana/grafana                                      True
# vercel/hyper                                         True
# facebook/jest                                        True
# nestjs/nest                                          True
# vuetifyjs/vuetify                                    True
# elastic/elasticsearch                                True
# spring-projects/spring-boot                          True
# spring-projects/spring-framework                     True
# square/okhttp                                        True
# apache/dubbo                                         True
# PhilJay/MPAndroidChart                               True
# bumptech/glide                                       True
# netty/netty                                          True
# ctripcorp/apollo                                     True
# alibaba/fastjson                                     True
# django/django                                        True
# pallets/flask                                        True
# keras-team/keras                                     True
# ansible/ansible                                      True
# psf/requests                                         True
# scrapy/scrapy                                        True
# home-assistant/core                                  True
# soimort/you-get                                      True
# huggingface/transformers                             True
# XX-net/XX-Net                                        True
# laravel/laravel                                      True
# fzaninotto/Faker                                     True
# composer/composer                                    True
# laravel/framework                                    True
# guzzle/guzzle                                        True
# bcit-ci/CodeIgniter                                  True
# Seldaek/monolog                                      True
# sebastianbergmann/phpunit                            True
# briannesbitt/Carbon                                  True
# WordPress/WordPress                                  True
# electron/electron                                    True
# opencv/opencv                                        True
# bitcoin/bitcoin                                      True
# protocolbuffers/protobuf                             True
# pytorch/pytorch                                      True
# microsoft/PowerToys                                  True
# tesseract-ocr/tesseract                              True
# godotengine/godot                                    True
# ocornut/imgui                                        True
# aria2/aria2                                          True
# Wox-launcher/Wox                                     True
# ShareX/ShareX                                        True
# icsharpcode/ILSpy                                    True
# MaterialDesignInXAML/MaterialDesignInXamlToolkit     True
# dotnet/efcore                                        True
# aspnetboilerplate/aspnetboilerplate                  True
# jellyfin/jellyfin                                    True
# SignalR/SignalR                                      True
# AutoMapper/AutoMapper                                True
# cefsharp/CefSharp                                    True
# netdata/netdata                                      True
# obsproject/obs-studio                                True
# ggreer/the_silver_searcher                           True
# tmux/tmux                                            True
# taosdata/TDengine                                    True
# radareorg/radare2                                    True
# mpv-player/mpv                                       True
# nginx/nginx                                          True
# arendst/Tasmota                                      True
# allinurl/goaccess                                    True
# discourse/discourse                                  True
# Homebrew/brew                                        True
# tootsuite/mastodon                                   True
# heartcombo/devise                                    True
# hashicorp/vagrant                                    True
# CocoaPods/CocoaPods                                  True
# diaspora/diaspora                                    True
# sinatra/sinatra                                      True
# rubocop-hq/rubocop                                   True
# gollum/gollum                                        True
# gohugoio/hugo                                        True
# gogs/gogs                                            True
# v2ray/v2ray-core                                     True
# prometheus/prometheus                                True
# etcd-io/etcd                                         True
# traefik/traefik                                      True
# astaxie/beego                                        True
# istio/istio                                          True
# hashicorp/terraform                                  True
# rclone/rclone                                        True

# %%
p = "briannesbitt/Carbon"

releases = pd.DataFrame()
suffix_exception_catalog = {
    "spring-projects/spring-boot": "^.RELEASE$",
    "spring-projects/spring-framework": "^.RELEASE$",
    "netty/netty": "^.Final$",
    "godotengine/godot": "^-stable$",
}

release_exception_catalog = {
    "facebook/react": [
        "15.3.1",
        "15.3.2",
        "16.1.0"
    ], 
    "facebook/react-native": [
        "0.60.2"
    ],
    "nodejs/node": [
        "heads/tags/v0.5.6"
    ], 
    "vercel/next.js": [
        "v2.4.2"
    ], 
    "ionic-team/ionic-framework": [
        "1.0.0"
    ], 
    "grafana/grafana": [
        "6.1.6",
        "7.0.0",
        "7.2.1"
    ], 
    "vercel/hyper": [
        "v0.7.0",
        "v0.7.1"
    ], 
    "nestjs/nest": [
        "6.3.1"
    ], 
    "apache/dubbo": [
        "2.7.6"
    ], 
    "psf/requests": [
        "2.0"
    ], 
    "huggingface/transformers": [
        "0.1.2",
        "0.5.0",
        "1.0",
        "3.0.1",
        "v0.2.0" #clone
    ], 
    "laravel/laravel": [
        "v4.0.8" # clone
    ], 
    "laravel/framework": [
        "5.3"
    ], 
    "dotnet/efcore": [
        "rel/1.0.1",
        "release/2.2",
        "release/3.0",
        "v2.1.10", #clone
        "v2.1.13", #clone
        "v2.1.16", #clone
        "v2.1.17", #clone
        "v2.1.19", #clone
        "v2.1.20", #clone
        "v2.1.21", #clone
        "v2.2.7",  #clone
        "v2.2.8"  #clone
    ], 
    "aspnetboilerplate/aspnetboilerplate": [
        "v.5.1.0",
        "v0.7.3.0", # clone
        "v5.10.1",  # clone
        "v5.12"     # clone
    ], 
    "SignalR/SignalR": [
        "v0.3.5",
        "0.5"
    ],
    "AutoMapper/AutoMapper": [
        "3.3.1"
    ], 
    "sinatra/sinatra": [
        "1.0",
        "v1.1.0",
        "v1.1.1",
        "v1.1.2",
        "v1.1.3",
        "v1.1.4",
        "v1.2.0",
        "v1.2.1",
        "v1.2.2",
        "v1.2.3",
        "v1.2.4",
        "v1.2.5",
        "v1.2.6",
        "v1.2.7",
        "v1.2.8",
        "v1.2.9",
        "v1.3.0",
        "v1.3.1",
        "v1.3.2",
        "v1.3.3",
        "v1.3.4",
        "v1.3.5",
        "v1.3.6",
        "v1.4.0",
        "v1.4.1",
        "v1.4.2",
        "v1.4.3"
    ], 
    "hashicorp/terraform": [
        "0.7.7"
    ],
    "rclone/rclone": [
        "v1.46" #clone
    ],
    "istio/istio": [
        "1.0.7", #clone
        "1.1.2"  #clone
    ],
    "XX-net/XX-Net": [
    	"1.14.5", #clone
        "1.15.0"  #clone
    ],
    "alibaba/fastjson": [
        "1.2.37" #clone
    ],
    "briannesbitt/Carbon": [
        "1.26.1", #clone
        "1.38.3"  #clone
    ],
    "vuetifyjs/vuetify": [
        "v0.8.3" #clone
    ],
    "microsoft/TypeScript": [
        "v1.5.4" #clone
    ],
    "psf/requests": [
        "v2.16.3" #clone
    ],
    "Wox-launcher/Wox": [
        "v1.0.0.185" #clone
    ],
    "jellyfin/jellyfin": [
        "v10.0.1" #clone
    ],
    "radareorg/radare2": [
        "1.0" #clone
    ],
    "v2ray/v2ray-core": [
        "v0.14.2", #clone
        "v2.19.2", #clone
        "v2.19.6", #clone
        "v2.36.3", #clone
        "v2.40.2", #clone
        "v2.41",   #clone
        "v3.11.3", #clone
        "v3.18",   #clone
        "v3.22",   #clone
        "v3.25", #clone
        "v3.38",   #clone
        "v3.46.4"  #clone
    ]
}

def analyze_project(name, lang, suffix_exception_catalog, release_exception_catalog):
    start = time.time()
    path = os.path.abspath(os.path.join('..','..','..','repos2',name))
    if name in suffix_exception_catalog:
        suffix_exception = suffix_exception_catalog[name]
    else:
        suffix_exception = None
    if name in release_exception_catalog:
        release_exceptions = release_exception_catalog[name]
    else:
        release_exceptions = None

    vcs = GitVcs(path)
    release_matcher = VersionWoPreReleaseMatcher(suffix_exception=suffix_exception, 
                                                 release_exceptions=release_exceptions)
    release_miner = TagReleaseMiner(vcs, release_matcher)
    releases = release_miner.mine_releases()

    version_sorter = TimeVersionReleaseSorter()
    releases_wbase = version_sorter.sort(releases)

    path_miner = PathCommitMiner(vcs, releases)
    range_miner = RangeCommitMiner(vcs, releases_wbase)
    time_miner = TimeCommitMiner(vcs, releases_wbase)
    time_naive_miner = TimeNaiveCommitMiner(vcs, releases_wbase)

    path_release_set = path_miner.mine_commits()
    range_release_set = range_miner.mine_commits()
    time_release_set = time_miner.mine_commits()
    time_naive_release_set = time_naive_miner.mine_commits()

    stats = []
    for release in releases:
        if f"{name}@{release.name}" not in release_exception_catalog:
            path_commits = set(path_release_set[release.name].commits)
            range_commits = set(range_release_set[release.name].commits)
            time_commits = set(time_release_set[release.name].commits)
            time_naive_commits = set(time_naive_release_set[release.name].commits)

            path_base_releases = [release.name.value for release in (path_release_set[release.name].base_releases or [])]
            range_base_releases = [release.name.value for release in (range_release_set[release.name].base_releases or [])]
            time_base_releases = [release.name.value for release in (time_release_set[release.name].base_releases or [])]
            time_naive_base_releases = [release.name.value for release in (time_naive_release_set[release.name].base_releases or [])]

            stats.append({
                "project": name,
                "name": release.name.value,
                "version": release.name.version,
                "semantic_version": release.name.semantic_version,
                "prefix": release.name.prefix,
                "suffix": release.name.suffix,
                "lang": lang,
                "head": str(release.head.id),
                "time": release.time,
                "committers": len(path_release_set[release.name].committers),
                "commits": len(path_commits),
                "merges": len(path_release_set[release.name].merges),
                "base_releases": path_base_releases,
                "base_releases_qnt": len(path_base_releases),
                "range_commits": len(range_commits),
                "range_base_releases": range_base_releases,
                "range_tpos": len(path_commits & range_commits),
                "range_fpos": len(range_commits - path_commits),
                "range_fneg": len(path_commits - range_commits),
                "time_commits": len(time_commits),
                "time_base_releases": time_base_releases,
                "time_tpos": len(path_commits & time_commits),
                "time_fpos": len(time_commits - path_commits),
                "time_fneg": len(path_commits - time_commits),
                "time_naive_commits": len(time_naive_commits),
                "time_naive_base_releases": time_naive_base_releases,
                "time_naive_tpos": len(path_commits & time_naive_commits),
                "time_naive_fpos": len(time_naive_commits - path_commits),
                "time_naive_fneg": len(path_commits - time_naive_commits)
            })
    releases = pd.DataFrame(stats)
    print(f"{time.time() - start:10} - {name}") 
    return releases



data = [analyze_project(p, "java", suffix_exception_catalog, release_exception_catalog)]
releases = pd.concat(data)

releases.commits = pd.to_numeric(releases.commits)
releases.time = pd.to_datetime(releases.time, utc=True)
releases.range_commits = pd.to_numeric(releases.range_commits)
releases.range_tpos = pd.to_numeric(releases.range_tpos)
releases.range_fpos = pd.to_numeric(releases.range_fpos)
releases.range_fneg = pd.to_numeric(releases.range_fneg)
releases.time_commits = pd.to_numeric(releases.time_commits)
releases.time_tpos = pd.to_numeric(releases.time_tpos)
releases.time_fpos = pd.to_numeric(releases.time_fpos)
releases.time_fneg = pd.to_numeric(releases.time_fneg)
releases = releases.set_index(['project', 'name'])
# Out:
# 15.33168363571167 - briannesbitt/Carbon

# %%
def precision(row, column):
    if (row[column+"_tpos"] + row[column+"_fpos"]) == 0:
        return 0.0
    else:
        return row[column+"_tpos"] / (row[column+"_tpos"] + row[column+"_fpos"])
    
def recall(row, column):
    if (row[column+"_tpos"] + row[column+"_fneg"]) == 0:
        return 0.0
    else:
        return row[column+"_tpos"] / (row[column+"_tpos"] + row[column+"_fneg"])
    
def fmeasure(row, column):
    if (row[column+"_precision"] + row[column+"_recall"]) == 0:
        return 0
    else:
        return 2 * row[column+"_precision"] * row[column+"_recall"] / (row[column+"_precision"] + row[column+"_recall"])

releases['range_precision'] = releases.apply(precision, args=('range',), axis=1)
releases['range_recall'] = releases.apply(recall, args=('range',), axis=1)
releases['range_fmeasure'] = releases.apply(fmeasure, args=('range',), axis=1)

releases['time_precision'] = releases.apply(precision, args=('time',), axis=1)
releases['time_recall'] = releases.apply(recall, args=('time',), axis=1)
releases['time_fmeasure'] = releases.apply(fmeasure, args=('time',), axis=1)

releases['time_naive_precision'] = releases.apply(precision, args=('time_naive',), axis=1)
releases['time_naive_recall'] = releases.apply(recall, args=('time_naive',), axis=1)
releases['time_naive_fmeasure'] = releases.apply(fmeasure, args=('time_naive',), axis=1)

# %%
releases.groupby(level=0).mean()[['time_precision','range_precision', 'time_recall', 'range_recall']]
# Out:
#                      time_precision  range_precision  time_recall  \
# project
# briannesbitt/Carbon        0.992805         0.982629     0.947798
#
#                      range_recall
# project
# briannesbitt/Carbon           1.0

# %%
releases[releases.time_precision < releases.range_precision][['commits','time_commits','base_releases','time_base_releases','range_base_releases','time_precision','range_precision', 'time_recall', 'range_recall']]
# Out:
# Empty DataFrame
# Columns: [commits, time_commits, base_releases, time_base_releases, range_base_releases, time_precision, range_precision, time_recall, range_recall]
# Index: []

# %%
releases.loc[("nodejs/node","v2.0.0"),['commits', 'range_commits', 'time_commits']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\felip\.virtualenvs\experiment-diqkfhtj\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nodejs/node'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# c:\users\felip\.virtualenvs\experiment-diqkfhtj\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2892             except KeyError as err:
# -> 2893                 raise KeyError(key) from err
#    2894
#
# KeyError: 'nodejs/node'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\users\felip\.virtualenvs\experiment-diqkfhtj\lib\site-packages\pandas\core\indexes\multi.py in get_loc_level(self, key, level, drop_level)
#    2849                     try:
# -> 2850                         return (self._engine.get_loc(key), None)
#    2851                     except KeyError as e:
#
# pandas\_libs\index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# KeyError: ('nodejs/node', 'v2.0.0')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-83fe4dfff8c2> in <module>
# ----> 1 releases.loc[("nodejs/node","v2.0.0"),['commits', 'range_commits', 'time_commits']]
#
# c:\users\felip\.virtualenvs\experiment-diqkfhtj\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# c:\users\felip\.virtualenvs\experiment-diqkfhtj\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# c:\users\felip\.virtualenvs\experiment-diqkfhtj\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     764         # we may have a nested tuples indexer here
#     765         if self._is_nested_tuple_indexer(tup):
# --> 766             return self._getitem_nested_tuple(tup)
#     767
#     768         # we maybe be using a tuple to represent multiple dimensions here
#
# c:\users\felip\.virtualenvs\experiment-diqkfhtj\lib\site-packages\pandas\core\indexing.py in _getitem_nested_tuple(self, tup)
#     845
#     846             current_ndim = obj.ndim
# --> 847             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#     848             axis += 1
#     849
#
# c:\users\felip\.virtualenvs\experiment-diqkfhtj\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# c:\users\felip\.virtualenvs\experiment-diqkfhtj\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# c:\users\felip\.virtualenvs\experiment-diqkfhtj\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3484         index = self.index
#    3485         if isinstance(index, MultiIndex):
# -> 3486             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3487         else:
#    3488             loc = self.index.get_loc(key)
#
# c:\users\felip\.virtualenvs\experiment-diqkfhtj\lib\site-packages\pandas\core\indexes\multi.py in get_loc_level(self, key, level, drop_level)
#    2850                         return (self._engine.get_loc(key), None)
#    2851                     except KeyError as e:
# -> 2852                         raise KeyError(key) from e
#    2853                 else:
#    2854                     return partial_selection(key)
#
# KeyError: ('nodejs/node', 'v2.0.0')

# %%
releases.groupby(level=0).mean()
# Out:
#                 commits    merges  base_releases_qnt  range_commits  \
# project
# nodejs/node  100.111298  0.649241           1.145025     103.005059
#
#              range_tpos  range_fpos  range_fneg  time_commits  time_tpos  \
# project
# nodejs/node    99.84317    3.161889    0.268128     66.662732  63.819562
#
#              time_fpos  ...  time_naive_fneg  range_precision  range_recall  \
# project                 ...
# nodejs/node    2.84317  ...        36.608769         0.955127      0.999024
#
#              range_fmeasure  time_precision  time_recall  time_fmeasure  \
# project
# nodejs/node        0.969942        0.927424     0.961547       0.936786
#
#              time_naive_precision  time_naive_recall  time_naive_fmeasure
# project
# nodejs/node              0.403462            0.94702             0.489241
#
# [1 rows x 24 columns]

# %%
releases = releases.set_index(['project', 'name'])

# %%
releases.head()
# Out:
#                         lang                                      head  \
# project   name
# vuejs/vue 0.6.0   javascript  218557cdec830a629252f4a9e2643973dc1f1d2d
#           v0.7.0  javascript  f4861ca9905a170b9a4b185e8a2038dc7c11c58e
#           v0.7.1  javascript  590a7ee55b655f166ecdf8e7a5e22dab7a9e6dd7
#           v0.7.2  javascript  e78fb82212ac229c91fc8b1f09a84b24f577541a
#           v0.7.3  javascript  dcc839a4314de8825f7087f00c4e40ea2d22b46f
#
#                                       time  commits base_releases  \
# project   name
# vuejs/vue 0.6.0  2013-12-08 00:32:17+00:00      354            []
#           v0.7.0 2013-12-24 03:31:05+00:00       34       [0.6.0]
#           v0.7.1 2013-12-24 21:58:33+00:00        6      [v0.7.0]
#           v0.7.2 2013-12-28 05:43:40+00:00        3      [v0.7.1]
#           v0.7.3 2014-01-06 19:13:12+00:00       15      [v0.7.2]
#
#                   range_commits range_base_releases  range_tpos  range_fpos  \
# project   name
# vuejs/vue 0.6.0             354                  []         354           0
#           v0.7.0             34             [0.6.0]          34           0
#           v0.7.1              6            [v0.7.0]           6           0
#           v0.7.2              3            [v0.7.1]           3           0
#           v0.7.3             15            [v0.7.2]          15           0
#
#                   range_fneg  time_commits time_base_releases  time_tpos  \
# project   name
# vuejs/vue 0.6.0            0           354                 []        354
#           v0.7.0           0            34            [0.6.0]         34
#           v0.7.1           0             6           [v0.7.0]          6
#           v0.7.2           0             3           [v0.7.1]          3
#           v0.7.3           0            15           [v0.7.2]         15
#
#                   time_fpos  time_fneg  range_precision  range_recall  \
# project   name
# vuejs/vue 0.6.0           0          0              1.0           1.0
#           v0.7.0          0          0              1.0           1.0
#           v0.7.1          0          0              1.0           1.0
#           v0.7.2          0          0              1.0           1.0
#           v0.7.3          0          0              1.0           1.0
#
#                   time_precision  time_recall
# project   name
# vuejs/vue 0.6.0              1.0          1.0
#           v0.7.0             1.0          1.0
#           v0.7.1             1.0          1.0
#           v0.7.2             1.0          1.0
#           v0.7.3             1.0          1.0

# %%
releases.dtypes
# Out:
# lang                                object
# head                                object
# time                   datetime64[ns, UTC]
# commits                              int64
# base_releases                       object
# range_commits                        int64
# range_base_releases                 object
# range_tpos                           int64
# range_fpos                           int64
# range_fneg                           int64
# time_commits                         int64
# time_base_releases                  object
# time_tpos                            int64
# time_fpos                            int64
# time_fneg                            int64
# range_precision                    float64
# range_recall                       float64
# time_precision                     float64
# time_recall                        float64
# dtype: object

# %%
releases.to_pickle("releases.zip")
releases.to_csv("releases.csv")

# %%
releases.groupby(level=0).mean()[['range_precision','range_recall','time_precision','time_recall']].sort_values('range_recall')
# Out:
#                                                   range_precision  \
# project
# dotnet/efcore                                            0.861097
# taosdata/TDengine                                        0.899112
# jellyfin/jellyfin                                        0.928050
# Wox-launcher/Wox                                         0.973684
# cefsharp/CefSharp                                        0.980903
# alibaba/fastjson                                         0.967328
# apache/dubbo                                             0.985109
# ionic-team/ionic-framework                               0.964719
# spring-projects/spring-framework                         0.986764
# ansible/ansible                                          0.987110
# aria2/aria2                                              0.985750
# laravel/laravel                                          0.967545
# facebook/jest                                            0.983616
# ytdl-org/youtube-dl                                      0.991657
# discourse/discourse                                      0.994569
# webpack/webpack                                          0.995715
# netty/netty                                              0.991238
# v2ray/v2ray-core                                         0.996793
# ant-design/ant-design                                    0.996487
# electron/electron                                        0.997561
# WordPress/WordPress                                      0.998171
# spring-projects/spring-boot                              0.867198
# Seldaek/monolog                                          0.954060
# nodejs/node                                              0.953342
# prometheus/prometheus                                    0.977678
# django/django                                            0.995095
# sebastianbergmann/phpunit                                0.916088
# laravel/framework                                        0.913758
# nginx/nginx                                              0.999475
# guzzle/guzzle                                            0.996928
# pallets/flask                                            0.975679
# vuetifyjs/vuetify                                        0.996083
# opencv/opencv                                            0.892497
# bitcoin/bitcoin                                          0.977067
# netdata/netdata                                          1.000000
# ocornut/imgui                                            1.000000
# mrdoob/three.js                                          1.000000
# mpv-player/mpv                                           1.000000
# vuejs/vue                                                1.000000
# nestjs/nest                                              1.000000
# obsproject/obs-studio                                    0.999975
# tmux/tmux                                                1.000000
# radareorg/radare2                                        1.000000
# psf/requests                                             0.993630
# tesseract-ocr/tesseract                                  1.000000
# tootsuite/mastodon                                       1.000000
# storybookjs/storybook                                    0.998559
# square/okhttp                                            1.000000
# traefik/traefik                                          1.000000
# twbs/bootstrap                                           1.000000
# protocolbuffers/protobuf                                 0.988596
# soimort/you-get                                          1.000000
# scrapy/scrapy                                            0.998193
# rubocop-hq/rubocop                                       1.000000
# reduxjs/redux                                            0.935286
# vercel/hyper                                             0.966542
# rclone/rclone                                            1.000000
# pytorch/pytorch                                          1.000000
# sinatra/sinatra                                          1.000000
# microsoft/TypeScript                                     0.994229
# AutoMapper/AutoMapper                                    1.000000
# keras-team/keras                                         1.000000
# ctripcorp/apollo                                         1.000000
# composer/composer                                        1.000000
# bumptech/glide                                           1.000000
# briannesbitt/Carbon                                      0.962301
# bcit-ci/CodeIgniter                                      1.000000
# astaxie/beego                                            0.999702
# aspnetboilerplate/aspnetboilerplate                      0.986190
# d3/d3                                                    0.999053
# arendst/Tasmota                                          0.993902
# allinurl/goaccess                                        1.000000
# SignalR/SignalR                                          1.000000
# ShareX/ShareX                                            1.000000
# PhilJay/MPAndroidChart                                   1.000000
# MaterialDesignInXAML/MaterialDesignInXamlToolkit         0.998825
# Homebrew/brew                                            1.000000
# CocoaPods/CocoaPods                                      0.999824
# angular/angular.js                                       1.000000
# microsoft/PowerToys                                      0.999711
# diaspora/diaspora                                        0.987103
# etcd-io/etcd                                             1.000000
# jquery/jquery                                            1.000000
# istio/istio                                              0.999899
# icsharpcode/ILSpy                                        1.000000
# huggingface/transformers                                 1.000000
# heartcombo/devise                                        1.000000
# hashicorp/vagrant                                        1.000000
# hashicorp/terraform                                      1.000000
# elastic/elasticsearch                                    1.000000
# grafana/grafana                                          0.991675
# gohugoio/hugo                                            0.994978
# gogs/gogs                                                1.000000
# godotengine/godot                                        1.000000
# ggreer/the_silver_searcher                               1.000000
# fzaninotto/Faker                                         1.000000
# facebook/react-native                                    1.000000
# facebook/react                                           0.976920
# gollum/gollum                                            1.000000
# home-assistant/core                                      0.995911
#
#                                                   range_recall  \
# project
# dotnet/efcore                                         0.907146
# taosdata/TDengine                                     0.919301
# jellyfin/jellyfin                                     0.966667
# Wox-launcher/Wox                                      0.973684
# cefsharp/CefSharp                                     0.984641
# alibaba/fastjson                                      0.988636
# apache/dubbo                                          0.988803
# ionic-team/ionic-framework                            0.990948
# spring-projects/spring-framework                      0.992801
# ansible/ansible                                       0.993056
# aria2/aria2                                           0.993205
# laravel/laravel                                       0.993677
# facebook/jest                                         0.994152
# ytdl-org/youtube-dl                                   0.994393
# discourse/discourse                                   0.995196
# webpack/webpack                                       0.996433
# netty/netty                                           0.996615
# v2ray/v2ray-core                                      0.997126
# ant-design/ant-design                                 0.997509
# electron/electron                                     0.998063
# WordPress/WordPress                                   0.998210
# spring-projects/spring-boot                           0.998831
# Seldaek/monolog                                       0.999015
# nodejs/node                                           0.999019
# prometheus/prometheus                                 0.999331
# django/django                                         0.999334
# sebastianbergmann/phpunit                             0.999379
# laravel/framework                                     0.999463
# nginx/nginx                                           0.999548
# guzzle/guzzle                                         0.999594
# pallets/flask                                         0.999948
# vuetifyjs/vuetify                                     0.999958
# opencv/opencv                                         0.999960
# bitcoin/bitcoin                                       0.999972
# netdata/netdata                                       1.000000
# ocornut/imgui                                         1.000000
# mrdoob/three.js                                       1.000000
# mpv-player/mpv                                        1.000000
# vuejs/vue                                             1.000000
# nestjs/nest                                           1.000000
# obsproject/obs-studio                                 1.000000
# tmux/tmux                                             1.000000
# radareorg/radare2                                     1.000000
# psf/requests                                          1.000000
# tesseract-ocr/tesseract                               1.000000
# tootsuite/mastodon                                    1.000000
# storybookjs/storybook                                 1.000000
# square/okhttp                                         1.000000
# traefik/traefik                                       1.000000
# twbs/bootstrap                                        1.000000
# protocolbuffers/protobuf                              1.000000
# soimort/you-get                                       1.000000
# scrapy/scrapy                                         1.000000
# rubocop-hq/rubocop                                    1.000000
# reduxjs/redux                                         1.000000
# vercel/hyper                                          1.000000
# rclone/rclone                                         1.000000
# pytorch/pytorch                                       1.000000
# sinatra/sinatra                                       1.000000
# microsoft/TypeScript                                  1.000000
# AutoMapper/AutoMapper                                 1.000000
# keras-team/keras                                      1.000000
# ctripcorp/apollo                                      1.000000
# composer/composer                                     1.000000
# bumptech/glide                                        1.000000
# briannesbitt/Carbon                                   1.000000
# bcit-ci/CodeIgniter                                   1.000000
# astaxie/beego                                         1.000000
# aspnetboilerplate/aspnetboilerplate                   1.000000
# d3/d3                                                 1.000000
# arendst/Tasmota                                       1.000000
# allinurl/goaccess                                     1.000000
# SignalR/SignalR                                       1.000000
# ShareX/ShareX                                         1.000000
# PhilJay/MPAndroidChart                                1.000000
# MaterialDesignInXAML/MaterialDesignInXamlToolkit      1.000000
# Homebrew/brew                                         1.000000
# CocoaPods/CocoaPods                                   1.000000
# angular/angular.js                                    1.000000
# microsoft/PowerToys                                   1.000000
# diaspora/diaspora                                     1.000000
# etcd-io/etcd                                          1.000000
# jquery/jquery                                         1.000000
# istio/istio                                           1.000000
# icsharpcode/ILSpy                                     1.000000
# huggingface/transformers                              1.000000
# heartcombo/devise                                     1.000000
# hashicorp/vagrant                                     1.000000
# hashicorp/terraform                                   1.000000
# elastic/elasticsearch                                 1.000000
# grafana/grafana                                       1.000000
# gohugoio/hugo                                         1.000000
# gogs/gogs                                             1.000000
# godotengine/godot                                     1.000000
# ggreer/the_silver_searcher                            1.000000
# fzaninotto/Faker                                      1.000000
# facebook/react-native                                 1.000000
# facebook/react                                        1.000000
# gollum/gollum                                         1.000000
# home-assistant/core                                   1.000000
#
#                                                   time_precision  time_recall
# project
# dotnet/efcore                                           0.339455     0.734689
# taosdata/TDengine                                       0.494730     0.809400
# jellyfin/jellyfin                                       0.368276     0.909911
# Wox-launcher/Wox                                        0.741645     0.936863
# cefsharp/CefSharp                                       0.526221     0.779052
# alibaba/fastjson                                        0.584992     0.957588
# apache/dubbo                                            0.438777     0.832963
# ionic-team/ionic-framework                              0.658225     0.887462
# spring-projects/spring-framework                        0.369048     0.927707
# ansible/ansible                                         0.236216     0.883675
# aria2/aria2                                             0.913342     0.922616
# laravel/laravel                                         0.669659     0.886555
# facebook/jest                                           0.823980     0.954924
# ytdl-org/youtube-dl                                     0.841618     0.956118
# discourse/discourse                                     0.461369     0.904493
# webpack/webpack                                         0.638549     0.884753
# netty/netty                                             0.448976     0.937916
# v2ray/v2ray-core                                        0.936334     0.945600
# ant-design/ant-design                                   0.724545     0.926181
# electron/electron                                       0.507292     0.892473
# WordPress/WordPress                                     0.138706     0.928619
# spring-projects/spring-boot                             0.370375     0.926167
# Seldaek/monolog                                         0.754822     0.955288
# nodejs/node                                             0.439025     0.945474
# prometheus/prometheus                                   0.554426     0.827250
# django/django                                           0.256410     0.821580
# sebastianbergmann/phpunit                               0.420406     0.862767
# laravel/framework                                       0.577871     0.938432
# nginx/nginx                                             0.714641     0.846592
# guzzle/guzzle                                           0.877881     0.954438
# pallets/flask                                           0.642369     0.884351
# vuetifyjs/vuetify                                       0.615645     0.940246
# opencv/opencv                                           0.458698     0.900270
# bitcoin/bitcoin                                         0.379277     0.789126
# netdata/netdata                                         0.995398     0.996960
# ocornut/imgui                                           0.862619     0.969942
# mrdoob/three.js                                         0.908704     0.919143
# mpv-player/mpv                                          0.547801     0.903699
# vuejs/vue                                               0.894595     0.978510
# nestjs/nest                                             0.882837     0.930667
# obsproject/obs-studio                                   0.884257     0.969236
# tmux/tmux                                               0.780144     0.906600
# radareorg/radare2                                       0.970491     0.996809
# psf/requests                                            0.914303     0.947484
# tesseract-ocr/tesseract                                 0.771658     0.938389
# tootsuite/mastodon                                      0.789145     0.929892
# storybookjs/storybook                                   0.565404     0.939742
# square/okhttp                                           0.534768     0.908654
# traefik/traefik                                         0.478468     0.926640
# twbs/bootstrap                                          0.692270     0.945280
# protocolbuffers/protobuf                                0.407196     0.790449
# soimort/you-get                                         0.933250     0.981949
# scrapy/scrapy                                           0.511644     0.783784
# rubocop-hq/rubocop                                      0.979921     0.992658
# reduxjs/redux                                           0.869338     0.906131
# vercel/hyper                                            0.870009     0.959424
# rclone/rclone                                           0.855534     0.969377
# pytorch/pytorch                                         0.471196     0.801698
# sinatra/sinatra                                         0.728727     0.881017
# microsoft/TypeScript                                    0.325319     0.779576
# AutoMapper/AutoMapper                                   0.904958     0.923837
# keras-team/keras                                        0.959869     0.982874
# ctripcorp/apollo                                        0.794591     0.939003
# composer/composer                                       0.490186     0.864838
# bumptech/glide                                          0.660599     0.955430
# briannesbitt/Carbon                                     0.604365     0.899559
# bcit-ci/CodeIgniter                                     0.354019     0.931246
# astaxie/beego                                           0.966162     0.961084
# aspnetboilerplate/aspnetboilerplate                     0.902278     0.956086
# d3/d3                                                   0.830477     0.941087
# arendst/Tasmota                                         0.805578     0.960280
# allinurl/goaccess                                       0.464313     0.700794
# SignalR/SignalR                                         0.552411     0.846578
# ShareX/ShareX                                           0.979056     0.988766
# PhilJay/MPAndroidChart                                  0.973404     0.988933
# MaterialDesignInXAML/MaterialDesignInXamlToolkit        0.849091     0.909790
# Homebrew/brew                                           0.919105     0.922389
# CocoaPods/CocoaPods                                     0.802406     0.941544
# angular/angular.js                                      0.610223     0.923273
# microsoft/PowerToys                                     0.455444     0.909868
# diaspora/diaspora                                       0.383118     0.765880
# etcd-io/etcd                                            0.253584     0.924332
# jquery/jquery                                           0.744244     0.950539
# istio/istio                                             0.204643     0.841270
# icsharpcode/ILSpy                                       0.681201     0.907310
# huggingface/transformers                                0.846581     0.965043
# heartcombo/devise                                       0.616350     0.891484
# hashicorp/vagrant                                       0.884996     0.945794
# hashicorp/terraform                                     0.753029     0.917918
# elastic/elasticsearch                                   0.266773     0.738842
# grafana/grafana                                         0.384095     0.861315
# gohugoio/hugo                                           0.935508     0.974284
# gogs/gogs                                               0.953159     0.979044
# godotengine/godot                                       0.385759     0.892090
# ggreer/the_silver_searcher                              0.910205     0.961298
# fzaninotto/Faker                                        0.967657     0.961780
# facebook/react-native                                   0.208155     0.711286
# facebook/react                                          0.529524     0.833534
# gollum/gollum                                           0.923572     0.964812
# home-assistant/core                                     0.410182     0.858160

# %%
releases.groupby(['project']).mean()[['range_precision','range_recall','time_precision','time_recall']].sort_values('range_recall')
# Out:
#                                                   range_precision  \
# project
# dotnet/efcore                                            0.861097
# taosdata/TDengine                                        0.899112
# jellyfin/jellyfin                                        0.928050
# Wox-launcher/Wox                                         0.973684
# cefsharp/CefSharp                                        0.980903
# alibaba/fastjson                                         0.967328
# apache/dubbo                                             0.985109
# ionic-team/ionic-framework                               0.964719
# spring-projects/spring-framework                         0.986764
# ansible/ansible                                          0.987110
# aria2/aria2                                              0.985750
# laravel/laravel                                          0.967545
# facebook/jest                                            0.983616
# ytdl-org/youtube-dl                                      0.991657
# discourse/discourse                                      0.994569
# webpack/webpack                                          0.995715
# netty/netty                                              0.991238
# v2ray/v2ray-core                                         0.996793
# ant-design/ant-design                                    0.996487
# electron/electron                                        0.997561
# WordPress/WordPress                                      0.998171
# spring-projects/spring-boot                              0.867198
# Seldaek/monolog                                          0.954060
# nodejs/node                                              0.953342
# prometheus/prometheus                                    0.977678
# django/django                                            0.995095
# sebastianbergmann/phpunit                                0.916088
# laravel/framework                                        0.913758
# nginx/nginx                                              0.999475
# guzzle/guzzle                                            0.996928
# pallets/flask                                            0.975679
# vuetifyjs/vuetify                                        0.996083
# opencv/opencv                                            0.892497
# bitcoin/bitcoin                                          0.977067
# netdata/netdata                                          1.000000
# ocornut/imgui                                            1.000000
# mrdoob/three.js                                          1.000000
# mpv-player/mpv                                           1.000000
# vuejs/vue                                                1.000000
# nestjs/nest                                              1.000000
# obsproject/obs-studio                                    0.999975
# tmux/tmux                                                1.000000
# radareorg/radare2                                        1.000000
# psf/requests                                             0.993630
# tesseract-ocr/tesseract                                  1.000000
# tootsuite/mastodon                                       1.000000
# storybookjs/storybook                                    0.998559
# square/okhttp                                            1.000000
# traefik/traefik                                          1.000000
# twbs/bootstrap                                           1.000000
# protocolbuffers/protobuf                                 0.988596
# soimort/you-get                                          1.000000
# scrapy/scrapy                                            0.998193
# rubocop-hq/rubocop                                       1.000000
# reduxjs/redux                                            0.935286
# vercel/hyper                                             0.966542
# rclone/rclone                                            1.000000
# pytorch/pytorch                                          1.000000
# sinatra/sinatra                                          1.000000
# microsoft/TypeScript                                     0.994229
# AutoMapper/AutoMapper                                    1.000000
# keras-team/keras                                         1.000000
# ctripcorp/apollo                                         1.000000
# composer/composer                                        1.000000
# bumptech/glide                                           1.000000
# briannesbitt/Carbon                                      0.962301
# bcit-ci/CodeIgniter                                      1.000000
# astaxie/beego                                            0.999702
# aspnetboilerplate/aspnetboilerplate                      0.986190
# d3/d3                                                    0.999053
# arendst/Tasmota                                          0.993902
# allinurl/goaccess                                        1.000000
# SignalR/SignalR                                          1.000000
# ShareX/ShareX                                            1.000000
# PhilJay/MPAndroidChart                                   1.000000
# MaterialDesignInXAML/MaterialDesignInXamlToolkit         0.998825
# Homebrew/brew                                            1.000000
# CocoaPods/CocoaPods                                      0.999824
# angular/angular.js                                       1.000000
# microsoft/PowerToys                                      0.999711
# diaspora/diaspora                                        0.987103
# etcd-io/etcd                                             1.000000
# jquery/jquery                                            1.000000
# istio/istio                                              0.999899
# icsharpcode/ILSpy                                        1.000000
# huggingface/transformers                                 1.000000
# heartcombo/devise                                        1.000000
# hashicorp/vagrant                                        1.000000
# hashicorp/terraform                                      1.000000
# elastic/elasticsearch                                    1.000000
# grafana/grafana                                          0.991675
# gohugoio/hugo                                            0.994978
# gogs/gogs                                                1.000000
# godotengine/godot                                        1.000000
# ggreer/the_silver_searcher                               1.000000
# fzaninotto/Faker                                         1.000000
# facebook/react-native                                    1.000000
# facebook/react                                           0.976920
# gollum/gollum                                            1.000000
# home-assistant/core                                      0.995911
#
#                                                   range_recall  \
# project
# dotnet/efcore                                         0.907146
# taosdata/TDengine                                     0.919301
# jellyfin/jellyfin                                     0.966667
# Wox-launcher/Wox                                      0.973684
# cefsharp/CefSharp                                     0.984641
# alibaba/fastjson                                      0.988636
# apache/dubbo                                          0.988803
# ionic-team/ionic-framework                            0.990948
# spring-projects/spring-framework                      0.992801
# ansible/ansible                                       0.993056
# aria2/aria2                                           0.993205
# laravel/laravel                                       0.993677
# facebook/jest                                         0.994152
# ytdl-org/youtube-dl                                   0.994393
# discourse/discourse                                   0.995196
# webpack/webpack                                       0.996433
# netty/netty                                           0.996615
# v2ray/v2ray-core                                      0.997126
# ant-design/ant-design                                 0.997509
# electron/electron                                     0.998063
# WordPress/WordPress                                   0.998210
# spring-projects/spring-boot                           0.998831
# Seldaek/monolog                                       0.999015
# nodejs/node                                           0.999019
# prometheus/prometheus                                 0.999331
# django/django                                         0.999334
# sebastianbergmann/phpunit                             0.999379
# laravel/framework                                     0.999463
# nginx/nginx                                           0.999548
# guzzle/guzzle                                         0.999594
# pallets/flask                                         0.999948
# vuetifyjs/vuetify                                     0.999958
# opencv/opencv                                         0.999960
# bitcoin/bitcoin                                       0.999972
# netdata/netdata                                       1.000000
# ocornut/imgui                                         1.000000
# mrdoob/three.js                                       1.000000
# mpv-player/mpv                                        1.000000
# vuejs/vue                                             1.000000
# nestjs/nest                                           1.000000
# obsproject/obs-studio                                 1.000000
# tmux/tmux                                             1.000000
# radareorg/radare2                                     1.000000
# psf/requests                                          1.000000
# tesseract-ocr/tesseract                               1.000000
# tootsuite/mastodon                                    1.000000
# storybookjs/storybook                                 1.000000
# square/okhttp                                         1.000000
# traefik/traefik                                       1.000000
# twbs/bootstrap                                        1.000000
# protocolbuffers/protobuf                              1.000000
# soimort/you-get                                       1.000000
# scrapy/scrapy                                         1.000000
# rubocop-hq/rubocop                                    1.000000
# reduxjs/redux                                         1.000000
# vercel/hyper                                          1.000000
# rclone/rclone                                         1.000000
# pytorch/pytorch                                       1.000000
# sinatra/sinatra                                       1.000000
# microsoft/TypeScript                                  1.000000
# AutoMapper/AutoMapper                                 1.000000
# keras-team/keras                                      1.000000
# ctripcorp/apollo                                      1.000000
# composer/composer                                     1.000000
# bumptech/glide                                        1.000000
# briannesbitt/Carbon                                   1.000000
# bcit-ci/CodeIgniter                                   1.000000
# astaxie/beego                                         1.000000
# aspnetboilerplate/aspnetboilerplate                   1.000000
# d3/d3                                                 1.000000
# arendst/Tasmota                                       1.000000
# allinurl/goaccess                                     1.000000
# SignalR/SignalR                                       1.000000
# ShareX/ShareX                                         1.000000
# PhilJay/MPAndroidChart                                1.000000
# MaterialDesignInXAML/MaterialDesignInXamlToolkit      1.000000
# Homebrew/brew                                         1.000000
# CocoaPods/CocoaPods                                   1.000000
# angular/angular.js                                    1.000000
# microsoft/PowerToys                                   1.000000
# diaspora/diaspora                                     1.000000
# etcd-io/etcd                                          1.000000
# jquery/jquery                                         1.000000
# istio/istio                                           1.000000
# icsharpcode/ILSpy                                     1.000000
# huggingface/transformers                              1.000000
# heartcombo/devise                                     1.000000
# hashicorp/vagrant                                     1.000000
# hashicorp/terraform                                   1.000000
# elastic/elasticsearch                                 1.000000
# grafana/grafana                                       1.000000
# gohugoio/hugo                                         1.000000
# gogs/gogs                                             1.000000
# godotengine/godot                                     1.000000
# ggreer/the_silver_searcher                            1.000000
# fzaninotto/Faker                                      1.000000
# facebook/react-native                                 1.000000
# facebook/react                                        1.000000
# gollum/gollum                                         1.000000
# home-assistant/core                                   1.000000
#
#                                                   time_precision  time_recall
# project
# dotnet/efcore                                           0.363637     0.775465
# taosdata/TDengine                                       0.454907     0.819983
# jellyfin/jellyfin                                       0.368276     0.909911
# Wox-launcher/Wox                                        0.741645     0.936863
# cefsharp/CefSharp                                       0.541150     0.784172
# alibaba/fastjson                                        0.584946     0.957588
# apache/dubbo                                            0.439195     0.832963
# ionic-team/ionic-framework                              0.656842     0.885974
# spring-projects/spring-framework                        0.369032     0.927707
# ansible/ansible                                         0.239749     0.905605
# aria2/aria2                                             0.912522     0.921558
# laravel/laravel                                         0.669659     0.886555
# facebook/jest                                           0.823980     0.954924
# ytdl-org/youtube-dl                                     0.827162     0.939764
# discourse/discourse                                     0.464142     0.916132
# webpack/webpack                                         0.638549     0.884753
# netty/netty                                             0.448971     0.937916
# v2ray/v2ray-core                                        0.974897     0.985956
# ant-design/ant-design                                   0.723756     0.924528
# electron/electron                                       0.503553     0.897591
# WordPress/WordPress                                     0.138706     0.928619
# spring-projects/spring-boot                             0.370375     0.926167
# Seldaek/monolog                                         0.754822     0.955288
# nodejs/node                                             0.438016     0.953422
# prometheus/prometheus                                   0.553416     0.824555
# django/django                                           0.194532     0.926104
# sebastianbergmann/phpunit                               0.420311     0.880493
# laravel/framework                                       0.577872     0.938432
# nginx/nginx                                             0.714641     0.846592
# guzzle/guzzle                                           0.877736     0.955182
# pallets/flask                                           0.642369     0.884351
# vuetifyjs/vuetify                                       0.608165     0.929884
# opencv/opencv                                           0.457840     0.901917
# bitcoin/bitcoin                                         0.386716     0.787696
# netdata/netdata                                         0.995671     0.997238
# ocornut/imgui                                           0.862619     0.969942
# mrdoob/three.js                                         0.923663     0.930750
# mpv-player/mpv                                          0.546669     0.896915
# vuejs/vue                                               0.888467     0.965795
# nestjs/nest                                             0.882837     0.930667
# obsproject/obs-studio                                   0.881794     0.958635
# tmux/tmux                                               0.789089     0.915618
# radareorg/radare2                                       0.970491     0.996809
# psf/requests                                            0.914303     0.947157
# tesseract-ocr/tesseract                                 0.771658     0.938389
# tootsuite/mastodon                                      0.789145     0.929892
# storybookjs/storybook                                   0.565404     0.939742
# square/okhttp                                           0.534768     0.908654
# traefik/traefik                                         0.478468     0.926640
# twbs/bootstrap                                          0.668773     0.920485
# protocolbuffers/protobuf                                0.438281     0.744800
# soimort/you-get                                         0.933472     0.982316
# scrapy/scrapy                                           0.517125     0.824023
# rubocop-hq/rubocop                                      0.979921     0.992658
# reduxjs/redux                                           0.861486     0.905735
# vercel/hyper                                            0.870009     0.959424
# rclone/rclone                                           0.868183     0.969319
# pytorch/pytorch                                         0.471184     0.801669
# sinatra/sinatra                                         0.762348     0.921368
# microsoft/TypeScript                                    0.325319     0.779576
# AutoMapper/AutoMapper                                   0.909958     0.945576
# keras-team/keras                                        0.953610     0.983474
# ctripcorp/apollo                                        0.794591     0.939003
# composer/composer                                       0.490186     0.864838
# bumptech/glide                                          0.656581     0.954456
# briannesbitt/Carbon                                     0.604365     0.899559
# bcit-ci/CodeIgniter                                     0.354211     0.939058
# astaxie/beego                                           0.964889     0.960814
# aspnetboilerplate/aspnetboilerplate                     0.902278     0.956086
# d3/d3                                                   0.828337     0.938246
# arendst/Tasmota                                         0.805578     0.960280
# allinurl/goaccess                                       0.565154     0.933302
# SignalR/SignalR                                         0.552411     0.846578
# ShareX/ShareX                                           0.993437     0.999114
# PhilJay/MPAndroidChart                                  0.973404     0.988933
# MaterialDesignInXAML/MaterialDesignInXamlToolkit        0.857296     0.926358
# Homebrew/brew                                           0.920168     0.924820
# CocoaPods/CocoaPods                                     0.808251     0.949620
# angular/angular.js                                      0.618971     0.944300
# microsoft/PowerToys                                     0.455444     0.909868
# diaspora/diaspora                                       0.391170     0.833786
# etcd-io/etcd                                            0.256786     0.930501
# jquery/jquery                                           0.744167     0.950171
# istio/istio                                             0.228949     0.885829
# icsharpcode/ILSpy                                       0.702405     0.916444
# huggingface/transformers                                0.846581     0.965043
# heartcombo/devise                                       0.616350     0.891484
# hashicorp/vagrant                                       0.886361     0.952525
# hashicorp/terraform                                     0.753222     0.918278
# elastic/elasticsearch                                   0.272911     0.832844
# grafana/grafana                                         0.353304     0.697523
# gohugoio/hugo                                           0.856554     0.881170
# gogs/gogs                                               0.953159     0.979044
# godotengine/godot                                       0.385759     0.892090
# ggreer/the_silver_searcher                              0.910205     0.961298
# fzaninotto/Faker                                        0.967657     0.961780
# facebook/react-native                                   0.206162     0.711112
# facebook/react                                          0.530025     0.871771
# gollum/gollum                                           0.923572     0.964812
# home-assistant/core                                     0.409631     0.858905

# %%
releases.sort_values('range_recall')
# Out:
#                              project            name    lang  \
# 2                    ansible/ansible            0.01  python
# 2   spring-projects/spring-framework  v3.0.1.RELEASE    java
# 14                  alibaba/fastjson          1.1.42    java
# 25                     dotnet/efcore         v2.1.10      c#
# 61               ytdl-org/youtube-dl      2012.02.26  python
# ..                               ...             ...     ...
# 74               ytdl-org/youtube-dl      2013.01.11  python
# 75               ytdl-org/youtube-dl      2013.01.12  python
# 76               ytdl-org/youtube-dl      2013.01.13  python
# 64               ytdl-org/youtube-dl      2012.10.09  python
# 76                     rclone/rclone         v1.53.1      go
#
#                                         head                      time  \
# 2   56de2e112a97f312c7a07c89e1ce5de74a2637f8 2012-03-08 19:12:58+00:00
# 2   c20c4e1f05eb3c64062ba3af509c528ad003f089 2010-02-18 17:56:59+00:00
# 14  354543ec35cda1a67839ac0a03792e69682435be 2014-10-11 08:24:04+00:00
# 25  0cde562cc070fd00ecf33248df715f6df58a1691 2019-01-10 21:54:40+00:00
# 61  c4105fa035a5c7c4d9aebc4a27822b1839961b7f 2012-02-26 23:42:26+00:00
# ..                                       ...                       ...
# 74  142d38f776913d1e2c004bd7358942f645ffd734 2013-01-11 07:05:30+00:00
# 75  fbc5f99db98de9707b0cb72d060a777cec2c0af4 2013-01-12 16:59:58+00:00
# 76  bbc3e2753a465cf96d19913d160c148464542319 2013-01-12 21:18:13+00:00
# 64  7b107eea5180444f7d8585889139cfe87eaa2cbd 2012-10-09 13:53:20+00:00
# 76  043016318039f1aea3f004147c996e38db33d9c3 2020-09-13 08:40:22+00:00
#
#     commits     base_releases  range_commits range_base_releases  range_tpos  \
# 2       260                []              0             [0.0.2]           0
# 2       234  [v3.0.0.RELEASE]              0  [v3.0.1.RELEASE.A]           0
# 14      122  [1.1.33, 1.1.36]              0            [1.1.37]           0
# 25        3          [v2.2.1]              0            [v2.1.8]           0
# 61       11      [2012.01.08]              0        [2012.02.22]           0
# ..      ...               ...            ...                 ...         ...
# 74        5      [2013.01.08]              5        [2013.01.08]           5
# 75        4      [2012.12.99]             36        [2013.01.11]           4
# 76       10      [2013.01.12]             10        [2013.01.12]          10
# 64       68      [2012.09.27]             68        [2012.09.27]          68
# 76       22         [v1.53.0]             22           [v1.53.0]          22
#
#     ...  range_fneg  time_commits  time_base_releases time_tpos  time_fpos  \
# 2   ...         260             0             [0.0.2]         0          0
# 2   ...         234             0  [v3.0.1.RELEASE.A]         0          0
# 14  ...         122             0            [1.1.37]         0          0
# 25  ...           3             0            [v2.1.8]         0          0
# 61  ...          11             0        [2012.02.22]         0          0
# ..  ...         ...           ...                 ...       ...        ...
# 74  ...           0             6        [2013.01.08]         5          1
# 75  ...           0            21        [2013.01.11]         4         17
# 76  ...           0            13        [2013.01.12]        10          3
# 64  ...           0            41        [2012.09.27]        38          3
# 76  ...           0            58           [v1.53.0]        22         36
#
#     time_fneg  range_precision  range_recall  time_precision  time_recall
# 2         260         1.000000           0.0        1.000000     0.000000
# 2         234         1.000000           0.0        1.000000     0.000000
# 14        122         1.000000           0.0        1.000000     0.000000
# 25          3         1.000000           0.0        1.000000     0.000000
# 61         11         1.000000           0.0        1.000000     0.000000
# ..        ...              ...           ...             ...          ...
# 74          0         1.000000           1.0        0.833333     1.000000
# 75          0         0.111111           1.0        0.190476     1.000000
# 76          0         1.000000           1.0        0.769231     1.000000
# 64         30         1.000000           1.0        0.926829     0.558824
# 76          0         1.000000           1.0        0.379310     1.000000
#
# [14126 rows x 21 columns]
